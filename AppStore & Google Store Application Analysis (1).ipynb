# %% [markdown]
# <h1> AppStore & Google Store Application Analysis </h1>
#
# Author:
# - Sahil Klaeb
# - sahilklaeb@gmail.com
#
# Significance of Study:
# - In the realm of mobile, tablet and desktop applications, both the Apple AppStore and Google's Google Play are both leaders in the application landscape. Both providers carry identical applications and those that are custom to their own platforms.
#
# - In addition, most of the applications on these stores are free. I want to analyze revenue and profitability of these free applications via in-application adds.
#
# - The logic in calculating revenue from free application stems from the fact that because adds are the number 1 revenue generator for profitability, we can deduce that the revenue for any given application is influenced by the number of customers who use the application.
#
# Goal of Study:
# - After forming our analysis, the goal of this study is to truly help our developers understand what type of applications attract more users, in turn, prioritizing our Product, Engineering, Operations and Communication verticals to target these types of applications.
#
# A Note from the author:
# - Often times, individuals using Python will utilize the power of additional libraries such as Pandas, Numpy, Matplotlib, Seaborn, Scikit-Learn etc. In the case of this project, though it would be helpful to utilize some of these libraries, I will focus on utilizing the generic "stock" Python language.
# - In my experience, it is good to rely on traditional Python every once in a while so one is not so dependent on the various libraries.

# %%
from csv import reader
opened_file_as = open('AppleStore.csv')
opened_file_gs = open('googleplaystore.csv')
read_file_as = reader(opened_file_as)
read_file_gs = reader(opened_file_gs)

#Dataset/Dataframe 
apple_store_data = list(read_file_as)
google_store_data = list(read_file_gs)

# %% [markdown]
# <h1> Function to Explore the Two Datasets </h1>
#
# My function will contain four parameters:
# 1. dataset - lists of lists
# 2. start and end - which are both expected to be integers and represents the starting and the ending indices of a slice from the data
# 3. rows_and_columns - which is a Boolean and has a False as the default argument
#
# Outside of the parameters, the specific code logic I will be using will be:
# 1. Slicing the dataset using dataset[start:end]
# 2. Loops through the slice, and for each iteration, prints a row and adds a new line after that using print('/n')
# 3. Prints the numbers of rows and columns if rows_and_columns is True

# %%
def explore_data(dataset, start, end, rows_and_column=False): 
    dataset_slice = dataset[start:end]
    for row in dataset_slice: 
        print(row)
        print('\n')
    if rows_and_column: 
        print('Number of rows:', len(dataset)) 
        print('Number of columns:', len(dataset[0]))

# %%
print(apple_store_data[0])
#For more descriptions on the column classifications, please visit 
# https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home#appleStore_description.csv
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %%
#These are the first five rows the apple store data including the header 
explore_data(apple_store_data,0,5,True)
# Out:
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# ['4', '282614216', 'eBay: Best App to Buy, Sell, Save! Online Shopping', '128512000', 'USD', '0', '262241', '649', '4', '4.5', '5.10.0', '12+', 'Shopping', '37', '5', '9', '1']
#
#
# Number of rows: 7198
# Number of columns: 17

# %%
print(google_store_data[0])
#For more description on the Google Play Store Apps Columns, please visit: 
#https://www.kaggle.com/lava18/google-play-store-apps/home
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
explore_data(google_store_data,0,5,True)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10842
# Number of columns: 13

# %% [markdown]
# <h3> Data Cleaning </h3>
#
# In the discussion sections of Kaggle, it is clearly evident that some of the data is filled with errors. For example, there is a problem with the row 10473 of the data. It is innacurate, and so I will not take this into account in my analysis

# %%
del google_store_data[10473]

# %% [markdown]
# <h3> Duplicate Values </h3>
#
# Checking for duplicate values. I will take a popular application name, and see if it contains duplicate. This will help me affirm whether or not I will have to further clean the data to remove duplicate values.

# %%
#Apple Store Data 
#Checking to see if the Apple Store Data might have duplicates for a popular app 
for apps in apple_store_data: 
    name = apps[2]
    if name == 'Facebook': 
        print(apps)
# Out:
# ['17', '284882215', 'Facebook', '389879808', 'USD', '0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']

# %%
#Apple Store Data Duplicate Count 
duplicate_values_as = [] 
unique_values_as = [] 

for apps in apple_store_data: 
    name = apps[2]
    if name in unique_values_as: 
        duplicate_values_as.append(name)
    else: 
        unique_values_as.append(name)

print('Number of Duplicate Applications:', len(duplicate_values_as))
print('\n')
print('Examples of Duplicate Applications:', duplicate_values_as[:20])
# Out:
# Number of Duplicate Applications: 2
#
#
# Examples of Duplicate Applications: ['VR Roller Coaster', 'Mannequin Challenge']

# %%
duplicate_apps_as = []
unique_apps_as = [] 

for app in apple_store_data: 
    name = app[2]
    
    if name in unique_apps_as: 
        duplicate_apps_as.append(app)
    else: 
        unique_apps_as.append(app)

# %%
duplicate_apps_as
# Out:
# []

# %%
duplicate_apple_store_apps = 2 
entire_apple_store_dataset = len(apple_store_data[1:])
new_target = entire_apple_store_dataset - duplicate_apple_store_apps
print(new_target)
# Out:
# 7195

# %%
apple_store_data
# Out:
# [['',
#   'id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic'],
#  ['1',
#   '281656475',
#   'PAC-MAN Premium',
#   '100788224',
#   'USD',
#   '3.99',
#   '21292',
#   '26',
#   '4',
#   '4.5',
#   '6.3.5',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '10',
#   '1'],
#  ['2',
#   '281796108',
#   'Evernote - stay organized',
#   '158578688',
#   'USD',
#   '0',
#   '161065',
#   '26',
#   '4',
#   '3.5',
#   '8.2.2',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '23',
#   '1'],
#  ['3',
#   '281940292',
#   'WeatherBug - Local Weather, Radar, Maps, Alerts',
#   '100524032',
#   'USD',
#   '0',
#   '188583',
#   '2822',
#   '3.5',
#   '4.5',
#   '5.0.0',
#   '4+',
#   'Weather',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['4',
#   '282614216',
#   'eBay: Best App to Buy, Sell, Save! Online Shopping',
#   '128512000',
#   'USD',
#   '0',
#   '262241',
#   '649',
#   '4',
#   '4.5',
#   '5.10.0',
#   '12+',
#   'Shopping',
#   '37',
#   '5',
#   '9',
#   '1'],
#  ['5',
#   '282935706',
#   'Bible',
#   '92774400',
#   'USD',
#   '0',
#   '985920',
#   '5320',
#   '4.5',
#   '5',
#   '7.5.1',
#   '4+',
#   'Reference',
#   '37',
#   '5',
#   '45',
#   '1'],
#  ['6',
#   '283619399',
#   'Shanghai Mahjong',
#   '10485713',
#   'USD',
#   '0.99',
#   '8253',
#   '5516',
#   '4',
#   '4',
#   '1.8',
#   '4+',
#   'Games',
#   '47',
#   '5',
#   '1',
#   '1'],
#  ['7',
#   '283646709',
#   'PayPal - Send and request money safely',
#   '227795968',
#   'USD',
#   '0',
#   '119487',
#   '879',
#   '4',
#   '4.5',
#   '6.12.0',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '19',
#   '1'],
#  ['8',
#   '284035177',
#   'Pandora - Music & Radio',
#   '130242560',
#   'USD',
#   '0',
#   '1126879',
#   '3594',
#   '4',
#   '4.5',
#   '8.4.1',
#   '12+',
#   'Music',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['9',
#   '284666222',
#   'PCalc - The Best Calculator',
#   '49250304',
#   'USD',
#   '9.99',
#   '1117',
#   '4',
#   '4.5',
#   '5',
#   '3.6.6',
#   '4+',
#   'Utilities',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['10',
#   '284736660',
#   'Ms. PAC-MAN',
#   '70023168',
#   'USD',
#   '3.99',
#   '7885',
#   '40',
#   '4',
#   '4',
#   '4.0.4',
#   '4+',
#   'Games',
#   '38',
#   '0',
#   '10',
#   '1'],
#  ['11',
#   '284791396',
#   'Solitaire by MobilityWare',
#   '49618944',
#   'USD',
#   '4.99',
#   '76720',
#   '4017',
#   '4.5',
#   '4.5',
#   '4.10.1',
#   '4+',
#   'Games',
#   '38',
#   '4',
#   '11',
#   '1'],
#  ['12',
#   '284815117',
#   'SCRABBLE Premium',
#   '227547136',
#   'USD',
#   '7.99',
#   '105776',
#   '166',
#   '3.5',
#   '2.5',
#   '5.19.0',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '6',
#   '1'],
#  ['13',
#   '284815942',
#   'Google – Search made just for mobile',
#   '179979264',
#   'USD',
#   '0',
#   '479440',
#   '203',
#   '3.5',
#   '4',
#   '27.0',
#   '17+',
#   'Utilities',
#   '37',
#   '4',
#   '33',
#   '1'],
#  ['14',
#   '284847138',
#   'Bank of America - Mobile Banking',
#   '160925696',
#   'USD',
#   '0',
#   '119773',
#   '2336',
#   '3.5',
#   '4.5',
#   '7.3.8',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['15',
#   '284862767',
#   'FreeCell',
#   '55153664',
#   'USD',
#   '4.99',
#   '6340',
#   '668',
#   '4.5',
#   '4.5',
#   '4.0.3',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '2',
#   '1'],
#  ['16',
#   '284876795',
#   'TripAdvisor Hotels Flights Restaurants',
#   '207907840',
#   'USD',
#   '0',
#   '56194',
#   '87',
#   '4',
#   '3.5',
#   '21.1',
#   '4+',
#   'Travel',
#   '37',
#   '1',
#   '26',
#   '1'],
#  ['17',
#   '284882215',
#   'Facebook',
#   '389879808',
#   'USD',
#   '0',
#   '2974676',
#   '212',
#   '3.5',
#   '3.5',
#   '95.0',
#   '4+',
#   'Social Networking',
#   '37',
#   '1',
#   '29',
#   '1'],
#  ['18',
#   '284910350',
#   'Yelp - Nearby Restaurants, Shopping & Services',
#   '167407616',
#   'USD',
#   '0',
#   '223885',
#   '3726',
#   '4',
#   '4.5',
#   '11.15.0',
#   '12+',
#   'Travel',
#   '37',
#   '5',
#   '18',
#   '1'],
#  ['20',
#   '284993459',
#   'Shazam - Discover music, artists, videos & lyrics',
#   '147093504',
#   'USD',
#   '0',
#   '402925',
#   '136',
#   '4',
#   '4.5',
#   '11.0.3',
#   '12+',
#   'Music',
#   '37',
#   '3',
#   '16',
#   '1'],
#  ['21',
#   '285005463',
#   'Crash Bandicoot Nitro Kart 3D',
#   '10735026',
#   'USD',
#   '2.99',
#   '31456',
#   '4178',
#   '4',
#   '3.5',
#   '1.0.0',
#   '4+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['22',
#   '285946052',
#   'iQuran',
#   '70707916',
#   'USD',
#   '1.99',
#   '2929',
#   '966',
#   '4.5',
#   '4.5',
#   '3.3',
#   '4+',
#   'Reference',
#   '43',
#   '0',
#   '2',
#   '1'],
#  ['23',
#   '285994151',
#   ':) Sudoku +',
#   '6169600',
#   'USD',
#   '2.99',
#   '11447',
#   '781',
#   '5',
#   '5',
#   '5.2.6',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['24',
#   '286058814',
#   'Yahoo Sports - Teams, Scores, News & Highlights',
#   '130583552',
#   'USD',
#   '0',
#   '137951',
#   '131',
#   '4',
#   '4.5',
#   '6.9',
#   '4+',
#   'Sports',
#   '37',
#   '2',
#   '6',
#   '1'],
#  ['25',
#   '286070473',
#   'Mileage Log | Fahrtenbuch',
#   '71203840',
#   'USD',
#   '5.99',
#   '8',
#   '0',
#   '4.5',
#   '0',
#   '9.0.5',
#   '4+',
#   'Business',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['27',
#   '286799607',
#   'Cleartune - Chromatic Tuner',
#   '11423008',
#   'USD',
#   '3.99',
#   '3241',
#   '297',
#   '4',
#   '4',
#   '2.1.3',
#   '4+',
#   'Music',
#   '43',
#   '2',
#   '10',
#   '1'],
#  ['28',
#   '286906691',
#   'Lifesum – Inspiring healthy lifestyle app',
#   '188017664',
#   'USD',
#   '0',
#   '5795',
#   '12',
#   '3.5',
#   '4',
#   '8.4.1',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '5',
#   '11',
#   '1'],
#  ['29',
#   '286911400',
#   'Hangman.',
#   '4765696',
#   'USD',
#   '0',
#   '42316',
#   '248',
#   '3',
#   '3.5',
#   '2.0.6',
#   '9+',
#   'Games',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['31',
#   '288113403',
#   'iTranslate - Language Translator & Dictionary',
#   '287933440',
#   'USD',
#   '0',
#   '123215',
#   '25',
#   '3.5',
#   '5',
#   '10.5.4',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '23',
#   '1'],
#  ['32',
#   '288120394',
#   'TouchOSC',
#   '4263936',
#   'USD',
#   '4.99',
#   '782',
#   '7',
#   '4',
#   '3.5',
#   '1.9.8',
#   '4+',
#   'Music',
#   '43',
#   '1',
#   '1',
#   '1'],
#  ['33',
#   '288419283',
#   'RadarScope',
#   '172772352',
#   'USD',
#   '9.99',
#   '3449',
#   '23',
#   '4',
#   '4.5',
#   '3.4.1',
#   '4+',
#   'Weather',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['34',
#   '288429040',
#   'LinkedIn',
#   '273844224',
#   'USD',
#   '0',
#   '71856',
#   '62',
#   '3.5',
#   '4.5',
#   '9.1.32',
#   '4+',
#   'Social Networking',
#   '37',
#   '2',
#   '23',
#   '1'],
#  ['35',
#   '289084315',
#   'Period Tracker Deluxe',
#   '40216576',
#   'USD',
#   '1.99',
#   '13350',
#   '489',
#   '4.5',
#   '5',
#   '9.6',
#   '12+',
#   'Health & Fitness',
#   '38',
#   '0',
#   '15',
#   '1'],
#  ['36',
#   '289446241',
#   'Election 2016 Map',
#   '2386944',
#   'USD',
#   '0.99',
#   '137',
#   '0',
#   '3',
#   '0',
#   '5.0',
#   '4+',
#   'Entertainment',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['37',
#   '289523017',
#   'Blackjack by MobilityWare',
#   '105431040',
#   'USD',
#   '0',
#   '180087',
#   '1101',
#   '3.5',
#   '4.5',
#   '5.5.3',
#   '12+',
#   'Games',
#   '37',
#   '5',
#   '5',
#   '1'],
#  ['39',
#   '289894882',
#   'White Noise',
#   '44129280',
#   'USD',
#   '0.99',
#   '33426',
#   '299',
#   '4',
#   '5',
#   '7.2',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['40',
#   '290638154',
#   'iHeartRadio – Free Music & Radio Stations',
#   '116443136',
#   'USD',
#   '0',
#   '293228',
#   '110',
#   '4',
#   '3',
#   '8.0.0',
#   '12+',
#   'Music',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['41',
#   '290807369',
#   'Line Rider iRide™',
#   '1646592',
#   'USD',
#   '1.99',
#   '21609',
#   '69',
#   '3.5',
#   '2.5',
#   '2.4',
#   '9+',
#   'Entertainment',
#   '40',
#   '0',
#   '1',
#   '1'],
#  ['42',
#   '290986013',
#   'Deliveries: a package tracker',
#   '30016512',
#   'USD',
#   '4.99',
#   '4684',
#   '10',
#   '4',
#   '4',
#   '8.0.3',
#   '4+',
#   'Utilities',
#   '37',
#   '4',
#   '9',
#   '1'],
#  ['43',
#   '291430598',
#   'Hurricane Pro',
#   '29518848',
#   'USD',
#   '2.99',
#   '2104',
#   '0',
#   '4.5',
#   '0',
#   '5.2',
#   '17+',
#   'Weather',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['47',
#   '292421271',
#   'Fieldrunners',
#   '66872320',
#   'USD',
#   '2.99',
#   '41633',
#   '6',
#   '4',
#   '3',
#   '1.7.177604',
#   '9+',
#   'Games',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['48',
#   '292628469',
#   'Juxtaposer',
#   '45229056',
#   'USD',
#   '2.99',
#   '3610',
#   '7',
#   '4.5',
#   '5',
#   '3.8.2',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['49',
#   '292738169',
#   'Deezer - Listen to your Favorite Music & Playlists',
#   '127470592',
#   'USD',
#   '0',
#   '4677',
#   '12',
#   '3',
#   '4',
#   '6.19.0',
#   '12+',
#   'Music',
#   '37',
#   '5',
#   '21',
#   '1'],
#  ['50',
#   '293118835',
#   'iStellar',
#   '44241920',
#   'USD',
#   '3.99',
#   '30',
#   '0',
#   '3.5',
#   '0',
#   '2.9.0',
#   '4+',
#   'Navigation',
#   '37',
#   '0',
#   '2',
#   '0'],
#  ['51',
#   '293523031',
#   'Sonos Controller',
#   '107983872',
#   'USD',
#   '0',
#   '48905',
#   '2691',
#   '4.5',
#   '4.5',
#   '7.2',
#   '4+',
#   'Music',
#   '37',
#   '4',
#   '12',
#   '1'],
#  ['52',
#   '293573778',
#   'Avertinoo',
#   '8044544',
#   'USD',
#   '4.99',
#   '32',
#   '0',
#   '3',
#   '0',
#   '3.9.2',
#   '4+',
#   'Navigation',
#   '38',
#   '5',
#   '7',
#   '1'],
#  ['53',
#   '293622097',
#   'Google Earth',
#   '37214208',
#   'USD',
#   '0',
#   '446185',
#   '1359',
#   '3.5',
#   '3.5',
#   '7.1.6',
#   '4+',
#   'Travel',
#   '43',
#   '5',
#   '30',
#   '1'],
#  ['54',
#   '293760823',
#   'iFart - The Original Fart Sounds App',
#   '60320768',
#   'USD',
#   '1.99',
#   '21825',
#   '10',
#   '3',
#   '4',
#   '4.0.8',
#   '9+',
#   'Entertainment',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['55',
#   '293778748',
#   'PAC-MAN',
#   '100849664',
#   'USD',
#   '0',
#   '508808',
#   '99',
#   '3',
#   '4.5',
#   '6.3.5',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '10',
#   '1'],
#  ['57',
#   '294056623',
#   'FOX Sports Mobile',
#   '72748032',
#   'USD',
#   '0',
#   '57500',
#   '103',
#   '3',
#   '4',
#   '3.5.13',
#   '4+',
#   'Sports',
#   '37',
#   '0',
#   '1',
#   '0'],
#  ['58',
#   '294536447',
#   'First Words Animals',
#   '32164864',
#   'USD',
#   '1.99',
#   '2576',
#   '4',
#   '4',
#   '5',
#   '7.0',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['59',
#   '294631159',
#   'WeatherPro',
#   '69079040',
#   'USD',
#   '1.99',
#   '1572',
#   '34',
#   '4',
#   '4.5',
#   '4.8.2',
#   '4+',
#   'Weather',
#   '37',
#   '0',
#   '13',
#   '1'],
#  ['60',
#   '294934058',
#   'HotSchedules',
#   '82037760',
#   'USD',
#   '2.99',
#   '3292',
#   '2',
#   '3',
#   '5',
#   '4.56.1',
#   '4+',
#   'Business',
#   '37',
#   '2',
#   '2',
#   '1'],
#  ['61',
#   '295430577',
#   'Star Walk - Find Stars And Planets in Sky Above',
#   '150195200',
#   'USD',
#   '4.99',
#   '8932',
#   '55',
#   '4.5',
#   '5',
#   '7.2.3',
#   '4+',
#   'Education',
#   '37',
#   '0',
#   '12',
#   '1'],
#  ['62',
#   '295646461',
#   'The Weather Channel: Forecast, Radar & Alerts',
#   '199734272',
#   'USD',
#   '0',
#   '495626',
#   '5893',
#   '3.5',
#   '4.5',
#   '8.11',
#   '4+',
#   'Weather',
#   '37',
#   '0',
#   '33',
#   '1'],
#  ['63',
#   '295759189',
#   'Big Day - Event Countdown',
#   '13156352',
#   'USD',
#   '0.99',
#   '812',
#   '14',
#   '3',
#   '4',
#   '8.2.0',
#   '4+',
#   'Lifestyle',
#   '38',
#   '0',
#   '7',
#   '1'],
#  ['64',
#   '295775656',
#   '12 Steps AA Companion - Alcoholics Anonymous',
#   '30367744',
#   'USD',
#   '2.99',
#   '1583',
#   '2',
#   '3.5',
#   '4.5',
#   '2.5.9.2',
#   '12+',
#   'Lifestyle',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['65',
#   '296581815',
#   'OpenTable - Restaurant Reservations',
#   '93420544',
#   'USD',
#   '0',
#   '113936',
#   '150',
#   '4.5',
#   '5',
#   '10.18.0',
#   '4+',
#   'Food & Drink',
#   '37',
#   '1',
#   '6',
#   '1'],
#  ['66',
#   '297244048',
#   'VLC Remote',
#   '31505408',
#   'USD',
#   '4.99',
#   '2027',
#   '2',
#   '4',
#   '5',
#   '9.30',
#   '4+',
#   'Entertainment',
#   '37',
#   '5',
#   '33',
#   '1'],
#  ['67',
#   '297332787',
#   'gFlashPro - Flashcards & Tests',
#   '25997312',
#   'USD',
#   '3.99',
#   '768',
#   '4',
#   '4',
#   '4',
#   '7.1',
#   '4+',
#   'Education',
#   '37',
#   '3',
#   '3',
#   '1'],
#  ['68',
#   '297368629',
#   'Lose It! – Weight Loss Program and Calorie Counter',
#   '182054912',
#   'USD',
#   '0',
#   '373835',
#   '402',
#   '4',
#   '4.5',
#   '8.0.2',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '3',
#   '1',
#   '1'],
#  ['69',
#   '297430070',
#   'Target',
#   '138754048',
#   'USD',
#   '0',
#   '108131',
#   '13',
#   '3',
#   '2',
#   '8.21.0',
#   '4+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['70',
#   '297606726',
#   'Fish Tycoon',
#   '13564835',
#   'USD',
#   '0.99',
#   '18943',
#   '1787',
#   '3.5',
#   '4.5',
#   '1.1.0',
#   '4+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['71',
#   '297606951',
#   'Amazon App: shop, scan, compare, and read reviews',
#   '133688320',
#   'USD',
#   '0',
#   '126312',
#   '22',
#   '3.5',
#   '3',
#   '9.10.0',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '8',
#   '1'],
#  ['72',
#   '297694601',
#   'Touchgrind',
#   '55205888',
#   'USD',
#   '4.99',
#   '35735',
#   '378',
#   '4',
#   '4.5',
#   '1.5.1',
#   '4+',
#   'Games',
#   '40',
#   '0',
#   '0',
#   '1'],
#  ['73',
#   '298127110',
#   'ProPresenter Remote',
#   '46922752',
#   'USD',
#   '4.99',
#   '410',
#   '7',
#   '3',
#   '2.5',
#   '4.8.1',
#   '4+',
#   'Utilities',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['74',
#   '298206806',
#   'iReal Pro - Music Book & Play Along',
#   '63283200',
#   'USD',
#   '12.99',
#   '1390',
#   '143',
#   '4.5',
#   '5',
#   '7.0.1',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '33',
#   '1'],
#  ['75',
#   '298596830',
#   'NRJ Radio',
#   '53426176',
#   'USD',
#   '0',
#   '38',
#   '2',
#   '3.5',
#   '5',
#   '5.2.6',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '4',
#   '1'],
#  ['76',
#   '298867247',
#   'Chase Mobile℠',
#   '39505920',
#   'USD',
#   '0',
#   '233270',
#   '14625',
#   '4.5',
#   '4.5',
#   '2.610',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['77',
#   '299029654',
#   '大辞林',
#   '210088960',
#   'USD',
#   '21.99',
#   '64',
#   '0',
#   '4.5',
#   '0',
#   '4.1.1',
#   '4+',
#   'Reference',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['79',
#   '299515267',
#   'Allrecipes Dinner Spinner',
#   '36399104',
#   'USD',
#   '0',
#   '109349',
#   '1540',
#   '3.5',
#   '5',
#   '6.3',
#   '12+',
#   'Food & Drink',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['80',
#   '299853944',
#   '新浪新闻-阅读最新时事热门头条资讯视频',
#   '115143680',
#   'USD',
#   '0',
#   '2229',
#   '4',
#   '3.5',
#   '1',
#   '6.2.1',
#   '17+',
#   'News',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['81',
#   '299949744',
#   'MotionX GPS',
#   '56481792',
#   'USD',
#   '1.99',
#   '14970',
#   '24',
#   '3.5',
#   '4.5',
#   '24.2',
#   '4+',
#   'Navigation',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['82',
#   '300048137',
#   'AccuWeather - Weather for Life',
#   '181941248',
#   'USD',
#   '0',
#   '144214',
#   '2162',
#   '3.5',
#   '4',
#   '10.4.1',
#   '4+',
#   'Weather',
#   '37',
#   '1',
#   '43',
#   '1'],
#  ['83',
#   '300238550',
#   'Mint: Personal Finance, Budget, Bills & Money',
#   '162891776',
#   'USD',
#   '0',
#   '232940',
#   '683',
#   '4',
#   '4.5',
#   '5.9.0',
#   '4+',
#   'Finance',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['84',
#   '300255638',
#   'ABC News - US & World News + Live Video',
#   '98108416',
#   'USD',
#   '0',
#   '48407',
#   '20',
#   '3',
#   '3.5',
#   '5.16',
#   '12+',
#   'News',
#   '37',
#   '0',
#   '1',
#   '0'],
#  ['85',
#   '300265786',
#   'Rowmote: Remote Control for Mac',
#   '54088704',
#   'USD',
#   '0.99',
#   '5531',
#   '37',
#   '3.5',
#   '2.5',
#   '4.3',
#   '4+',
#   'Utilities',
#   '40',
#   '3',
#   '13',
#   '1'],
#  ['86',
#   '300590611',
#   'Peekaboo Barn',
#   '50155520',
#   'USD',
#   '1.99',
#   '3393',
#   '77',
#   '4',
#   '4',
#   '5.1.0',
#   '4+',
#   'Education',
#   '43',
#   '5',
#   '1',
#   '1'],
#  ['87',
#   '300704847',
#   'Speedtest by Ookla',
#   '23936000',
#   'USD',
#   '0',
#   '65016',
#   '274',
#   '3.5',
#   '5',
#   '3.8.2',
#   '4+',
#   'Utilities',
#   '38',
#   '4',
#   '17',
#   '1'],
#  ['89',
#   '301387274',
#   'Pocket God',
#   '145293312',
#   'USD',
#   '0.99',
#   '187529',
#   '1071',
#   '4',
#   '4',
#   '1.48.2',
#   '9+',
#   'Entertainment',
#   '43',
#   '5',
#   '1',
#   '1'],
#  ['90',
#   '301521403',
#   'Nike+ Training Club - Workouts & Fitness Plans',
#   '140367872',
#   'USD',
#   '0',
#   '33969',
#   '466',
#   '3.5',
#   '5',
#   '5.4.1',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '17',
#   '1'],
#  ['91',
#   '301724680',
#   'Citi Mobile®',
#   '281244672',
#   'USD',
#   '0',
#   '48822',
#   '193',
#   '3.5',
#   '4',
#   '8.5.0',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['92',
#   '302049354',
#   'Phase 10 Pro - Play Your Friends!',
#   '66695168',
#   'USD',
#   '1.99',
#   '59155',
#   '101',
#   '4.5',
#   '2.5',
#   '3.2.0',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['93',
#   '302584613',
#   'Kindle – Read eBooks, Magazines & Textbooks',
#   '169747456',
#   'USD',
#   '0',
#   '252076',
#   '80',
#   '3.5',
#   '4.5',
#   '5.11',
#   '4+',
#   'Book',
#   '37',
#   '5',
#   '9',
#   '1'],
#  ['95',
#   '303058767',
#   'MASH',
#   '41691136',
#   'USD',
#   '1.99',
#   '4913',
#   '1',
#   '4',
#   '4',
#   '3.3.2',
#   '9+',
#   'Games',
#   '37',
#   '3',
#   '15',
#   '1'],
#  ['96',
#   '303191318',
#   '同花顺-炒股、股票',
#   '122886144',
#   'USD',
#   '0',
#   '1744',
#   '0',
#   '3.5',
#   '0',
#   '10.10.46',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['97',
#   '303337299',
#   'Wedding Dash Deluxe',
#   '55803904',
#   'USD',
#   '0.99',
#   '16567',
#   '1155',
#   '4.5',
#   '4.5',
#   '2.29.13',
#   '4+',
#   'Games',
#   '43',
#   '4',
#   '1',
#   '1'],
#  ['99',
#   '303849934',
#   'Beer Pong Game',
#   '188956672',
#   'USD',
#   '0',
#   '187315',
#   '9',
#   '2',
#   '4',
#   '17.05.15',
#   '17+',
#   'Games',
#   '37',
#   '5',
#   '9',
#   '1'],
#  ['100',
#   '304731501',
#   'Tempo - Metronome with Setlists',
#   '22185984',
#   'USD',
#   '2.99',
#   '4781',
#   '1',
#   '4.5',
#   '5',
#   '3.9.2',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '10',
#   '1'],
#  ['101',
#   '304770340',
#   'Skat',
#   '66160640',
#   'USD',
#   '3.99',
#   '94',
#   '4',
#   '4.5',
#   '4.5',
#   '11.0.10',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['102',
#   '304871603',
#   'Color Splash',
#   '28135424',
#   'USD',
#   '0.99',
#   '29554',
#   '55',
#   '4',
#   '5',
#   '3.6.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '0',
#   '3',
#   '1'],
#  ['103',
#   '304871622',
#   'Zombieville USA',
#   '27962441',
#   'USD',
#   '0.99',
#   '32988',
#   '2489',
#   '4',
#   '4',
#   '1.7',
#   '12+',
#   'Games',
#   '47',
#   '5',
#   '1',
#   '1'],
#  ['104',
#   '304878510',
#   'Skype for iPhone',
#   '133238784',
#   'USD',
#   '0',
#   '373519',
#   '127',
#   '3.5',
#   '4',
#   '6.35.1',
#   '4+',
#   'Social Networking',
#   '37',
#   '0',
#   '32',
#   '1'],
#  ['105',
#   '305343404',
#   'Tumblr',
#   '151573504',
#   'USD',
#   '0',
#   '334293',
#   '919',
#   '4',
#   '4',
#   '8.6',
#   '17+',
#   'Social Networking',
#   '37',
#   '5',
#   '16',
#   '1'],
#  ['106',
#   '305557780',
#   'iSwap Faces',
#   '27069440',
#   'USD',
#   '1.99',
#   '2302',
#   '3',
#   '3.5',
#   '5',
#   '5.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['107',
#   '305939712',
#   'Match™ - #1 Dating App.',
#   '101259264',
#   'USD',
#   '0',
#   '60659',
#   '57',
#   '3',
#   '2.5',
#   '17.05.01',
#   '17+',
#   'Social Networking',
#   '37',
#   '5',
#   '10',
#   '1'],
#  ['108',
#   '306169895',
#   "Tozzle - Toddler's favorite puzzle",
#   '168192000',
#   'USD',
#   '2.99',
#   '2562',
#   '10',
#   '4',
#   '4.5',
#   '5.1',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '4',
#   '1'],
#  ['109',
#   '306257910',
#   'HomeBudget with Sync',
#   '17485824',
#   'USD',
#   '4.99',
#   '3042',
#   '6',
#   '3.5',
#   '4',
#   '3.3.0',
#   '4+',
#   'Finance',
#   '37',
#   '5',
#   '11',
#   '1'],
#  ['110',
#   '306375551',
#   'Wind Meter',
#   '5234688',
#   'USD',
#   '0.99',
#   '338',
#   '12',
#   '2.5',
#   '2',
#   '5.0',
#   '4+',
#   'Weather',
#   '43',
#   '0',
#   '1',
#   '1'],
#  ['111',
#   '306468004',
#   'Map My Run+ - GPS Running & Workout Tracker',
#   '237913088',
#   'USD',
#   '2.99',
#   '16434',
#   '3',
#   '4.5',
#   '4.5',
#   '17.5.5',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '9',
#   '1'],
#  ['112',
#   '306561234',
#   'Map My Ride+ - GPS Cycling & Route Tracker',
#   '233513984',
#   'USD',
#   '2.99',
#   '10046',
#   '7',
#   '4.5',
#   '5',
#   '17.5.5',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '9',
#   '1'],
#  ['113',
#   '306621789',
#   'HuffPost - News, Politics & Entertainment',
#   '110420992',
#   'USD',
#   '0',
#   '29107',
#   '85',
#   '3',
#   '4',
#   '11.2',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '10',
#   '1'],
#  ['114',
#   '306628397',
#   'Phrase Party!',
#   '47774720',
#   'USD',
#   '1.99',
#   '878',
#   '48',
#   '4',
#   '4.5',
#   '8.7.5',
#   '17+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['115',
#   '306937053',
#   'Minesweeper Classic',
#   '22259712',
#   'USD',
#   '0.99',
#   '1140',
#   '20',
#   '3.5',
#   '3.5',
#   '3.6',
#   '4+',
#   'Games',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['116',
#   '307132353',
#   "Sally's Spa",
#   '431771648',
#   'USD',
#   '2.99',
#   '35074',
#   '403',
#   '4.5',
#   '4',
#   '3.3.0',
#   '4+',
#   'Games',
#   '43',
#   '0',
#   '6',
#   '1'],
#  ['117',
#   '307184892',
#   'CBS Sports App - Sports Scores, News, Stats, Watch',
#   '120357888',
#   'USD',
#   '0',
#   '59639',
#   '11',
#   '3',
#   '2.5',
#   '10.2.2',
#   '17+',
#   'Sports',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['118',
#   '307219387',
#   'Brain Wave ™ - 32 Advanced Binaural Brainwave Entrainment Programs with iTunes Music and Relaxing Ambience',
#   '90828800',
#   'USD',
#   '4.99',
#   '2913',
#   '357',
#   '4',
#   '5',
#   '7.4',
#   '4+',
#   'Health & Fitness',
#   '43',
#   '5',
#   '1',
#   '1'],
#  ['119',
#   '307354030',
#   'iSwap Faces LITE',
#   '30796800',
#   'USD',
#   '0',
#   '39722',
#   '0',
#   '3',
#   '0',
#   '5.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['120',
#   '307386350',
#   'DIRECTV',
#   '151397376',
#   'USD',
#   '0',
#   '81006',
#   '25',
#   '3.5',
#   '3',
#   '4.9.705',
#   '4+',
#   'Entertainment',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['121',
#   '307569751',
#   'NYTimes Crossword - Daily Word Puzzle Game',
#   '46880768',
#   'USD',
#   '0',
#   '53465',
#   '204',
#   '3.5',
#   '4',
#   '2.8.1',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['122',
#   '307727765',
#   'Doodle Jump',
#   '48741376',
#   'USD',
#   '0.99',
#   '395261',
#   '88',
#   '4.5',
#   '4.5',
#   '3.17.6',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['123',
#   '307741537',
#   'LEDit – The LED Banner App',
#   '17145856',
#   'USD',
#   '1.99',
#   '2021',
#   '147',
#   '4.5',
#   '4.5',
#   '3.5.1',
#   '4+',
#   'Utilities',
#   '37',
#   '4',
#   '12',
#   '1'],
#  ['124',
#   '307764057',
#   'niconico',
#   '25808896',
#   'USD',
#   '0',
#   '182',
#   '0',
#   '3',
#   '0',
#   '6.52',
#   '17+',
#   'Entertainment',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['125',
#   '307906541',
#   'Fandango Movies - Times + Tickets',
#   '81924096',
#   'USD',
#   '0',
#   '291787',
#   '589',
#   '4',
#   '5',
#   '8.6',
#   '4+',
#   'Entertainment',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['126',
#   '308111628',
#   'iCab Mobile (Web Browser)',
#   '19451904',
#   'USD',
#   '1.99',
#   '2441',
#   '4',
#   '4',
#   '5',
#   '9.9',
#   '17+',
#   'Utilities',
#   '38',
#   '4',
#   '12',
#   '1'],
#  ['128',
#   '308339980',
#   'iRagdoll - Ragdoll Physics',
#   '118683648',
#   'USD',
#   '0.99',
#   '1372',
#   '25',
#   '4',
#   '4',
#   '1.8.3',
#   '12+',
#   'Games',
#   '37',
#   '2',
#   '1',
#   '1'],
#  ['129',
#   '308368164',
#   'Proloquo2Go - Symbol-based AAC',
#   '723764224',
#   'USD',
#   '249.99',
#   '773',
#   '10',
#   '4',
#   '3.5',
#   '5.0.1',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['130',
#   '308750436',
#   'Dictionary.com Dictionary & Thesaurus',
#   '111275008',
#   'USD',
#   '0',
#   '200047',
#   '177',
#   '4',
#   '4',
#   '7.1.3',
#   '4+',
#   'Reference',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['132',
#   '308834491',
#   "20 Minutes.fr - l'actualité en continu",
#   '109616128',
#   'USD',
#   '0',
#   '112',
#   '0',
#   '3.5',
#   '0',
#   '5.0.11',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '17',
#   '1'],
#  ['133',
#   '309025938',
#   'The Masters Tournament',
#   '120725504',
#   'USD',
#   '0',
#   '148160',
#   '63',
#   '4.5',
#   '3.5',
#   '9.0.701',
#   '4+',
#   'Sports',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['134',
#   '309172177',
#   'myAT&T',
#   '68491264',
#   'USD',
#   '0',
#   '108507',
#   '628',
#   '3',
#   '3',
#   '5.3',
#   '4+',
#   'Utilities',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['135',
#   '309187846',
#   'SFR TV',
#   '122153984',
#   'USD',
#   '0',
#   '46',
#   '0',
#   '3',
#   '0',
#   '7.3.0',
#   '4+',
#   'Entertainment',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['136',
#   '309465525',
#   'Shutterfly: Prints, Photo Books, Cards Made Easy',
#   '122315776',
#   'USD',
#   '0',
#   '51427',
#   '874',
#   '4',
#   '5',
#   '7.7.0',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['137',
#   '309527804',
#   'StickWars',
#   '17010688',
#   'USD',
#   '0.99',
#   '53821',
#   '165',
#   '3.5',
#   '4',
#   '1.8.9',
#   '12+',
#   'Games',
#   '43',
#   '1',
#   '1',
#   '0'],
#  ['138',
#   '309735670',
#   'Indeed Job Search',
#   '3691520',
#   'USD',
#   '0',
#   '38681',
#   '563',
#   '4',
#   '4.5',
#   '4.3',
#   '4+',
#   'Business',
#   '37',
#   '3',
#   '28',
#   '1'],
#  ['139',
#   '310303959',
#   'World Cup Table Tennis™',
#   '31387648',
#   'USD',
#   '0.99',
#   '17776',
#   '6',
#   '4',
#   '5',
#   '4.6.1',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '11',
#   '1'],
#  ['140',
#   '310633997',
#   'WhatsApp Messenger',
#   '135044096',
#   'USD',
#   '0',
#   '287589',
#   '73088',
#   '4.5',
#   '4.5',
#   '2.17.22',
#   '4+',
#   'Social Networking',
#   '12',
#   '0',
#   '35',
#   '1'],
#  ['141',
#   '310636441',
#   'iStudiez Pro – Homework, Schedule, Grades',
#   '55815168',
#   'USD',
#   '2.99',
#   '7308',
#   '15',
#   '4',
#   '4.5',
#   '1.9.1',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '30',
#   '1'],
#  ['142',
#   '310738695',
#   'Zillow Real Estate - Homes for Sale & for Rent',
#   '132632576',
#   'USD',
#   '0',
#   '342969',
#   '88478',
#   '4.5',
#   '4.5',
#   '10.4.5',
#   '4+',
#   'Lifestyle',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['144',
#   '310951782',
#   '2XL Supercross',
#   '270729216',
#   'USD',
#   '4.99',
#   '6093',
#   '3',
#   '4',
#   '5',
#   '1.2.1',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '7',
#   '1'],
#  ['146',
#   '311466554',
#   'Pocket Tanks Deluxe',
#   '39827456',
#   'USD',
#   '4.99',
#   '5452',
#   '39',
#   '4.5',
#   '4.5',
#   '2.3.1',
#   '9+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['148',
#   '311548709',
#   'Wells Fargo Mobile',
#   '57328640',
#   'USD',
#   '0',
#   '43064',
#   '216',
#   '3',
#   '2.5',
#   '3.55',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['150',
#   '311762416',
#   'radio.de - Der Radioplayer',
#   '40717312',
#   'USD',
#   '0',
#   '64',
#   '9',
#   '4.5',
#   '5',
#   '4.0.5',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '14',
#   '1'],
#  ['151',
#   '311785642',
#   'AutoScout24 - mobile used & new car market',
#   '141136896',
#   'USD',
#   '0',
#   '220',
#   '2',
#   '4.5',
#   '5',
#   '9.1.10',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '13',
#   '1'],
#  ['152',
#   '311972587',
#   'Sky Burger - Build & Match Food Free',
#   '146228224',
#   'USD',
#   '0',
#   '114096',
#   '2157',
#   '4.5',
#   '4',
#   '3.0.3',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['153',
#   '312220102',
#   'MindNode – Delightful Mind Mapping',
#   '52294656',
#   'USD',
#   '9.99',
#   '1296',
#   '4',
#   '4',
#   '5',
#   '4.5.3',
#   '4+',
#   'Productivity',
#   '37',
#   '4',
#   '13',
#   '1'],
#  ['154',
#   '312266675',
#   'Packing Pro',
#   '16332800',
#   'USD',
#   '2.99',
#   '1293',
#   '31',
#   '4',
#   '5',
#   '12.2',
#   '4+',
#   'Travel',
#   '37',
#   '5',
#   '11',
#   '1'],
#  ['155',
#   '312325565',
#   'USAA Mobile',
#   '164382720',
#   'USD',
#   '0',
#   '19946',
#   '13',
#   '4',
#   '2.5',
#   '7.32.3',
#   '4+',
#   'Finance',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['156',
#   '312343159',
#   'The Moron Test',
#   '45712384',
#   'USD',
#   '0',
#   '88613',
#   '392',
#   '4',
#   '4.5',
#   '6.3.1',
#   '4+',
#   'Entertainment',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['157',
#   '313199385',
#   'Sunday Lawn',
#   '16086016',
#   'USD',
#   '0.99',
#   '107727',
#   '55',
#   '3.5',
#   '4.5',
#   '1.41.1',
#   '4+',
#   'Games',
#   '37',
#   '3',
#   '1',
#   '1'],
#  ['158',
#   '314303518',
#   'Peggle Classic',
#   '223805440',
#   'USD',
#   '0.99',
#   '21416',
#   '974',
#   '4.5',
#   '4.5',
#   '1.7.2',
#   '4+',
#   'Games',
#   '43',
#   '0',
#   '5',
#   '1'],
#  ['159',
#   '314506629',
#   'SmartGo Player',
#   '22159360',
#   'USD',
#   '2.99',
#   '533',
#   '27',
#   '4',
#   '4',
#   '2.5.1',
#   '4+',
#   'Games',
#   '37',
#   '3',
#   '9',
#   '1'],
#  ['160',
#   '314652382',
#   'I Am T-Pain 2.0',
#   '20542280',
#   'USD',
#   '2.99',
#   '32650',
#   '754',
#   '3.5',
#   '3.5',
#   '2.0.4',
#   '12+',
#   'Music',
#   '43',
#   '1',
#   '1',
#   '1'],
#  ['161',
#   '314716233',
#   'TextNow - Unlimited Text + Calls',
#   '130637824',
#   'USD',
#   '0',
#   '164963',
#   '69',
#   '3.5',
#   '4',
#   '8.5.1',
#   '4+',
#   'Social Networking',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['162',
#   '314819528',
#   'Boating Weather',
#   '8900608',
#   'USD',
#   '1.99',
#   '141',
#   '15',
#   '3',
#   '3',
#   '4.5',
#   '4+',
#   'Weather',
#   '40',
#   '0',
#   '1',
#   '1'],
#  ['163',
#   '314855255',
#   'Best Buy',
#   '180500480',
#   'USD',
#   '0',
#   '80424',
#   '46',
#   '4',
#   '4.5',
#   '10.11.0',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['164',
#   '314864297',
#   'I Dig It',
#   '19853312',
#   'USD',
#   '0.99',
#   '17190',
#   '180',
#   '4',
#   '4.5',
#   '1.12',
#   '4+',
#   'Games',
#   '40',
#   '0',
#   '1',
#   '1'],
#  ['165',
#   '315021242',
#   'Unblock Me',
#   '42926080',
#   'USD',
#   '0.99',
#   '7973',
#   '127',
#   '4',
#   '5',
#   '1.5.95',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '15',
#   '1'],
#  ['166',
#   '316025912',
#   'Sonic The Hedgehog',
#   '36692992',
#   'USD',
#   '2.99',
#   '19621',
#   '1191',
#   '4',
#   '4.5',
#   '2.1.2',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['168',
#   '316227296',
#   '10 Pin Shuffle Pro Bowling',
#   '36647936',
#   'USD',
#   '3.99',
#   '7315',
#   '138',
#   '4',
#   '4.5',
#   '2.01',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '6',
#   '1'],
#  ['169',
#   '316391924',
#   'Sky News',
#   '91697152',
#   'USD',
#   '0',
#   '118',
#   '0',
#   '3',
#   '0',
#   '4.6',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['171',
#   '317469184',
#   'ESPN: Get scores, news, alerts & watch live sports',
#   '51538944',
#   'USD',
#   '0',
#   '290996',
#   '150',
#   '3.5',
#   '3.5',
#   '5.7.1',
#   '4+',
#   'Sports',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['172',
#   '317809458',
#   'LiveATC Air Radio',
#   '8302592',
#   'USD',
#   '3.99',
#   '2785',
#   '90',
#   '4',
#   '4',
#   '1.9.0',
#   '4+',
#   'Travel',
#   '37',
#   '5',
#   '26',
#   '1'],
#  ['173',
#   '317904170',
#   'The Sims 3',
#   '430128128',
#   'USD',
#   '6.99',
#   '54408',
#   '65',
#   '3.5',
#   '2',
#   '1.4.10',
#   '12+',
#   'Games',
#   '37',
#   '5',
#   '8',
#   '1'],
#  ['175',
#   '318304532',
#   'Chess Pro with Coach - Learn,Play & Online Friends',
#   '69960704',
#   'USD',
#   '9.99',
#   '8138',
#   '107',
#   '4',
#   '4.5',
#   '2.89',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '13',
#   '1'],
#  ['176',
#   '318592730',
#   'Guess My Age \ue020 Math Magic',
#   '767126',
#   'USD',
#   '0',
#   '123190',
#   '68841',
#   '3',
#   '3',
#   '1.1',
#   '4+',
#   'Education',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['177',
#   '318639200',
#   'Crush the Castle',
#   '12996628',
#   'USD',
#   '0.99',
#   '23810',
#   '582',
#   '3.5',
#   '4',
#   '1.5',
#   '12+',
#   'Games',
#   '45',
#   '0',
#   '1',
#   '1'],
#  ['178',
#   '319204550',
#   '2016 U.S. Open Golf Championship',
#   '139545600',
#   'USD',
#   '0',
#   '54192',
#   '32',
#   '4',
#   '2',
#   '8.0.263',
#   '4+',
#   'Sports',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['179',
#   '319284643',
#   'The Championships, Wimbledon 2016 - Tennis Grand Slam',
#   '130394112',
#   'USD',
#   '0',
#   '20953',
#   '481',
#   '4',
#   '4',
#   '8.1',
#   '4+',
#   'Sports',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['180',
#   '319295332',
#   'TuneIn Radio Pro - MLB Audiobooks Podcasts Music',
#   '101925888',
#   'USD',
#   '9.99',
#   '71609',
#   '99',
#   '4.5',
#   '4',
#   '11.9',
#   '12+',
#   'Music',
#   '37',
#   '4',
#   '14',
#   '1'],
#  ['181',
#   '319740707',
#   'NBC News',
#   '52951040',
#   'USD',
#   '0',
#   '32881',
#   '7',
#   '3.5',
#   '2',
#   '5.11.0',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['182',
#   '319881193',
#   'Grindr - Gay and same sex guys chat, meet and date',
#   '80409600',
#   'USD',
#   '0',
#   '23201',
#   '14',
#   '2.5',
#   '2',
#   '3.9.1',
#   '17+',
#   'Social Networking',
#   '37',
#   '5',
#   '5',
#   '1'],
#  ['183',
#   '320029256',
#   'Whole Foods Market',
#   '137312256',
#   'USD',
#   '0',
#   '17906',
#   '4',
#   '3',
#   '3',
#   '8.3.17',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['184',
#   '320279293',
#   'NAVIGON Europe',
#   '144412672',
#   'USD',
#   '74.99',
#   '927',
#   '3',
#   '3.5',
#   '2.5',
#   '2.17',
#   '4+',
#   'Navigation',
#   '37',
#   '2',
#   '21',
#   '1'],
#  ['185',
#   '320300350',
#   'Virtual Families',
#   '27746273',
#   'USD',
#   '1.99',
#   '18920',
#   '3014',
#   '3.5',
#   '4.5',
#   '1.1.2',
#   '9+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['186',
#   '320596872',
#   'Sparkasse+',
#   '119648256',
#   'USD',
#   '0.99',
#   '30',
#   '0',
#   '3',
#   '0',
#   '3.1.3',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '3',
#   '1'],
#  ['187',
#   '320599923',
#   'Sparkasse - Your mobile branch',
#   '119574528',
#   'USD',
#   '0',
#   '77',
#   '1',
#   '3',
#   '4',
#   '3.1.3',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '3',
#   '1'],
#  ['188',
#   '320606217',
#   'Sleep Cycle alarm clock',
#   '79315968',
#   'USD',
#   '0',
#   '104539',
#   '11',
#   '4.5',
#   '4.5',
#   '5.4.1',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '5',
#   '13',
#   '1'],
#  ['189',
#   '320636131',
#   'FACEinHOLE®',
#   '12818432',
#   'USD',
#   '0.99',
#   '4016',
#   '1',
#   '4',
#   '5',
#   '5.7',
#   '12+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['190',
#   '320650307',
#   'Harvest - Select the Best Produce',
#   '18165760',
#   'USD',
#   '1.99',
#   '299',
#   '28',
#   '4',
#   '4.5',
#   '3.1',
#   '4+',
#   'Food & Drink',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['191',
#   '321369231',
#   'WORMS',
#   '253834240',
#   'USD',
#   '1.99',
#   '5758',
#   '9',
#   '4',
#   '3',
#   '2.6',
#   '12+',
#   'Games',
#   '40',
#   '0',
#   '1',
#   '1'],
#  ['192',
#   '321756558',
#   'Pixel Starships™ : 8Bit MMORPG',
#   '69083136',
#   'USD',
#   '0',
#   '5565',
#   '140',
#   '4.5',
#   '4.5',
#   '0.39',
#   '9+',
#   'Games',
#   '37',
#   '5',
#   '17',
#   '1'],
#  ['193',
#   '322423174',
#   'Traffic Rush',
#   '8573952',
#   'USD',
#   '0.99',
#   '213092',
#   '51',
#   '3.5',
#   '4.5',
#   '1.45.1',
#   '9+',
#   'Games',
#   '37',
#   '3',
#   '1',
#   '1'],
#  ['194',
#   '322439990',
#   'MyRadar NOAA Weather Radar Forecast',
#   '127284224',
#   'USD',
#   '0',
#   '150158',
#   '3392',
#   '4.5',
#   '5',
#   '5.1.4',
#   '4+',
#   'Weather',
#   '37',
#   '2',
#   '8',
#   '1'],
#  ['196',
#   '322523436',
#   'Resident Evil 4: PLATINUM',
#   '81374398',
#   'USD',
#   '4.99',
#   '6046',
#   '446',
#   '4',
#   '4',
#   '1.04.10',
#   '12+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['197',
#   '323229106',
#   'Waze - GPS Navigation, Maps & Real-time Traffic',
#   '94139392',
#   'USD',
#   '0',
#   '345046',
#   '3040',
#   '4.5',
#   '4.5',
#   '4.24',
#   '4+',
#   'Navigation',
#   '37',
#   '5',
#   '36',
#   '1'],
#  ['198',
#   '323242790',
#   'Cartoon Wars',
#   '13216994',
#   'USD',
#   '0.99',
#   '35930',
#   '262',
#   '3.5',
#   '4',
#   '114',
#   '12+',
#   'Games',
#   '43',
#   '0',
#   '1',
#   '1'],
#  ['199',
#   '323438913',
#   'Moto X Mayhem',
#   '21010210',
#   'USD',
#   '0.99',
#   '22557',
#   '526',
#   '4',
#   '4',
#   '1.8.7',
#   '4+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['200',
#   '324266640',
#   'Fantasy Football Manager - FFM for FPL',
#   '35998720',
#   'USD',
#   '0.99',
#   '292',
#   '1',
#   '3',
#   '5',
#   '9.3',
#   '17+',
#   'Sports',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['202',
#   '324684580',
#   'Spotify Music',
#   '132510720',
#   'USD',
#   '0',
#   '878563',
#   '8253',
#   '4.5',
#   '4.5',
#   '8.4.3',
#   '12+',
#   'Music',
#   '37',
#   '5',
#   '18',
#   '1'],
#  ['203',
#   '324887734',
#   'McDo France',
#   '37001216',
#   'USD',
#   '0',
#   '22',
#   '0',
#   '3.5',
#   '0',
#   '4.0.16',
#   '4+',
#   'Food & Drink',
#   '37',
#   '0',
#   '30',
#   '1'],
#  ['204',
#   '325462190',
#   'PGA Championship 2016 – Baltusrol Golf Club',
#   '64147456',
#   'USD',
#   '0',
#   '10472',
#   '58',
#   '3.5',
#   '2',
#   '8.1',
#   '17+',
#   'Sports',
#   '37',
#   '5',
#   '1',
#   '0'],
#  ['206',
#   '325658560',
#   "BFMTV : l'info en continu",
#   '100779008',
#   'USD',
#   '0',
#   '115',
#   '70',
#   '4',
#   '5',
#   '5.0.3',
#   '17+',
#   'News',
#   '37',
#   '4',
#   '1',
#   '0'],
#  ['207',
#   '325683306',
#   'MyRadar Pro NOAA Weather Radar, Forecasts & Storms',
#   '123718656',
#   'USD',
#   '1.99',
#   '13915',
#   '205',
#   '4.5',
#   '5',
#   '5.1.4',
#   '4+',
#   'Weather',
#   '37',
#   '2',
#   '8',
#   '1'],
#  ['208',
#   '325954996',
#   'Spider:  The Secret of Bryce Manor',
#   '126312448',
#   'USD',
#   '1.99',
#   '6780',
#   '68',
#   '4',
#   '4.5',
#   '1.5',
#   '9+',
#   'Games',
#   '38',
#   '0',
#   '5',
#   '1'],
#  ['209',
#   '325962257',
#   'My Measures PRO',
#   '79882240',
#   'USD',
#   '7.99',
#   '1701',
#   '35',
#   '4',
#   '4.5',
#   '6.06',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '21',
#   '1'],
#  ['210',
#   '326082487',
#   'Food Additives Checker (E Numbers)',
#   '6418432',
#   'USD',
#   '1.99',
#   '6',
#   '0',
#   '3.5',
#   '0',
#   '4.1.2',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '8',
#   '1'],
#  ['212',
#   '326161564',
#   'SFR Mon Compte',
#   '74093568',
#   'USD',
#   '0',
#   '19',
#   '0',
#   '3',
#   '0',
#   '6.4.0',
#   '4+',
#   'Utilities',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['213',
#   '326574411',
#   'Baby Connect (Activity Log)',
#   '12937216',
#   'USD',
#   '4.99',
#   '3483',
#   '79',
#   '4.5',
#   '5',
#   '5.4.3',
#   '4+',
#   'Medical',
#   '37',
#   '0',
#   '14',
#   '1'],
#  ['214',
#   '326876192',
#   'Epson iPrint',
#   '53388288',
#   'USD',
#   '0',
#   '2838',
#   '26',
#   '3',
#   '2.5',
#   '6.3.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '12',
#   '1'],
#  ['215',
#   '326885152',
#   'Mad Libs',
#   '118498304',
#   'USD',
#   '0',
#   '117889',
#   '725',
#   '3',
#   '4.5',
#   '3.3.3',
#   '4+',
#   'Entertainment',
#   '38',
#   '1',
#   '1',
#   '1'],
#  ['217',
#   '326979430',
#   'BATTLE BEARS: Zombies!',
#   '103197675',
#   'USD',
#   '0.99',
#   '50710',
#   '309',
#   '3.5',
#   '4',
#   '1.6.7',
#   '9+',
#   'Games',
#   '45',
#   '0',
#   '1',
#   '1'],
#  ['219',
#   '327193945',
#   'Hurricane Tracker',
#   '24574976',
#   'USD',
#   '2.99',
#   '3960',
#   '0',
#   '4.5',
#   '0',
#   '5.0',
#   '4+',
#   'Weather',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['220',
#   '327243363',
#   'NFL Sunday Ticket',
#   '96093184',
#   'USD',
#   '0',
#   '24258',
#   '305',
#   '3',
#   '2.5',
#   '2.6.042',
#   '4+',
#   'Entertainment',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['221',
#   '327455869',
#   '2016 US Open Tennis Championships',
#   '77700096',
#   'USD',
#   '0',
#   '37522',
#   '39',
#   '4',
#   '3',
#   '8.0.353',
#   '4+',
#   'Sports',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['222',
#   '327630330',
#   'Dropbox',
#   '180804608',
#   'USD',
#   '0',
#   '49578',
#   '16',
#   '3.5',
#   '3',
#   '50.2',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '20',
#   '1'],
#  ['223',
#   '328011357',
#   'Wa Kingyo - Goldfish Pond',
#   '56397824',
#   'USD',
#   '0.99',
#   '626',
#   '44',
#   '4',
#   '5',
#   '2.0.3',
#   '4+',
#   'Entertainment',
#   '38',
#   '5',
#   '2',
#   '1'],
#  ['224',
#   '328205875',
#   'Monkey Preschool Lunchbox',
#   '229272576',
#   'USD',
#   '1.99',
#   '9286',
#   '49',
#   '4',
#   '3.5',
#   '4.02',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['225',
#   '328415391',
#   'Yahoo Fantasy Sports',
#   '131000320',
#   'USD',
#   '0',
#   '190670',
#   '19',
#   '3.5',
#   '2.5',
#   '9.1.0',
#   '17+',
#   'Sports',
#   '37',
#   '3',
#   '45',
#   '1'],
#  ['226',
#   '329127297',
#   'Gaia GPS Classic',
#   '53097472',
#   'USD',
#   '19.99',
#   '2429',
#   '8',
#   '4.5',
#   '3.5',
#   '10.9.13',
#   '4+',
#   'Navigation',
#   '37',
#   '5',
#   '16',
#   '1'],
#  ['227',
#   '329174056',
#   'iLoan Calc (Loan calculator)',
#   '3375104',
#   'USD',
#   '3.99',
#   '0',
#   '0',
#   '0',
#   '0',
#   '5.1.0',
#   '4+',
#   'Finance',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['228',
#   '329541503',
#   'Geocaching®',
#   '108166144',
#   'USD',
#   '0',
#   '12811',
#   '134',
#   '3.5',
#   '1.5',
#   '5.3',
#   '4+',
#   'Navigation',
#   '37',
#   '0',
#   '22',
#   '1'],
#  ['229',
#   '329670577',
#   'Camera+',
#   '89187328',
#   'USD',
#   '1.99',
#   '32338',
#   '261',
#   '4',
#   '4.5',
#   '9.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '0',
#   '10',
#   '1'],
#  ['230',
#   '329703516',
#   'Alter Ego',
#   '13647872',
#   'USD',
#   '4.99',
#   '262',
#   '43',
#   '4',
#   '4',
#   '1.3.0',
#   '12+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['231',
#   '329887910',
#   'Parking Mania',
#   '123544576',
#   'USD',
#   '0.99',
#   '9657',
#   '47',
#   '4.5',
#   '4.5',
#   '2.5.0',
#   '4+',
#   'Games',
#   '38',
#   '0',
#   '12',
#   '1'],
#  ['232',
#   '329981776',
#   'Sudoku⁺',
#   '1608704',
#   'USD',
#   '2.99',
#   '18332',
#   '1007',
#   '4.5',
#   '5',
#   '3.4',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['234',
#   '330376830',
#   'Period Tracker Lite',
#   '50169856',
#   'USD',
#   '0',
#   '53620',
#   '2872',
#   '4',
#   '5',
#   '9.5.1',
#   '12+',
#   'Health & Fitness',
#   '38',
#   '0',
#   '15',
#   '1'],
#  ['235',
#   '330803072',
#   'Camera Plus: For Macro Photos & Remote Photography',
#   '101181440',
#   'USD',
#   '0.99',
#   '38533',
#   '36',
#   '2.5',
#   '3.5',
#   '4.5.4',
#   '4+',
#   'Photo & Video',
#   '37',
#   '4',
#   '11',
#   '1'],
#  ['236',
#   '331004675',
#   'The perfect Egg timer',
#   '15329280',
#   'USD',
#   '0.99',
#   '40',
#   '0',
#   '3.5',
#   '0',
#   '1.8.9',
#   '4+',
#   'Food & Drink',
#   '37',
#   '4',
#   '7',
#   '1'],
#  ['237',
#   '331177703',
#   'Letter Quiz - alphabet tracing for kids',
#   '31845376',
#   'USD',
#   '1.99',
#   '472',
#   '0',
#   '4',
#   '0',
#   '2.4',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['238',
#   '331177714',
#   'Starbucks',
#   '135032832',
#   'USD',
#   '0',
#   '303856',
#   '7027',
#   '4.5',
#   '4.5',
#   '4.3.5',
#   '4+',
#   'Food & Drink',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['239',
#   '331259725',
#   '央视影音-海量央视内容高清直播',
#   '54648832',
#   'USD',
#   '0',
#   '2070',
#   '0',
#   '2.5',
#   '0',
#   '6.2.0',
#   '4+',
#   'Sports',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['240',
#   '331271904',
#   'Bloons TD',
#   '8432232',
#   'USD',
#   '2.99',
#   '7941',
#   '76',
#   '4',
#   '3.5',
#   '1.2.1',
#   '4+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['241',
#   '331308914',
#   'Weight Watchers',
#   '230720512',
#   'USD',
#   '0',
#   '136833',
#   '64',
#   '3.5',
#   '4.5',
#   '5.9.0',
#   '12+',
#   'Health & Fitness',
#   '37',
#   '5',
#   '6',
#   '1'],
#  ['242',
#   '331786748',
#   'CNN: Breaking US & World News, Live Video',
#   '80211968',
#   'USD',
#   '0',
#   '112886',
#   '298',
#   '3.5',
#   '1.5',
#   '5.3',
#   '12+',
#   'News',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['243',
#   '331804452',
#   'Gilt',
#   '148201472',
#   'USD',
#   '0',
#   '26353',
#   '3',
#   '3.5',
#   '2.5',
#   '5.1.3',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['245',
#   '332568551',
#   'TRUTH or DARE!!! - FREE',
#   '20795392',
#   'USD',
#   '0',
#   '171055',
#   '31',
#   '3',
#   '3.5',
#   '5',
#   '12+',
#   'Entertainment',
#   '38',
#   '1',
#   '1',
#   '1'],
#  ['246',
#   '333180061',
#   'Canabalt',
#   '27934720',
#   'USD',
#   '2.99',
#   '4540',
#   '140',
#   '4',
#   '4.5',
#   '2.31',
#   '9+',
#   'Games',
#   '43',
#   '5',
#   '15',
#   '1'],
#  ['247',
#   '333206289',
#   'Alipay - Makes Life Easy',
#   '208309248',
#   'USD',
#   '0',
#   '1926',
#   '2',
#   '3',
#   '3',
#   '10.0.15',
#   '4+',
#   'Lifestyle',
#   '38',
#   '5',
#   '3',
#   '1'],
#  ['248',
#   '333246187',
#   'Scanner911 Pro',
#   '33812480',
#   'USD',
#   '3.99',
#   '14345',
#   '100',
#   '4',
#   '2.5',
#   '4.0',
#   '12+',
#   'News',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['249',
#   '333263435',
#   'Daily Teachings',
#   '20298752',
#   'USD',
#   '4.99',
#   '1340',
#   '288',
#   '4.5',
#   '5',
#   '1.7.3',
#   '4+',
#   'Lifestyle',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['250',
#   '333710667',
#   'Scanner Pro - PDF document scanner app with OCR',
#   '101346304',
#   'USD',
#   '3.99',
#   '31912',
#   '154',
#   '4.5',
#   '5',
#   '7.1.3',
#   '4+',
#   'Business',
#   '37',
#   '5',
#   '9',
#   '1'],
#  ['251',
#   '333903271',
#   'Twitter',
#   '210569216',
#   'USD',
#   '0',
#   '354058',
#   '452',
#   '3.5',
#   '4',
#   '6.79.1',
#   '17+',
#   'News',
#   '37',
#   '2',
#   '33',
#   '1'],
#  ['252',
#   '334235181',
#   'Trainline UK: Live Train Times, Tickets & Planner',
#   '110198784',
#   'USD',
#   '0',
#   '248',
#   '0',
#   '4',
#   '0',
#   '22',
#   '4+',
#   'Travel',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['253',
#   '334256223',
#   'CBS News - Watch Free Live Breaking News',
#   '78047232',
#   'USD',
#   '0',
#   '11691',
#   '44',
#   '3.5',
#   '4.5',
#   '3.5.1',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['254',
#   '334264405',
#   'iOvilus',
#   '9946112',
#   'USD',
#   '1.99',
#   '381',
#   '6',
#   '3',
#   '2',
#   'iOV 2.1.3',
#   '12+',
#   'Entertainment',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['255',
#   '334503000',
#   'The Impossible Quiz!',
#   '44652544',
#   'USD',
#   '0',
#   '18884',
#   '451',
#   '4',
#   '4.5',
#   '1.62',
#   '9+',
#   'Entertainment',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['257',
#   '334989259',
#   'WolframAlpha',
#   '30369792',
#   'USD',
#   '2.99',
#   '7410',
#   '82',
#   '4',
#   '4.5',
#   '1.7.3',
#   '9+',
#   'Reference',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['258',
#   '335029050',
#   'Catan',
#   '376171520',
#   'USD',
#   '1.99',
#   '15175',
#   '308',
#   '4',
#   '4',
#   '4.6.2',
#   '4+',
#   'Games',
#   '38',
#   '0',
#   '6',
#   '1'],
#  ['259',
#   '335047649',
#   'ScanBizCards Business Card Reader',
#   '96815104',
#   'USD',
#   '0.99',
#   '3166',
#   '34',
#   '4',
#   '4.5',
#   '6.08',
#   '4+',
#   'Business',
#   '37',
#   '5',
#   '5',
#   '1'],
#  ['261',
#   '335364882',
#   'Walgreens – Pharmacy, Photo, Coupons and Shopping',
#   '169138176',
#   'USD',
#   '0',
#   '88885',
#   '333',
#   '4.5',
#   '4',
#   '6.5',
#   '12+',
#   'Shopping',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['262',
#   '335545504',
#   'King of Dragon Pass',
#   '364490752',
#   'USD',
#   '9.99',
#   '882',
#   '85',
#   '5',
#   '5',
#   '2.3.2',
#   '12+',
#   'Games',
#   '43',
#   '5',
#   '1',
#   '1'],
#  ['263',
#   '335709058',
#   'Stylebook',
#   '44135424',
#   'USD',
#   '3.99',
#   '1729',
#   '599',
#   '4',
#   '4.5',
#   '7.0',
#   '17+',
#   'Lifestyle',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['264',
#   '335744614',
#   'NBA',
#   '112074752',
#   'USD',
#   '0',
#   '43682',
#   '19',
#   '3.5',
#   '2.5',
#   '2013.4.3',
#   '4+',
#   'Sports',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['265',
#   '335862325',
#   'Blower',
#   '98942976',
#   'USD',
#   '0.99',
#   '861',
#   '70',
#   '2',
#   '2.5',
#   '4.2',
#   '4+',
#   'Entertainment',
#   '40',
#   '4',
#   '1',
#   '1'],
#  ['266',
#   '335875911',
#   'My Cycles Period and Ovulation Tracker',
#   '77686784',
#   'USD',
#   '0',
#   '7469',
#   '68',
#   '3.5',
#   '5',
#   '5.10.3',
#   '12+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['267',
#   '335989871',
#   'Kmart – Download Now, Shop Online & Pick Up Today!',
#   '94496768',
#   'USD',
#   '0',
#   '4186',
#   '6',
#   '3.5',
#   '4.5',
#   '17.0',
#   '4+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['268',
#   '336141475',
#   '优酷视频',
#   '204959744',
#   'USD',
#   '0',
#   '4885',
#   '0',
#   '3.5',
#   '0',
#   '6.7.0',
#   '12+',
#   'Entertainment',
#   '38',
#   '0',
#   '2',
#   '1'],
#  ['269',
#   '336347946',
#   'DOOM Classic',
#   '32796672',
#   'USD',
#   '4.99',
#   '3970',
#   '509',
#   '4',
#   '4',
#   '2.7',
#   '17+',
#   'Games',
#   '40',
#   '3',
#   '5',
#   '1'],
#  ['270',
#   '336353151',
#   'SoundCloud - Music & Audio',
#   '105009152',
#   'USD',
#   '0',
#   '135744',
#   '594',
#   '4',
#   '4.5',
#   '5.6.0',
#   '4+',
#   'Music',
#   '37',
#   '4',
#   '7',
#   '1'],
#  ['271',
#   '336435697',
#   'imo video calls and chat',
#   '22562816',
#   'USD',
#   '0',
#   '18841',
#   '0',
#   '4',
#   '0',
#   '7.0.84',
#   '4+',
#   'Social Networking',
#   '38',
#   '2',
#   '29',
#   '1'],
#  ['272',
#   '336477530',
#   'Plane Finder - Flight Tracker',
#   '52632576',
#   'USD',
#   '3.99',
#   '1438',
#   '171',
#   '4',
#   '4',
#   '9.4.1',
#   '4+',
#   'Navigation',
#   '37',
#   '3',
#   '10',
#   '1'],
#  ['274',
#   '336599882',
#   'Runtastic Running, Jogging and Walking Tracker',
#   '151388160',
#   'USD',
#   '0',
#   '10298',
#   '7',
#   '4.5',
#   '3.5',
#   '7.3',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '15',
#   '1'],
#  ['275',
#   '336683524',
#   'iFiles',
#   '47323136',
#   'USD',
#   '0.99',
#   '1842',
#   '23',
#   '3.5',
#   '2.5',
#   '1.17.11',
#   '4+',
#   'Productivity',
#   '38',
#   '1',
#   '1',
#   '1'],
#  ['276',
#   '336689375',
#   'TeachMe: Kindergarten',
#   '59846656',
#   'USD',
#   '1.99',
#   '2548',
#   '5',
#   '4',
#   '4',
#   '4.2.2',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['277',
#   '336834650',
#   'Moorhuhn Deluxe - Crazy Chicken',
#   '27807744',
#   'USD',
#   '0.99',
#   '319',
#   '12',
#   '3',
#   '5',
#   '2.8.0',
#   '12+',
#   'Games',
#   '38',
#   '5',
#   '5',
#   '1'],
#  ['278',
#   '336860594',
#   'Victoria’s Secret – The Sexiest Bras & Lingerie',
#   '60976128',
#   'USD',
#   '0',
#   '34507',
#   '38',
#   '3.5',
#   '5',
#   '5.2.1',
#   '12+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['279',
#   '337021781',
#   'MONOPOLY Game',
#   '194386944',
#   'USD',
#   '0.99',
#   '26482',
#   '331',
#   '3.5',
#   '2.5',
#   '1.4.04',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '6',
#   '1'],
#  ['281',
#   '337056601',
#   'n-tv Nachrichten',
#   '49470464',
#   'USD',
#   '0',
#   '273',
#   '0',
#   '3',
#   '0',
#   '5.25',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['282',
#   '337288863',
#   'Shazam Encore',
#   '147118080',
#   'USD',
#   '2.99',
#   '8331',
#   '24',
#   '4',
#   '3.5',
#   '11.0.2',
#   '12+',
#   'Music',
#   '37',
#   '3',
#   '15',
#   '1'],
#  ['283',
#   '337402021',
#   'Harry Potter: Spells',
#   '125411328',
#   'USD',
#   '0.99',
#   '17023',
#   '916',
#   '4',
#   '4.5',
#   '2.2',
#   '4+',
#   'Games',
#   '40',
#   '0',
#   '1',
#   '1'],
#  ['284',
#   '337462979',
#   'First Words Deluxe',
#   '63316992',
#   'USD',
#   '4.99',
#   '1101',
#   '8',
#   '4',
#   '4',
#   '7.0',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['285',
#   '337571576',
#   'Clay Hunt',
#   '15313920',
#   'USD',
#   '0.99',
#   '1193',
#   '1',
#   '4',
#   '2',
#   '3.5.3',
#   '17+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['286',
#   '337710261',
#   'Dream Team - be your own fantasy football manager',
#   '69816320',
#   'USD',
#   '0',
#   '35',
#   '0',
#   '2.5',
#   '0',
#   '12.8.0',
#   '17+',
#   'Sports',
#   '37',
#   '3',
#   '1',
#   '1'],
#  ['287',
#   '337866370',
#   'Jet Car Stunts',
#   '32848910',
#   'USD',
#   '1.99',
#   '4088',
#   '436',
#   '4',
#   '4.5',
#   '1.5.0',
#   '4+',
#   'Games',
#   '47',
#   '4',
#   '1',
#   '1'],
#  ['288',
#   '338057689',
#   'Call of Duty: Zombies',
#   '52821364',
#   'USD',
#   '4.99',
#   '63943',
#   '31264',
#   '4',
#   '4',
#   '1.5.0',
#   '17+',
#   'Games',
#   '47',
#   '0',
#   '1',
#   '1'],
#  ['289',
#   '338137227',
#   'Walmart: Free 2-Day Shipping,* Easy Store Shopping',
#   '146507776',
#   'USD',
#   '0',
#   '70286',
#   '51',
#   '3',
#   '4',
#   '17.8',
#   '4+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['290',
#   '338761996',
#   'AirWatch Agent',
#   '24747008',
#   'USD',
#   '0',
#   '1150',
#   '0',
#   '2.5',
#   '0',
#   '5.5',
#   '4+',
#   'Business',
#   '37',
#   '5',
#   '19',
#   '1'],
#  ['291',
#   '338828953',
#   'Shop Savvy Barcode Scanner - Price Compare & Deals',
#   '89517056',
#   'USD',
#   '0',
#   '54630',
#   '280',
#   '2.5',
#   '4.5',
#   '12.0',
#   '4+',
#   'Shopping',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['292',
#   '339440515',
#   'Voice Changer Plus',
#   '40722432',
#   'USD',
#   '0',
#   '98777',
#   '233',
#   '3',
#   '4',
#   '5.01',
#   '4+',
#   'Entertainment',
#   '37',
#   '2',
#   '12',
#   '1'],
#  ['293',
#   '339462921',
#   'CatPaint',
#   '73332736',
#   'USD',
#   '0.99',
#   '649',
#   '11',
#   '4',
#   '4',
#   '3.5.1',
#   '4+',
#   'Photo & Video',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['294',
#   '339532909',
#   'Redbox',
#   '83906560',
#   'USD',
#   '0',
#   '60236',
#   '58',
#   '3',
#   '4.5',
#   '5.24',
#   '12+',
#   'Entertainment',
#   '37',
#   '0',
#   '1',
# ...
#   '175780864',
#   'USD',
#   '0.99',
#   '79683',
#   '597',
#   '4.5',
#   '4.5',
#   '1.6.1',
#   '12+',
#   'Games',
#   '40',
#   '3',
#   '1',
#   '1'],
#  ['1043',
#   '454802329',
#   'F18 Carrier Landing',
#   '168557568',
#   'USD',
#   '5.99',
#   '4656',
#   '54',
#   '4.5',
#   '4.5',
#   '7.2',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '11',
#   '1'],
#  ['1044',
#   '454958810',
#   'Flick Champions HD',
#   '117258240',
#   'USD',
#   '1.99',
#   '7289',
#   '19',
#   '4.5',
#   '4.5',
#   '2.1.0',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1045',
#   '454988262',
#   'Programme TV Télé Loisirs',
#   '81083392',
#   'USD',
#   '0',
#   '23',
#   '0',
#   '3.5',
#   '0',
#   '7.2.1',
#   '12+',
#   'Entertainment',
#   '37',
#   '5',
#   '4',
#   '1'],
#  ['1047',
#   '455256615',
#   "White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game",
#   '31578112',
#   'USD',
#   '0',
#   '60',
#   '7',
#   '4',
#   '3.5',
#   '2.21',
#   '4+',
#   'Games',
#   '40',
#   '4',
#   '5',
#   '1'],
#  ['1048',
#   '455612214',
#   'Flashlight ◎',
#   '37967872',
#   'USD',
#   '0',
#   '24744',
#   '171',
#   '4.5',
#   '4',
#   '2.0.6',
#   '4+',
#   'Business',
#   '40',
#   '4',
#   '11',
#   '1'],
#  ['1049',
#   '455650341',
#   'Real Steel',
#   '968384512',
#   'USD',
#   '0.99',
#   '24880',
#   '13',
#   '4.5',
#   '4',
#   '1.37.1',
#   '9+',
#   'Games',
#   '38',
#   '5',
#   '8',
#   '1'],
#  ['1051',
#   '455826958',
#   'Pinball Arcade Plus',
#   '111875072',
#   'USD',
#   '0.99',
#   '3716',
#   '6',
#   '4',
#   '2.5',
#   '7.1.0',
#   '9+',
#   'Games',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['1053',
#   '456229650',
#   'QQ游戏大厅HD',
#   '20161086',
#   'USD',
#   '0',
#   '338',
#   '176',
#   '3.5',
#   '3.5',
#   '1.4',
#   '4+',
#   'Entertainment',
#   '26',
#   '5',
#   '1',
#   '1'],
#  ['1054',
#   '456355158',
#   'Doodle Jump FREE - BE WARNED: Insanely addictive',
#   '63676416',
#   'USD',
#   '0',
#   '28153',
#   '100',
#   '4',
#   '4',
#   '2.6.3',
#   '4+',
#   'Games',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1055',
#   '456726080',
#   'Pearson eText for Schools',
#   '21083136',
#   'USD',
#   '0',
#   '609',
#   '4',
#   '2.5',
#   '3',
#   '1.11',
#   '4+',
#   'Education',
#   '24',
#   '5',
#   '8',
#   '1'],
#  ['1057',
#   '457446957',
#   'Jetpack Joyride',
#   '108813312',
#   'USD',
#   '0',
#   '405647',
#   '877',
#   '4.5',
#   '4.5',
#   '1.9.24',
#   '9+',
#   'Games',
#   '38',
#   '5',
#   '3',
#   '1'],
#  ['1058',
#   '457517348',
#   'FotoRus -Camera & Photo Editor & Pic Collage Maker',
#   '119500800',
#   'USD',
#   '0',
#   '32558',
#   '147',
#   '5',
#   '4.5',
#   '7.0.4',
#   '4+',
#   'Photo & Video',
#   '38',
#   '5',
#   '3',
#   '1'],
#  ['1059',
#   '457561360',
#   'Catholic Bible',
#   '103469056',
#   'USD',
#   '1.99',
#   '999',
#   '44',
#   '4.5',
#   '5',
#   '3.4',
#   '4+',
#   'Reference',
#   '37',
#   '5',
#   '15',
#   '1'],
#  ['1060',
#   '457687954',
#   'Doodle Jump HD',
#   '164236288',
#   'USD',
#   '2.99',
#   '8580',
#   '12',
#   '4.5',
#   '4.5',
#   '3.16.4',
#   '4+',
#   'Games',
#   '24',
#   '5',
#   '1',
#   '1'],
#  ['1062',
#   '457876088',
#   'ASOS',
#   '141503488',
#   'USD',
#   '0',
#   '9725',
#   '109',
#   '5',
#   '5',
#   '3.4.1',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '6',
#   '1'],
#  ['1063',
#   '458225159',
#   'NOAA Hi-Def Radar Pro -  Storm Warnings, Hurricane Tracker & Weather Forecast',
#   '27500544',
#   'USD',
#   '1.99',
#   '15809',
#   '628',
#   '5',
#   '4.5',
#   '2.1',
#   '4+',
#   'Weather',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['1064',
#   '458272450',
#   'eHarmony™ Dating App - Meet Singles',
#   '102413312',
#   'USD',
#   '0',
#   '11124',
#   '15',
#   '2.5',
#   '1',
#   '5.5.1',
#   '17+',
#   'Social Networking',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1066',
#   '458318329',
#   '腾讯视频-欢乐颂2全网首播',
#   '112337920',
#   'USD',
#   '0',
#   '613',
#   '9',
#   '4',
#   '4.5',
#   '5.6.2',
#   '17+',
#   'Entertainment',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1067',
#   '458535809',
#   'Calculator ∞',
#   '80345088',
#   'USD',
#   '2.99',
#   '1138',
#   '59',
#   '4.5',
#   '4.5',
#   '4.5',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '15',
#   '1'],
#  ['1068',
#   '458587755',
#   '搜狐视频-欢乐颂2 全网首播',
#   '109425664',
#   'USD',
#   '0',
#   '774',
#   '0',
#   '4.5',
#   '0',
#   '6.6',
#   '17+',
#   'Entertainment',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1069',
#   '458813562',
#   'Abby Monkey® Basic Skills: Preschool and Kindergarten Kids Educational Early Learning Adventure Games.▫ TeachMe Counting, Colors, Alphabet, Math, Numbers, Shapes Sorting, Patterns, Puzzles, Learn to Read Letters for Toddler Children',
#   '71766016',
#   'USD',
#   '2.99',
#   '358',
#   '59',
#   '3.5',
#   '4',
#   '1.71',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['1070',
#   '459023164',
#   '唯品会 HD 全球精选，正品特卖',
#   '106416128',
#   'USD',
#   '0',
#   '68',
#   '0',
#   '4',
#   '0',
#   '6.0.2',
#   '17+',
#   'Shopping',
#   '24',
#   '5',
#   '1',
#   '1'],
#  ['1071',
#   '459035295',
#   'Top Eleven 2017 - Be a Soccer Manager',
#   '144414720',
#   'USD',
#   '0',
#   '14104',
#   '61',
#   '4.5',
#   '4.5',
#   '5.7',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '28',
#   '1'],
#  ['1072',
#   '459189186',
#   'Machinarium',
#   '258739200',
#   'USD',
#   '4.99',
#   '7919',
#   '73',
#   '4.5',
#   '4',
#   '2.1.1',
#   '12+',
#   'Games',
#   '37',
#   '5',
#   '14',
#   '1'],
#  ['1073',
#   '459313476',
#   'Tenuto',
#   '13062144',
#   'USD',
#   '3.99',
#   '562',
#   '0',
#   '5',
#   '0',
#   '3.0.3',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1074',
#   '459660048',
#   'STREET FIGHTER II COLLECTION',
#   '196291794',
#   'USD',
#   '3.99',
#   '242',
#   '218',
#   '4',
#   '4',
#   '1.00.01',
#   '12+',
#   'Games',
#   '43',
#   '0',
#   '1',
#   '1'],
#  ['1076',
#   '460177396',
#   'Twitch',
#   '79983616',
#   'USD',
#   '0',
#   '109549',
#   '149',
#   '4.5',
#   '4.5',
#   '3.20.2',
#   '12+',
#   'Entertainment',
#   '37',
#   '5',
#   '26',
#   '1'],
#  ['1077',
#   '460494135',
#   'Watch TNT',
#   '138006528',
#   'USD',
#   '0',
#   '6856',
#   '8',
#   '2',
#   '1.5',
#   '4.1.1',
#   '17+',
#   'Entertainment',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['1078',
#   '460712294',
#   'Kids Doodle - Movie Kids Color & Draw',
#   '21745664',
#   'USD',
#   '0',
#   '8025',
#   '611',
#   '4.5',
#   '4',
#   '2.4.1',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '8',
#   '1'],
#  ['1081',
#   '461123279',
#   'Written Legends: Nightmare at Sea HD (Full)',
#   '248307057',
#   'USD',
#   '4.99',
#   '234',
#   '234',
#   '4.5',
#   '4.5',
#   '1.0.0',
#   '9+',
#   'Games',
#   '26',
#   '5',
#   '6',
#   '1'],
#  ['1082',
#   '461218759',
#   'Drum Beats+ (Rhythm Metronome, Loops & Grooves Machine)',
#   '385908736',
#   'USD',
#   '3.99',
#   '879',
#   '612',
#   '4.5',
#   '5',
#   '3.4',
#   '4+',
#   'Music',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['1083',
#   '461390784',
#   'Real Fishing 3D',
#   '184315904',
#   'USD',
#   '1.99',
#   '880',
#   '58',
#   '3.5',
#   '4',
#   '1.1.4',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['1084',
#   '461504587',
#   'Trello',
#   '140944384',
#   'USD',
#   '0',
#   '2793',
#   '7',
#   '4.5',
#   '4.5',
#   '4.0.7',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '21',
#   '1'],
#  ['1085',
#   '461703208',
#   '高德地图（精准专业的手机地图）',
#   '166025216',
#   'USD',
#   '0',
#   '1040',
#   '5',
#   '4.5',
#   '4',
#   '8.0.8',
#   '4+',
#   'Navigation',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1086',
#   '462125072',
#   '广东移动手机营业厅-话费流量一手掌握，专属优惠定期发放',
#   '30503936',
#   'USD',
#   '0',
#   '33',
#   '0',
#   '3.5',
#   '0',
#   '5.2.2',
#   '17+',
#   'Utilities',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1087',
#   '462134755',
#   "Puppet Pals HD Director's Pass",
#   '103233536',
#   'USD',
#   '3.99',
#   '54',
#   '0',
#   '4',
#   '0',
#   '1.9.2',
#   '4+',
#   'Education',
#   '24',
#   '4',
#   '1',
#   '1'],
#  ['1088',
#   '462155908',
#   'Fisheye Lens - Retro Style Fisheye Camera',
#   '7671808',
#   'USD',
#   '1.99',
#   '2485',
#   '1564',
#   '4.5',
#   '4.5',
#   '2.1.0',
#   '4+',
#   'Photo & Video',
#   '40',
#   '4',
#   '6',
#   '1'],
#  ['1090',
#   '462397814',
#   'Waking Mars',
#   '337177600',
#   'USD',
#   '4.99',
#   '2101',
#   '0',
#   '4.5',
#   '0',
#   '2.2',
#   '9+',
#   'Games',
#   '37',
#   '5',
#   '2',
#   '1'],
#  ['1091',
#   '462638897',
#   'Fitbit',
#   '132913152',
#   'USD',
#   '0',
#   '90496',
#   '399',
#   '4',
#   '3.5',
#   '2.36',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '9',
#   '1'],
#  ['1093',
#   '462780547',
#   'Watch TBS',
#   '109416448',
#   'USD',
#   '0',
#   '4050',
#   '12',
#   '2',
#   '2.5',
#   '4.1.1',
#   '12+',
#   'Entertainment',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['1095',
#   '463142843',
#   'twinkle',
#   '17612800',
#   'USD',
#   '2.99',
#   '5',
#   '0',
#   '4',
#   '0',
#   '6.6',
#   '17+',
#   'Entertainment',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['1098',
#   '463240522',
#   'HISTORY Here',
#   '23040000',
#   'USD',
#   '0',
#   '685',
#   '369',
#   '4',
#   '4.5',
#   '3.1',
#   '4+',
#   'Travel',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1099',
#   '463295925',
#   'The Official DVSA Theory Test Kit for Car Drivers',
#   '403332096',
#   'USD',
#   '4.99',
#   '0',
#   '0',
#   '0',
#   '0',
#   '3.2.2',
#   '4+',
#   'Education',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1100',
#   '463422433',
#   'Meitu HD',
#   '107525120',
#   'USD',
#   '0',
#   '2150',
#   '68',
#   '4.5',
#   '4.5',
#   '5.4.0',
#   '4+',
#   'Photo & Video',
#   '24',
#   '5',
#   '3',
#   '1'],
#  ['1102',
#   '463431091',
#   'Railway Route Search',
#   '46950400',
#   'USD',
#   '0',
#   '5',
#   '0',
#   '3',
#   '0',
#   '3.17.1',
#   '4+',
#   'Navigation',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1103',
#   '463630399',
#   'PINK Nation',
#   '86456320',
#   'USD',
#   '0',
#   '49816',
#   '413',
#   '4.5',
#   '4.5',
#   '4.13.2',
#   '12+',
#   'Lifestyle',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1105',
#   '463869460',
#   "Ricky Carmichael's Motocross Matchup Pro",
#   '170055680',
#   'USD',
#   '0.99',
#   '4498',
#   '38',
#   '4',
#   '4.5',
#   '1.1.8',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '6',
#   '1'],
#  ['1107',
#   '464235764',
#   'Phonics Island • Early Reading, Spelling & Tracing Montessori Preschool and Kindergarten Kids Learning Adventure Games by Abby Monkey® Alphabet and Letter Sounds Reader',
#   '61427712',
#   'USD',
#   '2.99',
#   '199',
#   '73',
#   '3.5',
#   '3',
#   '1.71',
#   '4+',
#   'Education',
#   '40',
#   '5',
#   '1',
#   '1'],
#  ['1108',
#   '464309202',
#   'LotteryHUB',
#   '47699968',
#   'USD',
#   '0',
#   '2417',
#   '39',
#   '3',
#   '1.5',
#   '5.0.3',
#   '12+',
#   'News',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1109',
#   '464352883',
#   'Infinite Campus Mobile Portal',
#   '28331008',
#   'USD',
#   '0',
#   '2286',
#   '46',
#   '2.5',
#   '1.5',
#   '3.0.9',
#   '4+',
#   'Education',
#   '37',
#   '1',
#   '1',
#   '1'],
#  ['1110',
#   '464660903',
#   'Perfect Image - Pic Collage Maker, Add Text to Photo, Cool Picture Editor',
#   '77390848',
#   'USD',
#   '0',
#   '1646',
#   '141',
#   '4.5',
#   '4.5',
#   '3.8.2',
#   '4+',
#   'Photo & Video',
#   '38',
#   '5',
#   '5',
#   '1'],
#  ['1111',
#   '465092669',
#   'NHL',
#   '160124928',
#   'USD',
#   '0',
#   '15554',
#   '124',
#   '3.5',
#   '5',
#   '8.6.1',
#   '4+',
#   'Sports',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1112',
#   '465173198',
#   'Cronometer',
#   '17243136',
#   'USD',
#   '2.99',
#   '210',
#   '7',
#   '3',
#   '3.5',
#   '1.8.4',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1113',
#   '465694275',
#   'Zen Pinball',
#   '68499456',
#   'USD',
#   '0',
#   '6534',
#   '94',
#   '4.5',
#   '4.5',
#   '1.42.1',
#   '9+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['1114',
#   '466252999',
#   'Green Kitchen – healthy vegetarian recipes',
#   '407632896',
#   'USD',
#   '3.99',
#   '311',
#   '21',
#   '4.5',
#   '4.5',
#   '2.11',
#   '4+',
#   'Food & Drink',
#   '37',
#   '4',
#   '8',
#   '1'],
#  ['1118',
#   '466710109',
#   'HB2 PLUS',
#   '56817664',
#   'USD',
#   '0.99',
#   '54073',
#   '73',
#   '5',
#   '4',
#   '1.3.0',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '4',
#   '1'],
#  ['1119',
#   '466965151',
#   'The Sims™ FreePlay',
#   '695603200',
#   'USD',
#   '0',
#   '446880',
#   '1832',
#   '4.5',
#   '4',
#   '5.29.0',
#   '12+',
#   'Games',
#   '38',
#   '5',
#   '12',
#   '1'],
#  ['1122',
#   '467067151',
#   '百度糯米-电影,美食团购',
#   '127980544',
#   'USD',
#   '0',
#   '383',
#   '0',
#   '4.5',
#   '0',
#   '7.5.0',
#   '17+',
#   'Lifestyle',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['1123',
#   '467329677',
#   'Mathway - Math Problem Solver',
#   '94260224',
#   'USD',
#   '0',
#   '1854',
#   '28',
#   '3.5',
#   '3.5',
#   '3.1.0',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '7',
#   '1'],
#  ['1124',
#   '467703220',
#   'Elmo Calls',
#   '87581696',
#   'USD',
#   '1.99',
#   '1915',
#   '38',
#   '4',
#   '4.5',
#   '3.7',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['1125',
#   '467738064',
#   'AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes',
#   '64024576',
#   'USD',
#   '0',
#   '6408',
#   '77',
#   '4',
#   '4.5',
#   '4.1.2',
#   '4+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1126',
#   '467923185',
#   'Loopy HD',
#   '26399744',
#   'USD',
#   '3.99',
#   '561',
#   '4',
#   '4',
#   '5',
#   '1.6.3',
#   '4+',
#   'Music',
#   '37',
#   '5',
#   '4',
#   '1'],
#  ['1127',
#   '467953363',
#   'Best Hunting Times',
#   '6603776',
#   'USD',
#   '2.99',
#   '123',
#   '9',
#   '4',
#   '4',
#   '4.2',
#   '4+',
#   'Weather',
#   '38',
#   '0',
#   '1',
#   '1'],
#  ['1129',
#   '468090416',
#   'SamCard Pro-card reader&business card scanner&ocr',
#   '21118976',
#   'USD',
#   '5.99',
#   '875',
#   '123',
#   '4.5',
#   '4.5',
#   '2.3.3',
#   '4+',
#   'Business',
#   '37',
#   '0',
#   '7',
#   '1'],
#  ['1130',
#   '468401854',
#   'Daily Classifieds for iPhone',
#   '93220864',
#   'USD',
#   '0.99',
#   '7973',
#   '884',
#   '4',
#   '4.5',
#   '6.2.4.0',
#   '17+',
#   'News',
#   '37',
#   '0',
#   '5',
#   '1'],
#  ['1131',
#   '468429333',
#   'Runtastic Road Bike GPS Cycling Route Tracker PRO',
#   '57786368',
#   'USD',
#   '4.99',
#   '3800',
#   '99',
#   '4.5',
#   '4.5',
#   '3.5',
#   '4+',
#   'Health & Fitness',
#   '37',
#   '0',
#   '15',
#   '1'],
#  ['1132',
#   '468564994',
#   'Tasty Planet: Back for Seconds',
#   '31039488',
#   'USD',
#   '2.99',
#   '264',
#   '56',
#   '4.5',
#   '4.5',
#   '1.4',
#   '9+',
#   'Games',
#   '43',
#   '0',
#   '8',
#   '1'],
#  ['1133',
#   '468566852',
#   'Tasty Planet: Back for Seconds HD',
#   '29511680',
#   'USD',
#   '4.99',
#   '135',
#   '62',
#   '4.5',
#   '4.5',
#   '1.4',
#   '9+',
#   'Games',
#   '26',
#   '5',
#   '8',
#   '1'],
#  ['1135',
#   '468674094',
#   'Scanner911 HD Police Radio Pro',
#   '4348875',
#   'USD',
#   '3.99',
#   '204',
#   '166',
#   '4',
#   '4',
#   '3.95',
#   '12+',
#   'News',
#   '26',
#   '3',
#   '2',
#   '1'],
#  ['1136',
#   '468996152',
#   'OfferUp - Buy. Sell. Simple.',
#   '73138176',
#   'USD',
#   '0',
#   '57348',
#   '1213',
#   '4.5',
#   '4.5',
#   '2.10.17',
#   '4+',
#   'Shopping',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1137',
#   '469024771',
#   '随手记专业版 for  iPad',
#   '32996352',
#   'USD',
#   '0.99',
#   '240',
#   '1',
#   '4.5',
#   '5',
#   '4.0.0',
#   '4+',
#   'Finance',
#   '24',
#   '5',
#   '1',
#   '1'],
#  ['1138',
#   '469284907',
#   'HP All-in-One Printer Remote',
#   '60647424',
#   'USD',
#   '0',
#   '9819',
#   '415',
#   '4.5',
#   '4.5',
#   '5.3',
#   '4+',
#   'Productivity',
#   '37',
#   '2',
#   '14',
#   '1'],
#  ['1139',
#   '469337564',
#   'Adobe Acrobat Reader: View, Create, & Convert PDFs',
#   '81007616',
#   'USD',
#   '0',
#   '20069',
#   '33',
#   '4',
#   '4.5',
#   '17.05.23',
#   '4+',
#   'Business',
#   '37',
#   '5',
#   '19',
#   '1'],
#  ['1140',
#   '469338840',
#   '飞常准Pro-全球航班查询机票酒店预订',
#   '94053376',
#   'USD',
#   '0.99',
#   '132',
#   '1',
#   '4',
#   '5',
#   '4.0.5',
#   '17+',
#   'Travel',
#   '37',
#   '0',
#   '2',
#   '1'],
#  ['1142',
#   '469343097',
#   'MEGA MAN X',
#   '90374144',
#   'USD',
#   '4.99',
#   '3099',
#   '105',
#   '4.5',
#   '4.5',
#   '1.03.22',
#   '4+',
#   'Games',
#   '40',
#   '5',
#   '6',
#   '1'],
#  ['1143',
#   '469369175',
#   'CSR Racing',
#   '524803072',
#   'USD',
#   '0',
#   '677247',
#   '2029',
#   '4.5',
#   '4.5',
#   '4.0.1',
#   '4+',
#   'Games',
#   '37',
#   '5',
#   '10',
#   '1'],
#  ['1144',
#   '469610082',
#   'Riptide GP',
#   '41246720',
#   'USD',
#   '0.99',
#   '3883',
#   '675',
#   '4',
#   '4',
#   '1.4.1',
#   '4+',
#   'Games',
#   '40',
#   '4',
#   '1',
#   '1'],
#  ['1145',
#   '469622080',
#   'Math Practice - Integers',
#   '2598912',
#   'USD',
#   '0.99',
#   '11',
#   '0',
#   '4',
#   '0',
#   '2.0',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1146',
#   '469863705',
#   'Khan Academy: you can learn anything',
#   '162706432',
#   'USD',
#   '0',
#   '5459',
#   '10',
#   '4',
#   '4.5',
#   '4.3.0',
#   '4+',
#   'Education',
#   '37',
#   '5',
#   '6',
#   '1'],
#  ['1148',
#   '469960709',
#   'Bejeweled Blitz',
#   '91591680',
#   'USD',
#   '0',
#   '221002',
#   '131',
#   '4',
#   '4',
#   '1.29.1',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '1',
#   '1'],
#  ['1149',
#   '469964520',
#   'Lloyds Bank Mobile Banking',
#   '104023040',
#   'USD',
#   '0',
#   '17',
#   '5',
#   '4.5',
#   '4',
#   '16.1',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '1',
#   '1'],
#  ['1150',
#   '470412139',
#   'Sleepy Hollow: Mystery Legends HD (Full)',
#   '375949016',
#   'USD',
#   '4.99',
#   '168',
#   '168',
#   '4',
#   '4',
#   '1.0.1',
#   '9+',
#   'Games',
#   '26',
#   '5',
#   '4',
#   '1'],
#  ['1151',
#   '470412147',
#   'Poshmark: Buy & Sell Fashion',
#   '58299392',
#   'USD',
#   '0',
#   '18035',
#   '156',
#   '4.5',
#   '4.5',
#   '2.70',
#   '4+',
#   'Shopping',
#   '37',
#   '5',
#   '1',
#   '1'],
#  ['1152',
#   '470578793',
#   'Secret Calculator Pro - Hide photos & videos',
#   '14578688',
#   'USD',
#   '1.99',
#   '2504',
#   '644',
#   '4.5',
#   '5',
#   '1.13',
#   '4+',
#   'Photo & Video',
#   '37',
#   '0',
#   '12',
#   '1'],
#  ...]

# %%
reviews_max_as = {} 

for app in apple_store_data[1:]: 
    name = app[2]
    n_reviews = float(app[6])
    
    if name in reviews_max_as and reviews_max_as[name]<n_reviews: 
        reviews_max_as[name] = n_reviews
    elif name not in reviews_max_as: 
        reviews_max_as[name] = n_reviews

breviews_max_as
# Out:
# {'PAC-MAN Premium': 21292.0,
#  'Evernote - stay organized': 161065.0,
#  'WeatherBug - Local Weather, Radar, Maps, Alerts': 188583.0,
#  'eBay: Best App to Buy, Sell, Save! Online Shopping': 262241.0,
#  'Bible': 985920.0,
#  'Shanghai Mahjong': 8253.0,
#  'PayPal - Send and request money safely': 119487.0,
#  'Pandora - Music & Radio': 1126879.0,
#  'PCalc - The Best Calculator': 1117.0,
#  'Ms. PAC-MAN': 7885.0,
#  'Solitaire by MobilityWare': 76720.0,
#  'SCRABBLE Premium': 105776.0,
#  'Google – Search made just for mobile': 479440.0,
#  'Bank of America - Mobile Banking': 119773.0,
#  'FreeCell': 6340.0,
#  'TripAdvisor Hotels Flights Restaurants': 56194.0,
#  'Facebook': 2974676.0,
#  'Yelp - Nearby Restaurants, Shopping & Services': 223885.0,
#  'Shazam - Discover music, artists, videos & lyrics': 402925.0,
#  'Crash Bandicoot Nitro Kart 3D': 31456.0,
#  'iQuran': 2929.0,
#  ':) Sudoku +': 11447.0,
#  'Yahoo Sports - Teams, Scores, News & Highlights': 137951.0,
#  'Mileage Log | Fahrtenbuch': 8.0,
#  'Cleartune - Chromatic Tuner': 3241.0,
#  'Lifesum – Inspiring healthy lifestyle app': 5795.0,
#  'Hangman.': 42316.0,
#  'iTranslate - Language Translator & Dictionary': 123215.0,
#  'TouchOSC': 782.0,
#  'RadarScope': 3449.0,
#  'LinkedIn': 71856.0,
#  'Period Tracker Deluxe': 13350.0,
#  'Election 2016 Map': 137.0,
#  'Blackjack by MobilityWare': 180087.0,
#  'White Noise': 33426.0,
#  'iHeartRadio – Free Music & Radio Stations': 293228.0,
#  'Line Rider iRide™': 21609.0,
#  'Deliveries: a package tracker': 4684.0,
#  'Hurricane Pro': 2104.0,
#  'Fieldrunners': 41633.0,
#  'Juxtaposer': 3610.0,
#  'Deezer - Listen to your Favorite Music & Playlists': 4677.0,
#  'iStellar': 30.0,
#  'Sonos Controller': 48905.0,
#  'Avertinoo': 32.0,
#  'Google Earth': 446185.0,
#  'iFart - The Original Fart Sounds App': 21825.0,
#  'PAC-MAN': 508808.0,
#  'FOX Sports Mobile': 57500.0,
#  'First Words Animals': 2576.0,
#  'WeatherPro': 1572.0,
#  'HotSchedules': 3292.0,
#  'Star Walk - Find Stars And Planets in Sky Above': 8932.0,
#  'The Weather Channel: Forecast, Radar & Alerts': 495626.0,
#  'Big Day - Event Countdown': 812.0,
#  '12 Steps AA Companion - Alcoholics Anonymous': 1583.0,
#  'OpenTable - Restaurant Reservations': 113936.0,
#  'VLC Remote': 2027.0,
#  'gFlashPro - Flashcards & Tests': 768.0,
#  'Lose It! – Weight Loss Program and Calorie Counter': 373835.0,
#  'Target': 108131.0,
#  'Fish Tycoon': 18943.0,
#  'Amazon App: shop, scan, compare, and read reviews': 126312.0,
#  'Touchgrind': 35735.0,
#  'ProPresenter Remote': 410.0,
#  'iReal Pro - Music Book & Play Along': 1390.0,
#  'NRJ Radio': 38.0,
#  'Chase Mobile℠': 233270.0,
#  '大辞林': 64.0,
#  'Allrecipes Dinner Spinner': 109349.0,
#  '新浪新闻-阅读最新时事热门头条资讯视频': 2229.0,
#  'MotionX GPS': 14970.0,
#  'AccuWeather - Weather for Life': 144214.0,
#  'Mint: Personal Finance, Budget, Bills & Money': 232940.0,
#  'ABC News - US & World News + Live Video': 48407.0,
#  'Rowmote: Remote Control for Mac': 5531.0,
#  'Peekaboo Barn': 3393.0,
#  'Speedtest by Ookla': 65016.0,
#  'Pocket God': 187529.0,
#  'Nike+ Training Club - Workouts & Fitness Plans': 33969.0,
#  'Citi Mobile®': 48822.0,
#  'Phase 10 Pro - Play Your Friends!': 59155.0,
#  'Kindle – Read eBooks, Magazines & Textbooks': 252076.0,
#  'MASH': 4913.0,
#  '同花顺-炒股、股票': 1744.0,
#  'Wedding Dash Deluxe': 16567.0,
#  'Beer Pong Game': 187315.0,
#  'Tempo - Metronome with Setlists': 4781.0,
#  'Skat': 94.0,
#  'Color Splash': 29554.0,
#  'Zombieville USA': 32988.0,
#  'Skype for iPhone': 373519.0,
#  'Tumblr': 334293.0,
#  'iSwap Faces': 2302.0,
#  'Match™ - #1 Dating App.': 60659.0,
#  "Tozzle - Toddler's favorite puzzle": 2562.0,
#  'HomeBudget with Sync': 3042.0,
#  'Wind Meter': 338.0,
#  'Map My Run+ - GPS Running & Workout Tracker': 16434.0,
#  'Map My Ride+ - GPS Cycling & Route Tracker': 10046.0,
#  'HuffPost - News, Politics & Entertainment': 29107.0,
#  'Phrase Party!': 878.0,
#  'Minesweeper Classic': 1140.0,
#  "Sally's Spa": 35074.0,
#  'CBS Sports App - Sports Scores, News, Stats, Watch': 59639.0,
#  'Brain Wave ™ - 32 Advanced Binaural Brainwave Entrainment Programs with iTunes Music and Relaxing Ambience': 2913.0,
#  'iSwap Faces LITE': 39722.0,
#  'DIRECTV': 81006.0,
#  'NYTimes Crossword - Daily Word Puzzle Game': 53465.0,
#  'Doodle Jump': 395261.0,
#  'LEDit – The LED Banner App': 2021.0,
#  'niconico': 182.0,
#  'Fandango Movies - Times + Tickets': 291787.0,
#  'iCab Mobile (Web Browser)': 2441.0,
#  'iRagdoll - Ragdoll Physics': 1372.0,
#  'Proloquo2Go - Symbol-based AAC': 773.0,
#  'Dictionary.com Dictionary & Thesaurus': 200047.0,
#  "20 Minutes.fr - l'actualité en continu": 112.0,
#  'The Masters Tournament': 148160.0,
#  'myAT&T': 108507.0,
#  'SFR TV': 46.0,
#  'Shutterfly: Prints, Photo Books, Cards Made Easy': 51427.0,
#  'StickWars': 53821.0,
#  'Indeed Job Search': 38681.0,
#  'World Cup Table Tennis™': 17776.0,
#  'WhatsApp Messenger': 287589.0,
#  'iStudiez Pro – Homework, Schedule, Grades': 7308.0,
#  'Zillow Real Estate - Homes for Sale & for Rent': 342969.0,
#  '2XL Supercross': 6093.0,
#  'Pocket Tanks Deluxe': 5452.0,
#  'Wells Fargo Mobile': 43064.0,
#  'radio.de - Der Radioplayer': 64.0,
#  'AutoScout24 - mobile used & new car market': 220.0,
#  'Sky Burger - Build & Match Food Free': 114096.0,
#  'MindNode – Delightful Mind Mapping': 1296.0,
#  'Packing Pro': 1293.0,
#  'USAA Mobile': 19946.0,
#  'The Moron Test': 88613.0,
#  'Sunday Lawn': 107727.0,
#  'Peggle Classic': 21416.0,
#  'SmartGo Player': 533.0,
#  'I Am T-Pain 2.0': 32650.0,
#  'TextNow - Unlimited Text + Calls': 164963.0,
#  'Boating Weather': 141.0,
#  'Best Buy': 80424.0,
#  'I Dig It': 17190.0,
#  'Unblock Me': 7973.0,
#  'Sonic The Hedgehog': 19621.0,
#  '10 Pin Shuffle Pro Bowling': 7315.0,
#  'Sky News': 118.0,
#  'ESPN: Get scores, news, alerts & watch live sports': 290996.0,
#  'LiveATC Air Radio': 2785.0,
#  'The Sims 3': 54408.0,
#  'Chess Pro with Coach - Learn,Play & Online Friends': 8138.0,
#  'Guess My Age \ue020 Math Magic': 123190.0,
#  'Crush the Castle': 23810.0,
#  '2016 U.S. Open Golf Championship': 54192.0,
#  'The Championships, Wimbledon 2016 - Tennis Grand Slam': 20953.0,
#  'TuneIn Radio Pro - MLB Audiobooks Podcasts Music': 71609.0,
#  'NBC News': 32881.0,
#  'Grindr - Gay and same sex guys chat, meet and date': 23201.0,
#  'Whole Foods Market': 17906.0,
#  'NAVIGON Europe': 927.0,
#  'Virtual Families': 18920.0,
#  'Sparkasse+': 30.0,
#  'Sparkasse - Your mobile branch': 77.0,
#  'Sleep Cycle alarm clock': 104539.0,
#  'FACEinHOLE®': 4016.0,
#  'Harvest - Select the Best Produce': 299.0,
#  'WORMS': 5758.0,
#  'Pixel Starships™ : 8Bit MMORPG': 5565.0,
#  'Traffic Rush': 213092.0,
#  'MyRadar NOAA Weather Radar Forecast': 150158.0,
#  'Resident Evil 4: PLATINUM': 6046.0,
#  'Waze - GPS Navigation, Maps & Real-time Traffic': 345046.0,
#  'Cartoon Wars': 35930.0,
#  'Moto X Mayhem': 22557.0,
#  'Fantasy Football Manager - FFM for FPL': 292.0,
#  'Spotify Music': 878563.0,
#  'McDo France': 22.0,
#  'PGA Championship 2016 – Baltusrol Golf Club': 10472.0,
#  "BFMTV : l'info en continu": 115.0,
#  'MyRadar Pro NOAA Weather Radar, Forecasts & Storms': 13915.0,
#  'Spider:  The Secret of Bryce Manor': 6780.0,
#  'My Measures PRO': 1701.0,
#  'Food Additives Checker (E Numbers)': 6.0,
#  'SFR Mon Compte': 19.0,
#  'Baby Connect (Activity Log)': 3483.0,
#  'Epson iPrint': 2838.0,
#  'Mad Libs': 117889.0,
#  'BATTLE BEARS: Zombies!': 50710.0,
#  'Hurricane Tracker': 3960.0,
#  'NFL Sunday Ticket': 24258.0,
#  '2016 US Open Tennis Championships': 37522.0,
#  'Dropbox': 49578.0,
#  'Wa Kingyo - Goldfish Pond': 626.0,
#  'Monkey Preschool Lunchbox': 9286.0,
#  'Yahoo Fantasy Sports': 190670.0,
#  'Gaia GPS Classic': 2429.0,
#  'iLoan Calc (Loan calculator)': 0.0,
#  'Geocaching®': 12811.0,
#  'Camera+': 32338.0,
#  'Alter Ego': 262.0,
#  'Parking Mania': 9657.0,
#  'Sudoku⁺': 18332.0,
#  'Period Tracker Lite': 53620.0,
#  'Camera Plus: For Macro Photos & Remote Photography': 38533.0,
#  'The perfect Egg timer': 40.0,
#  'Letter Quiz - alphabet tracing for kids': 472.0,
#  'Starbucks': 303856.0,
#  '央视影音-海量央视内容高清直播': 2070.0,
#  'Bloons TD': 7941.0,
#  'Weight Watchers': 136833.0,
#  'CNN: Breaking US & World News, Live Video': 112886.0,
#  'Gilt': 26353.0,
#  'TRUTH or DARE!!! - FREE': 171055.0,
#  'Canabalt': 4540.0,
#  'Alipay - Makes Life Easy': 1926.0,
#  'Scanner911 Pro': 14345.0,
#  'Daily Teachings': 1340.0,
#  'Scanner Pro - PDF document scanner app with OCR': 31912.0,
#  'Twitter': 354058.0,
#  'Trainline UK: Live Train Times, Tickets & Planner': 248.0,
#  'CBS News - Watch Free Live Breaking News': 11691.0,
#  'iOvilus': 381.0,
#  'The Impossible Quiz!': 18884.0,
#  'WolframAlpha': 7410.0,
#  'Catan': 15175.0,
#  'ScanBizCards Business Card Reader': 3166.0,
#  'Walgreens – Pharmacy, Photo, Coupons and Shopping': 88885.0,
#  'King of Dragon Pass': 882.0,
#  'Stylebook': 1729.0,
#  'NBA': 43682.0,
#  'Blower': 861.0,
#  'My Cycles Period and Ovulation Tracker': 7469.0,
#  'Kmart – Download Now, Shop Online & Pick Up Today!': 4186.0,
#  '优酷视频': 4885.0,
#  'DOOM Classic': 3970.0,
#  'SoundCloud - Music & Audio': 135744.0,
#  'imo video calls and chat': 18841.0,
#  'Plane Finder - Flight Tracker': 1438.0,
#  'Runtastic Running, Jogging and Walking Tracker': 10298.0,
#  'iFiles': 1842.0,
#  'TeachMe: Kindergarten': 2548.0,
#  'Moorhuhn Deluxe - Crazy Chicken': 319.0,
#  'Victoria’s Secret – The Sexiest Bras & Lingerie': 34507.0,
#  'MONOPOLY Game': 26482.0,
#  'n-tv Nachrichten': 273.0,
#  'Shazam Encore': 8331.0,
#  'Harry Potter: Spells': 17023.0,
#  'First Words Deluxe': 1101.0,
#  'Clay Hunt': 1193.0,
#  'Dream Team - be your own fantasy football manager': 35.0,
#  'Jet Car Stunts': 4088.0,
#  'Call of Duty: Zombies': 63943.0,
#  'Walmart: Free 2-Day Shipping,* Easy Store Shopping': 70286.0,
#  'AirWatch Agent': 1150.0,
#  'Shop Savvy Barcode Scanner - Price Compare & Deals': 54630.0,
#  'Voice Changer Plus': 98777.0,
#  'CatPaint': 649.0,
#  'Redbox': 60236.0,
#  'クックパッド - No.1料理レシピ検索アプリ': 115.0,
#  'Trenches': 26732.0,
#  'The Christmas List': 2722.0,
#  "Macy's": 11013.0,
#  'Calorie Counter & Diet Tracker by MyFitnessPal': 507706.0,
#  'BlaBlaCar - Trusted Carpooling': 397.0,
#  'Refills Calendar - Scheduler - Note': 196.0,
#  '5-0 Radio Pro Police Scanner (Extra Feeds)': 24553.0,
#  'Hipstamatic': 12557.0,
#  'Sing Karaoke Songs Unlimited with StarMaker': 26227.0,
#  'TurboScan™ Pro - document & receipt scanner: scan multiple pages and photos to PDF': 28388.0,
#  'Positivity with Andrew Johnson': 282.0,
#  'Rat On A Scooter XL': 19296.0,
#  'IMDb Movies & TV - Trailers and Showtimes': 183425.0,
#  'Angry Birds': 824451.0,
#  'DB Navigator': 512.0,
#  'Video Calls with Santa': 315.0,
#  'Voyages-sncf.com : book train and bus tickets': 268.0,
#  'The Font Game': 438.0,
#  'ImmobilienScout24: Real Estate Search in Germany': 187.0,
#  'Grand Theft Auto: Chinatown Wars': 15142.0,
#  'Southwest Airlines': 30552.0,
#  'The Sims 3 World Adventures': 9744.0,
#  'Star Chart': 13482.0,
#  'TaxCaster – Free tax refund calculator': 17516.0,
#  'Glow Hockey 2 FREE': 186653.0,
#  'Big Button Box - funny sounds, sound effects buttons, pro fx soundboard, fun games board, scary music, annoying fart noises, jokes, super cool dj effect, cat, dog & animal fx': 10031.0,
#  'TV SPIELFILM - TV Programm mit Live TV': 81.0,
#  'All-in-1 Logic GameBox': 9854.0,
#  'Roadside America': 1093.0,
#  'Pocket Yoga': 4475.0,
#  'Sonic the Hedgehog 2': 9405.0,
#  'Simply Being - Guided Meditation for Relaxation and Presence': 2417.0,
#  'CamCard - Business card scanner & reader': 2923.0,
#  'This American Life': 8657.0,
#  'Timetracks - Slit-Scan Camera': 70.0,
#  "franceinfo - l'actualité & les élections en direct": 162.0,
#  'DOUBUTSU URANAI®-Animal Fortune-': 5.0,
#  'Doodle Army': 12354.0,
#  'Ameba': 269.0,
#  'eBook: War and Peace': 0.0,
#  'Plants vs. Zombies': 426463.0,
#  'Weibo': 7265.0,
#  '大众点评-发现品质生活': 844.0,
#  'AlloCiné : Cinéma et Séries': 101.0,
#  'Badoo - Meet New People, Chat, Socialize.': 34428.0,
#  'Flick Kick Field Goal': 36946.0,
#  'Venmo': 21090.0,
#  'Dungeons & Such Treasures,Collectibles and Dragons': 653.0,
#  'StarMap 3D+: Night Sky, Astronomy, Star View Guide': 1118.0,
#  'Shift Worker': 348.0,
#  'Spy Calc - Hide pictures, videos, documents': 207.0,
#  'Waterlogged - Daily Hydration Tracker': 5000.0,
#  'MyNetDiary PRO - Calorie Counter and Food Diary': 15188.0,
#  'The Washington Post Classic': 18572.0,
#  'F-Sim Space Shuttle': 6403.0,
#  'Groupon - Deals, Coupons & Discount Shopping App': 417779.0,
#  'Learn to Speak Spanish Fast With MosaLingua': 9.0,
#  'Coaster VR, Extreme Endless 3D Stereograph': 107.0,
#  'Parents Calling Easter Bunny': 72.0,
#  'Sporcle': 2044.0,
#  'Univision Deportes: Liga MX, MLS, Fútbol En Vivo': 16683.0,
#  'DOOM II RPG': 1455.0,
#  'STREET FIGHTER IV': 15056.0,
#  'Dr. Seuss Camera - The Cat in the Hat Edition': 249.0,
#  'FINAL FANTASY': 6091.0,
#  'FINAL FANTASY II': 2754.0,
#  'Worms 2: Armageddon': 9870.0,
#  'SoundHound Song Search & Music Player': 82602.0,
#  'Jourist Weltübersetzer': 0.0,
#  'TeachMe: 1st Grade': 762.0,
#  'TeachMe: 3rd Grade': 160.0,
#  'ヤフオク! 利用者数NO.1のオークション、フリマアプリ': 9.0,
#  'Kik': 260965.0,
#  'Slow Shutter Cam': 2305.0,
#  'PeakFinder Earth': 137.0,
#  'AgingBooth': 11999.0,
#  'iWatermark - Watermark 1 or Batch of Photos. Watermarking with Text, Logo, & Graphics Overlays.': 1995.0,
#  'Tabs & Chords by Ultimate Guitar - learn and play': 35045.0,
#  'Dude, your car!': 343.0,
#  'Drawing Pad': 1824.0,
#  'ESPN Tournament Challenge': 39642.0,
#  'Solitaire': 679055.0,
#  'Notability': 17594.0,
#  "Rubik's® Cube": 3531.0,
#  'Super Why! Power to Read': 1080.0,
#  'Amex Mobile': 11421.0,
#  'Fruit Ninja Classic': 698516.0,
#  'Animation Creator HD': 4497.0,
#  'Plants vs. Zombies HD': 163598.0,
#  'SCRABBLE Premium for iPad': 39678.0,
#  'Graphic - illustration and design': 1809.0,
#  'Ship Finder': 624.0,
#  'Photogene ⁴': 3761.0,
#  'Hurricane HD': 353.0,
#  'Star Walk HD - Night Sky Map': 6503.0,
#  'Space War HD': 71.0,
#  'Netflix': 308844.0,
#  'forScore': 3909.0,
#  'ComicGlass [ComicReader]': 308.0,
#  'iAnnotate PDF': 11156.0,
#  'ArtStudio for iPad - Draw Sketch and Paint': 8542.0,
#  'Call of Duty: Zombies HD': 5853.0,
#  'Small World 2': 1506.0,
#  'Qzone': 1649.0,
#  'ABC – Watch Live TV & Stream Full Episodes': 78890.0,
#  'Fieldrunners for iPad': 2147.0,
#  'Angry Birds HD': 89110.0,
#  'The Weather Channel App for iPad – best local forecast, radar map, and storm tracking': 208648.0,
#  'Do Not Press The Red Button HD': 856.0,
#  'Digits, the calculator for humans': 7825.0,
#  'PDF Reader Pro Edition - Annotate,edit & sign PDFs': 7033.0,
#  'National Geographic World Atlas': 4255.0,
#  'FileBrowser - Access files on remote computers': 3230.0,
#  'Dictionary.com Dictionary & Thesaurus for iPad': 54175.0,
#  'Animation & Drawing by Do Ink': 308.0,
#  'AirCoaster - Roller Coaster Builder': 2602.0,
#  'Documents 6 - File manager, PDF reader and browser': 29110.0,
#  'The World Factbook for iPad': 273.0,
#  'Photo Transfer App - Easy backup of photos+videos': 15654.0,
#  'TwitCasting Viewer - Watch Live Video & Radio': 189.0,
#  'Ski Tracks': 829.0,
#  "The Photographer's Ephemeris": 663.0,
#  '▻Sudoku': 359832.0,
#  'StubHub - Tickets to Sports, Concerts and Theatre': 9011.0,
#  'Runtastic PRO Running, Jogging and Fitness Tracker': 17667.0,
#  'OverDrive – Library eBooks and Audiobooks': 65450.0,
#  'Hotels & Vacation Rentals by Booking.com': 31261.0,
#  'The Impossible Game': 9885.0,
#  'PrankDial - #1 Prank Call App': 11091.0,
#  'Fox News': 132703.0,
#  'Live Cams - HD': 286.0,
#  'QR Reader for iPhone': 12683.0,
#  'Uber': 49466.0,
#  'WEB.DE Mail': 168.0,
#  'iBunkoHD': 114.0,
#  'Hurricane Tracker For iPad': 2798.0,
#  '6play, TV en direct et en replay': 62.0,
#  'AudioNote - Notepad and Voice Recorder': 1756.0,
#  'Breathing Zone: Guided Breathing for Mindfulness': 511.0,
#  'My Virtual Girlfriend - Deluxe Dating Sim': 2609.0,
#  'Fake-A-Location Free ™': 354.0,
#  'QQ 浏览器-搜新闻、选小说漫画、看视频': 1750.0,
#  'Math Ninja HD': 1121.0,
#  'Résultats Foot en Direct': 339.0,
#  'Chase Mobile': 34322.0,
#  'Captio - Email yourself with 1 tap': 162.0,
#  'My Vodafone': 8.0,
#  'Math Bingo': 4386.0,
#  '▻Sudoku +': 5397.0,
#  'Tango - Free Video Call, Voice and Chat': 75412.0,
#  'MeetMe - Chat and Meet New People': 97072.0,
#  'WebMD for iPad': 9142.0,
#  'GeoBee Challenge HD by National Geographic': 1957.0,
#  'OPlayer HD - video player, classic media streaming': 2944.0,
#  'TouchRetouch': 588.0,
#  'Cat Physics': 40552.0,
#  '随手记（专业版）-好用的记账理财工具': 1267.0,
#  'AnkiMobile Flashcards': 753.0,
#  'WeatherPro for iPad': 725.0,
#  'Real英会話': 45.0,
#  'BATTLE BEARS -1': 14910.0,
#  'Crash Bandicoot Nitro Kart 2': 3064.0,
#  'WIRED Magazine': 12074.0,
#  'Popplet': 336.0,
#  'Notes Plus': 6257.0,
#  'Color Splash for iPad': 2445.0,
#  'Robot Unicorn Attack': 22150.0,
#  'SimSimi': 23530.0,
#  'Carcassonne': 10846.0,
#  'Apple Store': 55171.0,
#  'TED': 5782.0,
#  'Météo-France': 24.0,
#  'Ma Banque': 17.0,
#  'Doodle God™': 35759.0,
#  'Carnivores: Dinosaur Hunter Pro': 18306.0,
#  'Blackboard Mobile Learn™': 13567.0,
#  'SEC Football Schedules, Scores & Radio': 240.0,
#  'Hulu: Watch TV Shows & Stream the Latest Movies': 56170.0,
#  'かなもじ': 19.0,
#  '恵方コンパス.': 0.0,
#  '360 Panorama': 10463.0,
#  'Mega Millions & Powerball - lottery games in the US with winning number results, lotto jackpots and prize payouts': 1255.0,
#  'Cake Doodle': 5803.0,
#  'The Impossible Quiz! for iPad': 227.0,
#  'Boating USA': 342.0,
#  'Diptic': 7578.0,
#  'Family Feud™ HD': 1156.0,
#  'Edmodo': 7197.0,
#  'Auto Palmistry Premium': 5.0,
#  'Drift Mania Championship': 3432.0,
#  '「宅建士」過去問題《受験用》': 0.0,
#  'Osmos for iPad': 24306.0,
#  '携程旅行-酒店、机票、火车票预订助手': 312.0,
#  'Audible – audio books, original series & podcasts': 105274.0,
#  'Living Earth - Clock & Weather': 25475.0,
#  'Sushi Cat': 8718.0,
#  'Talking Tom Cat for iPad': 29492.0,
#  "Let's create! Pottery HD": 12787.0,
#  'Files HD Pro - File Manager & Web Browser': 2237.0,
#  'Army Fitness APFT Calculator': 108.0,
#  'Ringtones for iPhone & Ringtone Maker': 25403.0,
#  'Zoopla Property Search -UK Homes for Sale and Rent': 210.0,
#  'Vestiaire Collective - Pre-Owned Luxury Fashion': 169.0,
#  'Week Calendar': 7447.0,
#  'Stack the States®': 12833.0,
#  'Flashlight Ⓞ': 130450.0,
#  'ゲーム発展国＋＋': 6.0,
#  'Celebtwin: Celebrity Looks Like Lite': 1111.0,
#  'Onefootball - Soccer Scores & Live News': 3194.0,
#  'SuperCam_Pro': 1399.0,
#  'カロリー管理（痩せるアプリ）': 10.0,
#  '手机百度 - 百度一下你就得到': 1990.0,
#  "Sam's Club: Wholesale Shopping & Bulk Buy Deals": 8149.0,
#  'Splashtop Personal - Remote Desktop': 29376.0,
#  'eBay Kleinanzeigen - Free. Easy. Local.': 74.0,
#  'Viber Messenger – Text & Call': 164249.0,
#  'Osmos': 14605.0,
#  'shopkick - Shopping Rewards & Discounts': 130823.0,
#  'Decide Now!': 486.0,
#  'Ringtone Designer Pro - Create Unlimited Ringtones, Text Tones, Email Alerts, and More!': 8946.0,
#  'The Secret of Grisly Manor': 1993.0,
#  'Find My Family, Friends & iPhone - Life360 Locator': 43877.0,
#  'Pocketbooth - the photo booth in your pocket': 2377.0,
#  '乐视视频-白鹿原,欢乐颂,奔跑吧全网热播': 1590.0,
#  'The Incident': 2070.0,
#  'ホットペッパービューティー/サロン予約': 9.0,
#  'Dictionary.com Dictionary & Thesaurus Premium': 11530.0,
#  'Autohome-Find new＆Used Cars For Sale': 194.0,
#  'OPEN Forum': 200.0,
#  'Weibo HD': 16772.0,
#  'Reckless Racing HD': 9.0,
#  'Bloons Super Monkey': 2113.0,
#  'Lotto Results - Mega Millions Powerball Lottery': 794.0,
#  'IKEA Catalog': 8939.0,
#  'QQ安全中心': 308.0,
#  'Free IQ Test: Calculate your IQ': 5.0,
#  'Infinity Blade': 326482.0,
#  '淘宝 - 随时随地，想淘就淘': 3801.0,
#  'Virtual Regatta Offshore': 209.0,
#  'iSlash': 33868.0,
#  'Ugly Meter™': 13741.0,
#  'Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran': 18418.0,
#  'Carbs & Cals - Diet & Diabetes': 21.0,
#  '2XL Supercross HD': 1588.0,
#  'Fly Delta': 8094.0,
#  'Google Authenticator': 1652.0,
#  'CamScanner +| PDF Document Scanner and OCR': 5482.0,
#  'Pocket Anatomy - Interactive 3D Human Anatomy and Physiology.': 611.0,
#  'Flashlight for iPhone , iPod and iPad': 26697.0,
#  '赶集网-工作生活啥都有！': 317.0,
#  'The Sims 3 Ambitions': 14202.0,
#  'Bookshelf': 2064.0,
#  'QQ同步助手-新机一键换机必备工具': 746.0,
#  'Der Feueralarm': 0.0,
#  'POF - Best Dating App for Conversations': 52642.0,
#  'NFL': 27317.0,
#  'Vernier Video Physics': 76.0,
#  'Instagram': 2161558.0,
#  'Due — Reminders, Countdown Timers': 2554.0,
#  'UFO on Tape': 1058.0,
#  'Catan HD': 10382.0,
#  'Polar Plunge ™': 1428.0,
#  'Sunday Ticket': 3134.0,
#  '央视影音HD-海量央视内容高清直播': 596.0,
#  'Neuroshima Hex': 4378.0,
#  'Maps 3D PRO - GPS for Bike, Hike, Ski & Outdoor': 280.0,
#  'ArtRage': 1045.0,
#  'Sleep Talk Recorder': 1110.0,
#  'Spider Solitaire by MobilityWare': 11154.0,
#  'iSleeping by iSommeil SARL': 0.0,
#  '中国建设银行': 258.0,
#  'Lane Splitter': 44567.0,
#  'Ryder Cup 2016 – Hazeltine National Golf Club': 3818.0,
#  'Noteshelf': 7562.0,
#  'The Legend of Spookley the Square Pumpkin': 120.0,
#  'BUBBLE BOBBLE DOUBLE': 206.0,
#  'Paprika Recipe Manager': 1755.0,
#  'ToonCamera': 1037.0,
#  'Sonic The Hedgehog 4™ Episode I': 4755.0,
#  'Cisco AnyConnect': 825.0,
#  'GroupMe': 28260.0,
#  '招商银行': 306.0,
#  'Jenga': 32527.0,
#  'Zappos: shop shoes & clothes, fast free shipping': 103655.0,
#  'Printer Pro - Print photos, pdf and emails': 15981.0,
#  'Sephora Makeup & Beauty App – Insider Tips & Style': 15593.0,
#  '欧路英语词典 Eudic 增强版': 206.0,
#  '爱奇艺 - 电视剧电影综艺娱乐视频播放器': 786.0,
#  'Mathmateer®': 1207.0,
#  'Battleheart': 6879.0,
#  'Youku HD': 5683.0,
#  'Bowitter for iPhone': 0.0,
#  'Need for Speed™ Hot Pursuit': 5059.0,
#  'Instant Heart Rate+: Heart Rate & Pulse Monitor': 10158.0,
#  '去哪儿旅行-预订机票酒店火车票特价旅游自由行': 291.0,
#  'NOAA Hurricane Center': 31.0,
#  'CVS Pharmacy': 35981.0,
#  'Age of Zombies™': 14493.0,
#  'AVPlayer': 853.0,
#  '土豆视频HD—高清影视综艺视频播放器': 990.0,
#  '土豆（短视频分享平台）': 676.0,
#  'Spider Solitaire Free by MobilityWare': 128739.0,
#  'The Calculator': 1556.0,
#  'Game Dev Story': 12331.0,
#  'French Words for Kids - Learn Letter Sounds': 22.0,
#  'Death Worm': 6527.0,
#  'Cartoon Wars 2: Heroes': 13049.0,
#  'MSNBC': 3692.0,
#  'Super Stickman Golf': 41446.0,
#  'Black Friday 2017 Ads App - BlackFriday.fm': 8221.0,
#  'Hotel Dash Deluxe': 36190.0,
#  'Backbreaker 2: Vengeance': 14491.0,
#  'The Calculator - Free and Easy Calculating!': 99244.0,
#  '出会い系アプリ i-Mail（アイメール）': 0.0,
#  'Angry Birds Seasons HD': 75714.0,
#  'Gravity Guy': 35161.0,
#  'Fooducate - Lose Weight, Eat Healthy,Get Motivated': 11875.0,
#  '招商银行信用卡掌上生活': 122.0,
#  'myChevrolet': 1083.0,
#  'Puzzle Quest 2': 1575.0,
#  'Mountain Biker': 24.0,
#  'Yurekuru Call': 53.0,
#  'Stratego® Single Player': 739.0,
#  'Text Free: Free Texting + Calling + MMS': 100477.0,
#  '腾讯新闻-头条新闻热点资讯掌上阅读软件': 718.0,
#  'Merriam-Webster Dictionary': 16849.0,
#  '中国银行手机银行': 192.0,
#  'Learn English quickly with MosaLingua': 7.0,
#  "Reiner Knizia's Ra": 1114.0,
#  'Guitar Pro': 1218.0,
#  'Flick Golf!': 9948.0,
#  'DirectVR Remote for DirecTV': 528.0,
#  'World of Goo': 4675.0,
#  'Airbnb': 22302.0,
#  'UPAD 3': 3849.0,
#  'Tagesschau': 233.0,
#  'iExit Interstate Exit Guide': 1798.0,
#  'Genius Scan+ - PDF Scanner': 916.0,
#  'iSafe Pro': 2956.0,
#  'NBA JAM by EA SPORTS™': 21648.0,
#  'iHandy Translator Pro': 5163.0,
#  'AR Missile - Automatic Target Tracking': 49.0,
#  'QuakeFeed Earthquake Map, Alerts, and News': 6081.0,
#  'Dungeon Raid': 4401.0,
#  'Badoo Premium - Meet new people. Extra features.': 2231.0,
#  'Fruit Ninja®': 327025.0,
#  'LEGO Harry Potter: Years 1-4': 10463.0,
#  'Rat On A Skateboard': 28672.0,
#  'iTrackBites Plus - Smart Weight Loss Tracker & Points Calculator for Diet Nutrition Watchers': 4716.0,
#  'Pocket God: Journey To Uranus': 6278.0,
#  'ファッション通販 ZOZOTOWN': 0.0,
#  'Bloons TD 4': 8304.0,
#  'Cartoon Network App – Teen Titans Go! And more!': 15984.0,
#  'SkyView® - Explore the Universe': 5079.0,
#  'Coach Guitar - Lessons & Easy Tabs For Beginners': 2416.0,
#  'Lobi': 36.0,
#  'MONOPOLY for iPad': 8165.0,
#  '聚力视频HD-人民的名义,跨界歌王全网热播': 7446.0,
#  'Eden - World Builder': 26419.0,
#  'Holiday Greetings - 3D Animations, Emoji, Emoticons, Sounds & Videos for Special Occasions': 208.0,
#  'Puffin Browser Pro': 7565.0,
#  '8mm Vintage Camera': 3040.0,
#  'GasBuddy': 145549.0,
#  'Paprika Recipe Manager for iPhone': 835.0,
#  'BillMinder - Bill Reminder and Organizer': 4262.0,
#  'myCardLists Christmas Card Address Label Printing': 219.0,
#  'Capital One Mobile': 56110.0,
#  'HotelTonight - Great Deals on Last Minute Hotels': 32341.0,
#  'The 7th Guest': 1419.0,
#  'Stack the Countries®': 3303.0,
#  '腾讯视频HD-楚乔传,明日之子6月全网首播': 2058.0,
#  'Secret of Mana': 990.0,
#  'AVPlayerHD': 1986.0,
#  'SimplePhysics': 8981.0,
#  'Hot Springs Story': 554.0,
#  'The Guardian': 8176.0,
#  "Annabel Karmel's Baby & Toddler Recipe App": 53.0,
#  'SecurityCam for iPhone': 6.0,
#  'La Banque Postale': 8.0,
#  'My Score Plus Weight Loss, Food & Exercise Tracker': 467.0,
#  '爱奇艺HD -《欢乐颂2》电视剧热播': 2394.0,
#  'Quit Pro': 287.0,
#  'Splice - Video Editor + Movie Maker by GoPro': 28189.0,
#  'Localscope - Find places and people around you': 868.0,
#  'Slingo Supreme HD': 4094.0,
#  'VLC Streamer': 3152.0,
#  'Low Carb Diet Tracker PRO by Carb Manager': 2950.0,
#  'NOAA Weather Radio': 3245.0,
#  'Mad Skills Motocross': 9341.0,
#  'Pearson eText': 981.0,
#  'QWOP for iOS': 735.0,
#  'Sleep Pillow Sounds: white noise, rain, ocean, fan': 15116.0,
#  'Microsoft OneNote': 39638.0,
#  'PlayStation®App': 7256.0,
#  'Scan - QR Code and Barcode Reader': 12590.0,
#  'Carnivores: Ice Age Pro': 13258.0,
#  '花しらべ 花認識/花検索': 0.0,
#  'Fighter Verses - memorize bible verses': 331.0,
#  'Schoology': 1777.0,
#  'iDarkroom': 554.0,
#  'GolfNow – Book Tee Times, Golf GPS, Scorecard': 7535.0,
#  'Hudl': 2622.0,
#  '乐视视频HD-白鹿原,欢乐颂,奔跑吧全网热播': 2340.0,
#  'TEDiSUB - Enjoy TED Talks with Subtitles': 823.0,
#  'SkyDroid - Golf GPS': 261.0,
#  'Verbrechen - echte Polizeifälle aus Deiner Umgebung': 0.0,
#  'Legendary Wars': 29739.0,
#  'ナビタイム ドライブサポーター - NAVITIMEのカーナビアプリ': 0.0,
#  'Weather Radio by WDT': 1359.0,
#  'Home Design 3D - 3D Printing Edition': 6001.0,
#  "マクドナルド - McDonald's Japan": 10.0,
#  'SkyView® Free - Explore the Universe': 4188.0,
#  '搜房网房天下-新房二手房租房交易平台': 89.0,
#  'WordFoto': 513.0,
#  'IRS2Go': 1329.0,
#  '手机京东-首次购买可领取188元优惠券': 361.0,
#  '搜狐视频HD-欢乐颂2 全网首播': 3768.0,
#  'WeChat': 34584.0,
#  'QQ音乐-来这里“发现・音乐”': 745.0,
#  'Google Translate': 26786.0,
#  'Pocket Casts': 1911.0,
#  'The Lost City': 1393.0,
#  'Tasty Planet': 430.0,
#  'Feed the Head': 193.0,
#  'ContactsBook -AddressBook Organizer': 7.0,
#  '安居客-二手房、新房、租房的找房助手': 84.0,
#  '汽车之家-提供新车,二手车报价及资讯': 116.0,
#  'PhotoSync – transfer and backup photos & videos': 4352.0,
#  'My Verizon': 126948.0,
#  'Meitu': 6478.0,
#  'Talking Ben the Dog for iPad': 31116.0,
#  '中国联通手机营业厅客户端(官方版)': 248.0,
#  'Bodyweight Training: You Are Your Own Gym': 3326.0,
#  '唯品会-欢乐颂2独家电商 同款热卖': 100.0,
#  'GMX Mail': 102.0,
#  'Talking Carl': 3662.0,
#  'Tiny Wings': 219418.0,
#  'NOAA Weather Alerts - Severe Weather Push Notifications & Warnings': 2293.0,
#  'Bleacher Report: Sports news, scores, & highlights': 16979.0,
#  'TuneIn Radio - MLB NBA Audiobooks Podcasts Music': 110420.0,
#  'iTheme - Themes for iPhone and iPad': 4719.0,
#  'Bitauto Autoprice': 157.0,
#  'Math Fact Master: Addition, Subtraction, Multiplication, and Division': 1537.0,
#  'Lieferando.de': 29.0,
#  '万年历-值得信赖的日历黄历查询工具': 2270.0,
#  'Temple Run': 1724546.0,
#  'Angry Birds Rio': 170843.0,
#  'Angry Birds Rio HD': 70122.0,
#  "My Baby's Beat - Prenatal Listener": 1887.0,
#  'My Horse': 293857.0,
#  'iStatVball 2 iPad Edition': 193.0,
#  'Magic Piano by Smule': 131695.0,
#  'DIRECTV App for iPad': 47506.0,
#  'PodCruncher podcast app - Player and manager for podcasts': 2261.0,
#  'Shell Shock 1.5': 26.0,
#  'Talking Tom Cat 2 for iPad': 56399.0,
#  'MTV': 5987.0,
#  'Tiny Tower - Free City Building': 414803.0,
#  'Gmail - email by Google: secure, fast & organized': 135962.0,
#  'OneCam': 0.0,
#  '美团 - 吃喝玩乐全都有': 549.0,
#  'Chess Pro - with coach': 10619.0,
#  "NCAA March Madness Live - Men's College Basketball": 13572.0,
#  'Catholic New American Bible Revised Edition': 149.0,
#  'Planimeter - Measure Land Area and Distance on a Map': 249.0,
#  '中国工商银行': 152.0,
#  'Bumpy Road': 1073.0,
#  'Dude Perfect': 9763.0,
#  'Countdown‼ (Event Reminders and Timer)': 60490.0,
#  'Dude Perfect HD': 2552.0,
#  'FINAL FANTASY III': 1378.0,
#  '苏宁易购-新人专享大礼包': 38.0,
#  'SPIEGEL ONLINE - Nachrichten': 299.0,
#  'Superbrothers: Sword & Sworcery EP': 5362.0,
#  'Procreate – Sketch, paint, create.': 6109.0,
#  '网易新闻 - 精选好内容，算出你的兴趣': 4263.0,
#  'Tiny Planet Photos and Video': 714.0,
#  'Touchgrind BMX': 3170.0,
#  'QQ浏览器HD-极速搜索浏览器': 936.0,
#  'QR Reader for iPad': 1341.0,
#  'NBA JAM by EA SPORTS™ for iPad': 4934.0,
#  'Toca Hair Salon': 9649.0,
#  'Showroomprive - Private Fashion Sales': 11.0,
#  'Bloons TD 4 HD': 2493.0,
#  'Elmo Loves ABCs for iPad': 1888.0,
#  'Forbidden Island': 923.0,
#  '1号店-全球超市 轻松到家': 65.0,
#  '易到 - 低价专车,高品质出行': 115.0,
#  'Expedia Hotels, Flights & Vacation Package Deals': 10278.0,
#  'YY- 小全民手机直播交友软件': 624.0,
#  'ooVoo – Free Video Call, Text and Voice': 177501.0,
#  'Virtual Villagers 4: The Tree of Life': 500.0,
#  'WatchESPN': 159735.0,
#  'Pinterest': 1061624.0,
#  'iFunny :)': 98344.0,
#  'HBO GO': 26278.0,
#  'Flashlight ！': 35769.0,
#  'DEATHSMILES': 540.0,
#  'QQ音乐HD': 224.0,
#  'Talking Pierre the Parrot for iPad': 11665.0,
#  'Photon Flash Player for iPad - Flash Video & Games plus Private Web Browser': 20951.0,
#  'Rota Calendar - Work Shift Manager': 43.0,
#  'Site Audit Pro': 125.0,
#  "It's Tyrannosaurus Rex - Smithsonian Institution": 92.0,
#  'FINAL FANTASY III for iPad': 857.0,
#  'True Red Eye Remover HD-Face Recovery': 528.0,
#  'Tikal': 626.0,
#  '美丽说-潮流穿搭快人一步': 1026.0,
#  'Phone Drive - File Manager, Browser & Explorer': 1403.0,
#  'Fake Location': 117.0,
#  'Summer Games 3D': 193.0,
#  'Classic Explain Everything™': 896.0,
#  'The JMU Bus App': 35.0,
#  'ROBLOX': 183621.0,
#  'Pocket Academy': 616.0,
#  '知乎': 397.0,
#  'プチ・ロワイヤル仏和辞典（第4版）・和仏辞典（第3版）': 0.0,
#  'Round1 お得なクーポン毎週配信！': 0.0,
#  'Ticket to Ride': 4866.0,
#  'Dice With Buddies: Fun New Social Dice Game': 20355.0,
#  'Money Origami - Learn How to Fold Money': 6.0,
#  'Cloud Baby Monitor ~ Video, Audio, Unlimited Range': 1855.0,
#  'STREET FIGHTER IV VOLT': 9741.0,
#  'FL Studio Mobile': 818.0,
#  'Qzone HD': 458.0,
#  'PicFrame': 6374.0,
#  'Bank of America - Mobile Banking for iPad': 7569.0,
#  'Nyan Cat: Lost In Space': 76392.0,
#  'ZOOKEEPER\u3000DX': 274.0,
#  'Fishing Kings Free+': 35058.0,
#  'Werewolf "Nightmare in Prison"': 78.0,
#  'PhotoToaster - Photo Editor, Filters, Effects and Borders': 4748.0,
#  'Bike Baron': 12162.0,
#  'Moji Weather - Free Weather Forecast': 2333.0,
#  '京东 HD': 150.0,
#  'Toca Robot Lab': 1006.0,
#  'Viator Tours & Activities': 1839.0,
#  'Lookout: Security and Identity Theft Protection': 2661.0,
#  'PBS KIDS Video': 8651.0,
#  'LetterSchool - learn to write letters and numbers': 460.0,
#  'Kurumaki Calendar -month scroll calendar-': 34.0,
#  'Building Parallel Circuits': 32.0,
#  'HappyCow Vegan / Vegetarian Restaurant Guide': 863.0,
#  'Building Serial Circuits': 23.0,
#  'Superimpose': 2965.0,
#  'ComicBook!': 3702.0,
#  'Jelly Defense': 5058.0,
#  'Learn to Speak Italian Fast With MosaLingua': 0.0,
#  "Domino's Pizza USA": 258624.0,
#  'Junk Jack Retro': 8632.0,
#  'FiLMiC Pro': 1478.0,
#  'AliExpress Shopping App': 10647.0,
#  '搜狐新闻—新闻热点资讯掌上阅读软件': 383.0,
#  'ZDFmediathek': 320.0,
#  'Digital Domain': 102.0,
#  'SayHi Translate': 8623.0,
#  'Tank Hero': 14361.0,
#  '聚力视频-蓝光电视剧电影在线热播': 1670.0,
#  'TextGrabber – image to text: OCR & translate photo': 1153.0,
#  '淘宝HD－Taobao for iPad': 1103.0,
#  'Timenote': 11.0,
#  'Snapseed': 8683.0,
#  '北京浮生记': 44.0,
#  'My PlayHome': 3523.0,
#  '腾讯手机管家-拦截骚扰电话的QQ安全助手': 527.0,
#  '5K Runner: 0 to 5K Run Trainer. Couch potato to 5K': 10368.0,
#  'Magic Jigsaw Puzzles': 187666.0,
#  'DragonVale': 503230.0,
#  'SHADOWGUN': 4513.0,
#  'PlayerXtreme Media Player PRO - Movies & streaming': 125.0,
#  'Lieferheld - Delicious food delivery service': 29.0,
#  'Kwai - Share your video moments': 668.0,
#  'ibis Paint - speed painting': 112.0,
#  '360手机卫士-超安全的来电防骚扰助手': 944.0,
#  'Photo Lab: Picture Editor, effects & fun face app': 34585.0,
#  'ConjuVerb - Spanish Verb Conjugation Helper': 406.0,
#  'Skype for iPad': 60163.0,
#  'Book Creator for iPad': 415.0,
#  'Modern Combat 3: Fallen Nation': 23766.0,
#  'Toca Store': 1595.0,
#  'NBC – Watch Now and Stream Full TV Episodes': 55950.0,
#  'CCW – Concealed Carry 50 State Guide': 644.0,
#  'TOEIC®テスト文法640問1': 0.0,
#  'Camera360 - Selfie Filter Camera, Photo Editor': 16729.0,
#  'Hotspot Shield Free VPN Proxy & Wi-Fi Privacy': 32499.0,
#  'Racing Penguin Free - Top Flying and Diving Game': 141224.0,
#  'Fitness Buddy+ Gym Workout Exercise, Home Trainer': 10386.0,
#  'LINE': 11437.0,
#  '驴妈妈旅游-订景点门票机票火车票特价酒店': 30.0,
#  'Calculator for iPad Free.': 4021.0,
#  'NOAA Hurricane Center HD': 43.0,
#  'Jesus Calling Devotional by Sarah Young': 1685.0,
#  'ADP Mobile Solutions': 8324.0,
#  'Daily Audio Bible App': 796.0,
#  'Scribblenauts Remix': 86127.0,
#  'QQ': 9109.0,
#  'Talking Tom & Ben News for iPad': 20988.0,
#  'Calc for Loan': 0.0,
#  'LOVOO - Dating Chat': 1985.0,
#  '爱奇艺PPS -《欢乐颂2》电视剧热播': 14844.0,
#  '当当-正品秒杀，首单立减5元': 65.0,
#  'Phoenix HD': 13106.0,
#  'Zaim': 44.0,
#  'MailShot Pro- Group Email Done Right!': 425.0,
#  'Human Anatomy Atlas – 3D Anatomical Model of the Human Body': 1298.0,
#  '欢乐斗地主•腾讯': 403.0,
#  'Virtual Villagers 5: New Believers': 309.0,
#  'FINAL FANTASY TACTICS: THE WAR OF THE LIONS': 5180.0,
#  '自転車ナビ by NAVITIME(ナビタイム) - 自転車のナビができるアプリ': 0.0,
#  'Reckless Getaway': 18259.0,
#  'Snapchat': 323905.0,
#  '途牛旅游-订机票酒店，查旅行景点门票': 51.0,
#  'PDF Converter - Convert Documents, Photos to PDF': 1294.0,
#  'Auto Palmistry': 5.0,
#  'Muffin Knight': 9302.0,
#  'Infinity Blade II': 153588.0,
#  'Quick Scan Pro - Barcode Scanner. Deal Finder. Money Saver.': 3837.0,
#  'Sprinkle: Water splashing fire fighting fun!': 10509.0,
#  'Lock Photos & Video.s Vault - Passcode Protect Your Secret Photo Album & Secure Private Picture.s Folders': 4697.0,
#  'Truecaller - Spam Identification & Block': 27791.0,
#  'MOMO陌陌-开启视频社交,用直播分享生活': 1862.0,
#  'Couch to 5K® - Running App and Training Coach': 3820.0,
#  'Pic Collage - Picture Editor & Photo Collage Maker': 123433.0,
#  "Where's My Water?": 131656.0,
#  'United Airlines': 5748.0,
#  'Dictionary.com Premium Dictionary & Thesaurus for iPad': 4922.0,
#  'Cut the Rope: Experiments': 63272.0,
#  'The Singing Machine Mobile Karaoke App': 130.0,
#  'ibis Paint X - speed painting': 1933.0,
#  'VIBO RealMassager': 6.0,
#  'Peggle Classic HD': 3912.0,
#  'Monkey Math School Sunshine': 1092.0,
#  'Conservative Talk Radio': 2436.0,
#  'Azuki Wave': 14.0,
#  '蘑菇街-网红直播搭配的购物特卖平台': 558.0,
#  '百度地图-智能的手机导航，公交地铁出行必备': 1014.0,
#  'Smilebox Moments - Collages, Stickers, Filters, Frames & Animations': 4510.0,
#  'Gangstar Rio: City of Saints': 14724.0,
#  '去哪儿旅行HD-总有你要的低价': 85.0,
#  '咕咚-你的跑步骑行运动社区': 160.0,
#  'Photon Flash Player for iPhone - Flash Video & Games plus Private Web Browser': 4676.0,
#  'Knots 3D': 3196.0,
#  'Sight Recover 3D': 1.0,
#  'Kazehakase fu-ring bank - Tokoname & Nanbu': 0.0,
#  '飞猪': 154.0,
#  'QQ HD': 5058.0,
#  'Bon Appetit': 750.0,
#  'Skins Pro Creator for Minecraft': 7943.0,
#  'Flick Home Run !': 98851.0,
#  'STEINS;GATE': 16.0,
#  'Sonic CD': 16358.0,
#  'Messenger': 351466.0,
#  'Zombieville USA 2': 79683.0,
#  'F18 Carrier Landing': 4656.0,
#  'Flick Champions HD': 7289.0,
#  'Programme TV Télé Loisirs': 23.0,
#  "White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game": 60.0,
#  'Flashlight ◎': 24744.0,
#  'Real Steel': 24880.0,
#  'Pinball Arcade Plus': 3716.0,
#  'QQ游戏大厅HD': 338.0,
#  'Doodle Jump FREE - BE WARNED: Insanely addictive': 28153.0,
#  'Pearson eText for Schools': 609.0,
#  'Jetpack Joyride': 405647.0,
#  'FotoRus -Camera & Photo Editor & Pic Collage Maker': 32558.0,
#  'Catholic Bible': 999.0,
#  'Doodle Jump HD': 8580.0,
#  'ASOS': 9725.0,
#  'NOAA Hi-Def Radar Pro -  Storm Warnings, Hurricane Tracker & Weather Forecast': 15809.0,
#  'eHarmony™ Dating App - Meet Singles': 11124.0,
#  '腾讯视频-欢乐颂2全网首播': 613.0,
#  'Calculator ∞': 1138.0,
#  '搜狐视频-欢乐颂2 全网首播': 774.0,
#  'Abby Monkey® Basic Skills: Preschool and Kindergarten Kids Educational Early Learning Adventure Games.▫ TeachMe Counting, Colors, Alphabet, Math, Numbers, Shapes Sorting, Patterns, Puzzles, Learn to Read Letters for Toddler Children': 358.0,
#  '唯品会 HD 全球精选，正品特卖': 68.0,
#  'Top Eleven 2017 - Be a Soccer Manager': 14104.0,
#  'Machinarium': 7919.0,
#  'Tenuto': 562.0,
#  'STREET FIGHTER II COLLECTION': 242.0,
#  'Twitch': 109549.0,
#  'Watch TNT': 6856.0,
#  'Kids Doodle - Movie Kids Color & Draw': 8025.0,
#  'Written Legends: Nightmare at Sea HD (Full)': 234.0,
#  'Drum Beats+ (Rhythm Metronome, Loops & Grooves Machine)': 879.0,
#  'Real Fishing 3D': 880.0,
#  'Trello': 2793.0,
#  '高德地图（精准专业的手机地图）': 1040.0,
#  '广东移动手机营业厅-话费流量一手掌握，专属优惠定期发放': 33.0,
#  "Puppet Pals HD Director's Pass": 54.0,
#  'Fisheye Lens - Retro Style Fisheye Camera': 2485.0,
#  'Waking Mars': 2101.0,
#  'Fitbit': 90496.0,
#  'Watch TBS': 4050.0,
#  'twinkle': 5.0,
#  'HISTORY Here': 685.0,
#  'The Official DVSA Theory Test Kit for Car Drivers': 0.0,
#  'Meitu HD': 2150.0,
#  'Railway Route Search': 5.0,
#  'PINK Nation': 49816.0,
#  "Ricky Carmichael's Motocross Matchup Pro": 4498.0,
#  'Phonics Island • Early Reading, Spelling & Tracing Montessori Preschool and Kindergarten Kids Learning Adventure Games by Abby Monkey® Alphabet and Letter Sounds Reader': 199.0,
#  'LotteryHUB': 2417.0,
#  'Infinite Campus Mobile Portal': 2286.0,
#  'Perfect Image - Pic Collage Maker, Add Text to Photo, Cool Picture Editor': 1646.0,
#  'NHL': 15554.0,
#  'Cronometer': 210.0,
#  'Zen Pinball': 6534.0,
#  'Green Kitchen – healthy vegetarian recipes': 311.0,
#  'HB2 PLUS': 54073.0,
#  'The Sims™ FreePlay': 446880.0,
#  '百度糯米-电影,美食团购': 383.0,
#  'Mathway - Math Problem Solver': 1854.0,
#  'Elmo Calls': 1915.0,
#  'AEO|Aerie: Jeans, Dresses, Swimsuits & Bralettes': 6408.0,
#  'Loopy HD': 561.0,
#  'Best Hunting Times': 123.0,
#  'SamCard Pro-card reader&business card scanner&ocr': 875.0,
#  'Daily Classifieds for iPhone': 7973.0,
#  'Runtastic Road Bike GPS Cycling Route Tracker PRO': 3800.0,
#  'Tasty Planet: Back for Seconds': 264.0,
#  'Tasty Planet: Back for Seconds HD': 135.0,
#  'Scanner911 HD Police Radio Pro': 204.0,
#  'OfferUp - Buy. Sell. Simple.': 57348.0,
#  '随手记专业版 for  iPad': 240.0,
#  'HP All-in-One Printer Remote': 9819.0,
#  'Adobe Acrobat Reader: View, Create, & Convert PDFs': 20069.0,
#  '飞常准Pro-全球航班查询机票酒店预订': 132.0,
#  'MEGA MAN X': 3099.0,
#  'CSR Racing': 677247.0,
#  'Riptide GP': 3883.0,
#  'Math Practice - Integers': 11.0,
#  'Khan Academy: you can learn anything': 5459.0,
#  'Bejeweled Blitz': 221002.0,
#  'Lloyds Bank Mobile Banking': 17.0,
#  'Sleepy Hollow: Mystery Legends HD (Full)': 168.0,
#  'Poshmark: Buy & Sell Fashion': 18035.0,
#  'Secret Calculator Pro - Hide photos & videos': 2504.0,
#  'Call of Duty: Black Ops Zombies': 116601.0,
#  ...}

# %%
len(reviews_max_as)
# Out:
# 7195

# %%
ios_cleaned = [] 
already_added_ios = [] 

for app in apple_store_data[1:]: 
    name=app[2]
    n_reviews = app[6]
    
    if (n_reviews == reviews_max_as[name]) and (name not in already_added_ios): 
        ios_cleaned.append(app)
        already_added_ios.append(name)

# %%
#By conducting a quick check, we know 
for app in google_store_data: 
    name = app[0]
    if name =='Instagram': 
        print(app)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %%
duplicate_apps_gs = []
unique_apps_gs = []

for apps in google_store_data: 
    name = apps[0]
    if name in unique_apps_gs: 
        duplicate_apps_gs.append(name)
    else: 
        unique_apps_gs.append(name)

print('Duplicate Apps Count:', len(duplicate_apps_gs))
print('\n')
print('Examples of Duplicate Apps:', duplicate_apps_gs[:20])
# Out:
# Duplicate Apps Count: 1181
#
#
# Examples of Duplicate Apps: ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack', 'FreshBooks Classic', 'Insightly CRM', 'QuickBooks Accounting: Invoicing & Expenses', 'HipChat - Chat Built for Teams', 'Xero Accounting Software', 'MailChimp - Email, Marketing Automation', 'Crew - Free Messaging and Scheduling', 'Asana: organize team projects', 'Google Analytics', 'AdWords Express']

# %% [markdown]
# Since there are 1181 duplicate applications, I will need to not include these in the analysis. Thus, it becomes clear that I will have to re-adjust the number of applications (scope to include) within the analysis

# %%
duplicate_app_count_gs = 1181 
adjusted_length_google_ds = len(google_store_data[1:])- duplicate_app_count_gs 
print(adjusted_length_google_ds)
# Out:
# 9659

# %% [markdown]
# <h3> Removing Duplicates Strategically </h3>
#
# Rather than removing duplicate rows at random, I would like to devise a small but effective strategy - for the purpose of this analysis - to remove the duplicate values. In checking the above example for duplicates with the name Instagram, it becomes clearly evident that the main difference between the duplicate values is the number of reviews (4th column).
#
# That makes sense. The dataset contains multiple duplicate values for Instagram due to the fact  that multiple entries were made after the number of reviews was updated. Following the same line of logic, it would be logical to conclude that the higher the number of ratings in our duplicate columns, the more recent the data is - which is what we should be using to carry out our analysis.

# %%
#Removing the Duplicates via Dictionary Method: 
#Each Dictionary Key will be a unique Application Name 
#Each Value will be it's highest rating count 
reviews_max_gs = {}
for app in google_store_data[1:]: 
    name = app[0]
    n_reviews = float(app[3])
    
    if name in reviews_max_gs and reviews_max_gs[name]<n_reviews: 
        reviews_max_gs[name] = n_reviews
    elif name not in reviews_max_gs: 
        reviews_max_gs[name] = n_reviews

        
#Pseudo Code
#If the name of the application exists in the dictionary: this will create the dictionary
#The key will be application name and if the value of what already exists for each name is less than 
#The number of reviews

# %%
reviews_max_gs
# Out:
# {'Photo Editor & Candy Camera & Grid & ScrapBook': 159.0,
#  'Coloring book moana': 967.0,
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps': 87510.0,
#  'Sketch - Draw & Paint': 215644.0,
#  'Pixel Draw - Number Art Coloring Book': 967.0,
#  'Paper flowers instructions': 167.0,
#  'Smoke Effect Photo Maker - Smoke Editor': 178.0,
#  'Infinite Painter': 36815.0,
#  'Garden Coloring Book': 13791.0,
#  'Kids Paint Free - Drawing Fun': 121.0,
#  'Text on Photo - Fonteee': 13880.0,
#  'Name Art Photo Editor - Focus n Filters': 8788.0,
#  'Tattoo Name On My Photo Editor': 44829.0,
#  'Mandala Coloring Book': 4326.0,
#  '3D Color Pixel by Number - Sandbox Art Coloring': 1518.0,
#  'Learn To Draw Kawaii Characters': 55.0,
#  'Photo Designer - Write your name with shapes': 3632.0,
#  '350 Diy Room Decor Ideas': 27.0,
#  'FlipaClip - Cartoon animation': 194216.0,
#  'ibis Paint X': 224399.0,
#  'Logo Maker - Small Business': 450.0,
#  "Boys Photo Editor - Six Pack & Men's Suit": 654.0,
#  'Superheroes Wallpapers | 4K Backgrounds': 7699.0,
#  'Mcqueen Coloring pages': 61.0,
#  'HD Mickey Minnie Wallpapers': 118.0,
#  'Harley Quinn wallpapers HD': 192.0,
#  'Colorfit - Drawing & Coloring': 20260.0,
#  'Animated Photo Editor': 203.0,
#  'Pencil Sketch Drawing': 136.0,
#  'Easy Realistic Drawing Tutorial': 223.0,
#  'Pink Silver Bow Keyboard Theme': 1120.0,
#  'Art Drawing Ideas': 227.0,
#  'Anime Manga Coloring Book': 5035.0,
#  'Easy Origami Ideas': 1015.0,
#  'I Creative Idea': 353.0,
#  'How to draw Ladybug and Cat Noir': 564.0,
#  'UNICORN - Color By Number & Pixel Art Coloring': 8145.0,
#  'Floor Plan Creator': 36639.0,
#  'PIP Camera - PIP Collage Maker': 158.0,
#  'How To Color Disney Princess - Coloring Pages': 591.0,
#  'Drawing Clothes Fashion Ideas': 117.0,
#  'Sad Poetry Photo Frames 2018': 176.0,
#  'Textgram - write on photos': 295221.0,
#  'Paint Splash!': 2206.0,
#  'Popsicle Sticks and Similar DIY Craft Ideas': 26.0,
#  'Canva: Poster, banner, card maker & graphic design': 174531.0,
#  'Install images with music to make video without Net - 2018': 1070.0,
#  'Little Teddy Bear Colouring Book Game': 85.0,
#  'How To Draw Food': 845.0,
#  'Monster Truck Stunt 3D 2019': 367.0,
#  'Real Tractor Farming': 1598.0,
#  'Ultimate F1 Racing Championship': 284.0,
#  'Used Cars and Trucks for Sale': 17057.0,
#  'American Muscle Car Race': 129.0,
#  'Offroad Oil Tanker Driver Transport Truck 2019': 542.0,
#  'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru': 10479.0,
#  'Gas Prices (Germany only)': 805.0,
#  'Extreme Rally Championship': 129.0,
#  'Restart Navigator': 1403.0,
#  'REG - Check the regnumber, find information about Swedish vehicles': 3971.0,
#  'CityBus Lviv': 534.0,
#  'CDL Practice Test 2018 Edition': 7774.0,
#  'ezETC (ETC balance inquiry, meter trial, real-time traffic)': 38846.0,
#  'Free VIN Report for Used Cars': 2431.0,
#  'DMV Permit Practice Test 2018 Edition': 6090.0,
#  'Check Vehicle Tax': 295.0,
#  'Used Cars Mexico': 190.0,
#  'Ulysse Speedometer': 40211.0,
#  'REPUVE': 356.0,
#  'Used cars for sale - Trovit': 52530.0,
#  'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines': 116986.0,
#  'SK Enca Direct Malls - Used Cars Search': 1379.0,
#  'Android Auto - Maps, Media, Messaging & Voice': 271920.0,
#  'PDD-UA': 736.0,
#  'Tickets SDA 2019 + Exam RF': 7021.0,
#  'Super Cars Wallpapers And Backgrounds': 197.0,
#  'Police Lights, Sirens & Follow Me': 737.0,
#  'Police Detector (Speed Camera Radar)': 3574.0,
#  'Best Car Wallpapers': 994.0,
#  'Tickets + PDA 2018 Exam': 197136.0,
#  'Pick Your Part Garage': 142.0,
#  'PakWheels: Buy & Sell Cars': 15168.0,
#  'Supervision service': 2155.0,
#  'Speed Camera Detector - Traffic & Speed Alert': 138.0,
#  'Used car search Goo net whole car Go to net': 5414.0,
#  'CarMax – Cars for Sale: Search Used Car Inventory': 21777.0,
#  'BEST CAR SOUNDS': 348.0,
#  'RST - Sale of cars on the PCT': 250.0,
#  'AutoScout24 Switzerland – Find your new car': 13372.0,
#  'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo': 7880.0,
#  'SMS Park': 3617.0,
#  'SKencar': 4806.0,
#  'Fuelio: Gas log & costs': 65786.0,
#  'auto fines': 31433.0,
#  'Used car is the first car - used car purchase, used car quotation, dealer information to': 5097.0,
#  'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)': 1754.0,
#  'Inquiry Fines and Debits of Vehicles': 2680.0,
#  'Gas Station': 1288.0,
#  'Hush - Beauty for Everyone': 18900.0,
#  'ipsy: Makeup, Beauty, and Tips': 49790.0,
#  'Natural recipes for your beauty': 1150.0,
#  'BestCam Selfie-selfie, beauty camera, photo editor': 1739.0,
#  'Mirror - Zoom & Exposure -': 32090.0,
#  'Beauty Selfie Camera': 2225.0,
#  'Hairstyles step by step': 4369.0,
#  'Filters for Selfie': 8572.0,
#  'Tie - Always be happy': 964.0,
#  'Ulta Beauty': 42050.0,
#  'Prom MakeUp Tutorial': 104.0,
#  'Selfie Camera': 17934.0,
#  'Sweet Selfie Beauty Camera': 601.0,
#  'Colors of white in Urdu': 36.0,
#  'Selfie Camera Photo Editor & Filter & Sticker': 187.0,
#  'Wrinkles and rejuvenation': 182.0,
#  'Eyes Makeup Beauty Tips': 30.0,
#  'Photo Editor 2018': 134.0,
#  'Step By Step Eyes Makeup Tutorial': 74.0,
#  'Beauty Camera - Selfie Camera': 113715.0,
#  'Girls Hairstyles': 3595.0,
#  'Mirror Camera (Mirror + Selfie Camera)': 9315.0,
#  'Beauty Tips - Beauty Tips in Sinhala': 75.0,
#  'Haircut Tutorials/Haircut Videos': 38.0,
#  'Sephora: Skin Care, Beauty Makeup & Fragrance Shop': 26834.0,
#  'Manicure - nail design': 119.0,
#  'Sticker Camera - Selfie Filters, Beauty Camera': 2277.0,
#  'Filters for B Live': 2280.0,
#  'Skin Care and Natural Beauty': 654.0,
#  'Facial Wrinkle Reduction': 184.0,
#  'Makeup Videos': 9.0,
#  'Secrets of beauty, youth and health': 77.0,
#  'Recipes and tips for losing weight': 35.0,
#  'Discover Color': 364.0,
#  'Eyeliner step by step 2018': 18.0,
#  'Dresses Ideas & Fashions +3000': 473.0,
#  'Lady adviser (beauty, health)': 30.0,
#  'Step By Step Hairstyles For Women': 66.0,
#  'Rainbow Camera': 3871.0,
#  'Methods of teeth whitening': 257.0,
#  'Girls hairstyles 2018': 62.0,
#  'Wattpad 📖 Free Books': 2914724.0,
#  'E-Book Read - Read Book for free': 1857.0,
#  'Download free book with green book': 4478.0,
#  'Wikipedia': 577550.0,
#  'Amazon Kindle': 814080.0,
#  'Cool Reader': 246315.0,
#  'Dictionary - Merriam-Webster': 454060.0,
#  'NOOK: Read eBooks & Magazines': 155446.0,
#  'Free Panda Radio Music': 418.0,
#  'Book store': 22486.0,
#  'FBReader: Favorite Book Reader': 203130.0,
#  'English Grammar Complete Handbook': 1435.0,
#  'Free Books - Spirit Fanfiction and Stories': 116507.0,
#  'Google Play Books': 1433233.0,
#  'AlReader -any text book reader': 90468.0,
#  'Offline English Dictionary': 860.0,
#  'Oxford Dictionary of English : Free': 363934.0,
#  'Offline: English to Tagalog Dictionary': 967.0,
#  'Spanish English Translator': 87873.0,
#  'FamilySearch Tree': 17506.0,
#  'Cloud of Books': 1862.0,
#  'Recipes of Prophetic Medicine for free': 2084.0,
#  'ReadEra – free ebook reader': 47303.0,
#  'NOOK App for NOOK Devices': 19080.0,
#  'Anonymous caller detection': 161.0,
#  'Ebook Reader': 85842.0,
#  'Litnet - E-books': 7831.0,
#  'Read books online': 91615.0,
#  'English to Urdu Dictionary': 4620.0,
#  'eBoox: book reader fb2 epub zip': 21336.0,
#  'English Persian Dictionary': 26875.0,
#  'Flybook': 1778.0,
#  'All Maths Formulas': 2709.0,
#  'Ancestry': 64513.0,
#  'HTC Help': 8342.0,
#  'English translation from Bengali': 527.0,
#  'Pdf Book Download - Read Pdf Book': 1322.0,
#  'Free Book Reader': 1680.0,
#  'eBoox new: Reader for fb2 epub zip books': 2739.0,
#  'Only 30 days in English, the guideline is guaranteed': 1065.0,
#  'Moon+ Reader': 233757.0,
#  "SH-02J Owner's Manual (Android 8.0)": 2.0,
#  'English-Myanmar Dictionary': 8788.0,
#  'Golden Dictionary (EN-AR)': 51269.0,
#  'All Language Translator Free': 30105.0,
#  'Azpen eReader': 156.0,
#  'URBANO V 02 instruction manual': 114.0,
#  'English Dictionary - Offline': 341157.0,
#  'Visual Voicemail by MetroPCS': 16129.0,
#  'Indeed Job Search': 674730.0,
#  'Uber Driver': 1254730.0,
#  'ADP Mobile Solutions': 85185.0,
#  'Snag - Jobs Hiring Now': 32584.0,
#  'Docs To Go™ Free Office Suite': 217730.0,
#  'Google My Business': 70991.0,
#  'OfficeSuite : Free Office + PDF Editor': 1002859.0,
#  'USPS MOBILE®': 16589.0,
#  'Job Search by ZipRecruiter': 148945.0,
#  'Curriculum vitae App CV Builder Free Resume Maker': 4458.0,
#  'Google Primer': 62272.0,
#  'Alba Heaven - Alvarez Job Portal Services': 8941.0,
#  'SuperLivePro': 46353.0,
#  'Facebook Pages Manager': 1279184.0,
#  'OfficeSuite Pro + PDF (Trial)': 88073.0,
#  'My Space - Employment Center': 67000.0,
#  'Box': 159872.0,
#  'Polaris Office for LG': 30847.0,
#  'Call Blocker': 17529.0,
#  'Jobs in Alabama - Jobs in Alba': 11622.0,
#  'Square Point of Sale - POS': 95912.0,
#  'Plugin:AOT v5.0': 4034.0,
#  'Kariyer.net': 45964.0,
#  'SEEK Job Search': 14955.0,
#  'Become a Job - Find a job or advertise': 6903.0,
#  'ZOOM Cloud Meetings': 31614.0,
#  'Easy Installer - Apps On SD': 23055.0,
#  'Facebook Ads Manager': 19023.0,
#  'IndiaMART: Search Products, Buy, Sell & Trade': 207372.0,
#  'ViettelPost express delivery': 1225.0,
#  'MyASUS - Service Center': 380837.0,
#  'Job Korea - Career Jobs': 10600.0,
#  '104 Looking for a job - looking for a job, looking for a job, looking for a part-time job, health checkup, resume, treatment room': 74359.0,
#  'Myanmar 2D/3D': 822.0,
#  'Quick PDF Scanner + OCR FREE': 80804.0,
#  'sABN': 2287.0,
#  'ATI Cargoes and Transportation': 4162.0,
#  'Secure Folder': 14760.0,
#  'UPS Mobile': 23243.0,
#  'Y! Mobile menu': 9.0,
#  'SignEasy | Sign and Fill PDF and other Documents': 8978.0,
#  'Genius Scan - PDF Scanner': 42492.0,
#  'Tiny Scanner - PDF Scanner App': 286897.0,
#  'Fast Scanner : Free PDF Scan': 103755.0,
#  'Mobile Doc Scanner (MDScan) Lite': 46505.0,
#  'TurboScan: scan documents and receipts in PDF': 11442.0,
#  'Tiny Scanner Pro: PDF Doc Scan': 10295.0,
#  'Zenefits': 296.0,
#  'Google Ads': 29313.0,
#  'Slack': 51507.0,
#  'FreshBooks Classic': 1802.0,
#  'Insightly CRM': 1383.0,
#  'QuickBooks Accounting: Invoicing & Expenses': 23175.0,
#  'HipChat - Chat Built for Teams': 5868.0,
#  'Xero Accounting Software': 2111.0,
#  'MailChimp - Email, Marketing Automation': 5448.0,
#  'Crew - Free Messaging and Scheduling': 4159.0,
#  'Asana: organize team projects': 20815.0,
#  'Google Analytics': 78662.0,
#  'AdWords Express': 7149.0,
#  'Accounting App - Zoho Books': 3079.0,
#  'Invoice & Time Tracking - Zoho': 5800.0,
#  'join.me - Simple Meetings': 6989.0,
#  'Invoice 2go — Professional Invoices and Estimates': 16422.0,
#  'Cisco Webex Meetings': 108741.0,
#  'ScreenMeet. Easy Phone Meeting': 624.0,
#  'Cisco Webex Teams': 1661.0,
#  'Microsoft Remote Desktop': 97702.0,
#  'Start Meeting': 308.0,
#  'ClickMeeting Webinars': 5211.0,
#  'BlueJeans for Android': 1058.0,
#  'Skype for Business for Android': 78172.0,
#  'Verify - Receipts & Expenses': 413.0,
#  'LINE WEBTOON - Free Comics': 1013635.0,
#  'Manga Master - Best manga & comic reader': 24005.0,
#  'GANMA! - All original stories free of charge for all original comics': 57106.0,
#  'Röhrich Werner Soundboard': 2249.0,
#  'Unicorn Pokez - Color By Number': 516.0,
#  'MangaToon - Comics updated Daily': 834.0,
#  'Manga Net – Best Online Manga Reader': 1010.0,
#  'Manga Rock - Best Manga Reader': 238970.0,
#  'Manga - read Thai translation': 302.0,
#  'The Vietnam Story - Fun Stories': 438.0,
#  'Dragon Ball Wallpaper - Ringtones': 73.0,
#  'Funny Jokes Photos': 39.0,
#  'Truyện Vui Tý Quậy': 144.0,
#  'Comic Es - Shojo manga / love comics free of charge ♪ ♪': 2181.0,
#  'comico Popular Original Cartoon Updated Everyday Comico': 93965.0,
#  'Daily Manga - Comic & Webtoon': 1446.0,
#  '漫咖 Comics - Manga,Novel and Stories': 12088.0,
#  'Emmanuella Funny Videos 2018': 314.0,
#  'DC Comics': 25671.0,
#  'Manga Zero - Japanese cartoon and comic reader': 15194.0,
#  'Marvel Unlimited': 22551.0,
#  'Tapas – Comics, Novels, and Stories': 29839.0,
#  "Children's cartoons (Mithu-Mina-Raju)": 279.0,
#  "Narrator's Voice": 564387.0,
#  '【Ranobbe complete free】 Novelba - Free app that you can read and write novels': 1330.0,
#  'Faustop Sounds': 1677.0,
#  'Manga Mania - Best online manga reader': 757.0,
#  '- Free Comics - Comic Apps': 115.0,
#  'Manga AZ - Manga Comic Reader': 125.0,
#  'Buff Thun - Daily Free Webtoon / Comics / Web Fiction / Mini Game': 9952.0,
#  "pixiv comic - everyone's manga app": 18814.0,
#  'Funny Jokes and Stories 2018': 21.0,
#  'Hojiboy Tojiboyev Life Hacks': 15.0,
#  'Perfect Viewer': 51981.0,
#  'Best Wallpapers Backgrounds(100,000+ 4K HD)': 3596.0,
#  'think Comics': 1006.0,
#  'Memes Button': 5968.0,
#  'Laftel - Watching and Announcing Snooping, Streaming': 4895.0,
#  'Messenger – Text and Video Chat for Free': 56642847.0,
#  'WhatsApp Messenger': 69109672.0,
#  'Messenger for SMS': 125257.0,
#  'Google Chrome: Fast & Secure': 9642112.0,
#  'Messenger Lite: Free Calls & Messages': 1429035.0,
#  'Gmail': 4604324.0,
#  'Hangouts': 3419249.0,
#  'Viber Messenger': 11334799.0,
#  'My Tele2': 158679.0,
#  'Firefox Browser fast & private': 3075028.0,
#  'Yahoo Mail – Stay Organized': 4187998.0,
#  'imo beta free calls and text': 659395.0,
#  'imo free video calls and chat': 4785892.0,
#  'Contacts': 66602.0,
#  'Call Free – Free Call': 30209.0,
#  'Web Browser & Explorer': 36901.0,
#  'Opera Mini - fast web browser': 5149854.0,
#  'Browser 4G': 192948.0,
#  'MegaFon Dashboard': 99559.0,
#  'ZenUI Dialer & Contacts': 437674.0,
#  'Cricket Visual Voicemail': 13698.0,
#  'Opera Browser: Fast and Secure': 2473509.0,
#  'TracFone My Account': 20769.0,
#  'Firefox Focus: The privacy browser': 36880.0,
#  'Google Voice': 171031.0,
#  'Chrome Dev': 63543.0,
#  'Xperia Link™': 45487.0,
#  'TouchPal Keyboard - Fun Emoji & Android Keyboard': 615381.0,
#  'Who': 2451083.0,
#  'Skype Lite - Free Video Call & Chat': 33053.0,
#  'WeChat': 5387333.0,
#  'UC Browser Mini -Tiny Fast Private & Secure': 3648120.0,
#  'WhatsApp Business': 136662.0,
#  'My magenta': 42370.0,
#  'Android Messages': 781810.0,
#  'Telegram': 3128250.0,
#  'Google Duo - High Quality Video Calls': 2083237.0,
#  'Puffin Web Browser': 541389.0,
#  'Seznam.cz': 46702.0,
#  'Antillean Gold Telegram (original version)': 2939.0,
#  'AT&T Visual Voicemail': 13761.0,
#  'GMX Mail': 258556.0,
#  'Omlet Chat': 40751.0,
#  'UC Browser - Fast Download Private & Secure': 17712922.0,
#  'My Vodacom SA': 25021.0,
#  'Microsoft Edge': 27156.0,
#  'Hangouts Dialer - Call Phones': 122498.0,
#  'Talkatone: Free Texts, Calls & Phone Number': 132014.0,
#  'Calls & Text by Mo+': 83239.0,
#  'free video calls and chat': 594720.0,
#  'Skype - free IM & video calls': 10484169.0,
#  'GO SMS Pro - Messenger, Free Themes, Emoji': 2876500.0,
#  'Messaging+ SMS, MMS Free': 28238.0,
#  'chomp SMS': 335646.0,
#  'Glide - Video Chat Messenger': 350154.0,
#  'Text SMS': 349384.0,
#  'Google Allo': 346980.0,
#  'Talkray - Free Calls & Texts': 244863.0,
#  'LINE: Free Calls & Messages': 10790092.0,
#  'GroupMe': 330761.0,
#  'mysms SMS Text Messaging Sync': 37320.0,
#  'BBM - Free Calls & Messages': 12842860.0,
#  'KakaoTalk: Free Calls & Text': 2546527.0,
#  '2ndLine - Second Phone Number': 15880.0,
#  'CM Browser - Ad Blocker , Fast Download , Privacy': 2264916.0,
#  'Ninesky Browser': 42925.0,
#  'Dolphin Browser - Fast, Private & Adblock🐬': 2511130.0,
#  'Ghostery Privacy Browser': 13100.0,
#  'InBrowser - Incognito Browsing': 27156.0,
#  'Web Browser for Android': 55098.0,
#  'DU Browser—Browse fast & fun': 1133501.0,
#  'Lightning Web Browser': 12578.0,
#  'Web Browser': 10965.0,
#  'Puffin Browser Pro': 18247.0,
#  'Contacts+': 190613.0,
#  'ExDialer - Dialer & Contacts': 125232.0,
#  'PHONE for Google Voice & GTalk': 72065.0,
#  'Safest Call Blocker': 27540.0,
#  'Full Screen Caller ID': 104990.0,
#  'Hiya - Caller ID & Block': 177703.0,
#  'Mr. Number-Block calls & spam': 177263.0,
#  'Should I Answer?': 237468.0,
#  'RocketDial Dialer & Contacts': 32254.0,
#  'CallApp: Caller ID, Blocker & Phone Call Recorder': 483565.0,
#  'Whoscall - Caller ID & Block': 552441.0,
#  'CIA - Caller ID & Call Blocker': 60308.0,
#  'Calls Blacklist - Call Blocker': 457283.0,
#  'Call Control - Call Blocker': 93825.0,
#  'True Contact - Real Caller ID': 32283.0,
#  'Video Caller Id': 15287.0,
#  'Sync.ME – Caller ID & Block': 205739.0,
#  'Burner - Free Phone Number': 14873.0,
#  'Truecaller: Caller ID, SMS spam blocking & Dialer': 7820209.0,
#  'Caller ID +': 9498.0,
#  'K-9 Mail': 88427.0,
#  'myMail – Email for Hotmail, Gmail and Outlook Mail': 305218.0,
#  'Email TypeApp - Mail App': 183374.0,
#  'All Email Providers': 20901.0,
#  'Newton Mail - Email App for Gmail, Outlook, IMAP': 122595.0,
#  'GO Notifier': 124346.0,
#  'Mail.Ru - Email App': 837842.0,
#  'Mail1Click - Secure Mail': 255.0,
#  'Daum Mail - Next Mail': 41420.0,
#  'mail.com mail': 44706.0,
#  'SolMail - All-in-One email app': 23707.0,
#  'Vonage Mobile® Call Video Text': 29208.0,
#  'JusTalk - Free Video Calls and Fun Video Chat': 191032.0,
#  'Moco+ - Chat, Meet People': 1545.0,
#  'Calculator': 57.0,
#  'Truth or Dare Pro': 0.0,
#  'Private Dating, Hide App- Blue for PrivacyHider': 0.0,
#  'Ad Blocker for SayHi': 4.0,
#  'AMBW Dating App: Asian Men Black Women Interracial': 2.0,
#  'Zoosk Dating App: Meet Singles': 516801.0,
#  'OkCupid Dating': 285726.0,
#  'Match™ Dating - Meet Singles': 76646.0,
#  'Hily: Dating, Chat, Match, Meet & Hook up': 2556.0,
#  'Hinge: Dating & Relationships': 7779.0,
#  'Casual Dating & Adult Singles - Joyride': 61637.0,
#  'BBW Dating & Plus Size Chat': 12632.0,
#  'Moco - Chat, Meet People': 313724.0,
#  'CMB Free Dating App': 48845.0,
#  'Hot or Not - Find someone right now': 305708.0,
#  'eharmony - Online Dating App': 31320.0,
#  'Free Dating App & Flirt Chat - Match with Singles': 172460.0,
#  'Chispa, the Dating App for Latino, Latina Singles': 4195.0,
#  'Clover Dating App': 11633.0,
#  'Black People Meet Singles Date': 10212.0,
#  'Mingle2 - Free Online Dating & Singles Chat Rooms': 37053.0,
#  'Free Dating App & Flirt Chat - Cheers': 667.0,
#  'stranger chat - anonymous chat': 13202.0,
#  'Blendr - Chat, Flirt & Meet': 28671.0,
#  'Free Dating Hook Up Messenger': 1157.0,
#  'Find Real Love — YouLove Premium Dating': 212626.0,
#  'Once - Quality Matches Every day': 222888.0,
#  'BLK - Swipe. Match. Chat.': 2067.0,
#  'Cougar Dating Life : Date Older Women Sugar Mummy': 1643.0,
#  'Howlr': 105.0,
#  'Stranger Chat & Date': 3414.0,
#  'Free Dating & Flirt Chat - Choice of Love': 42194.0,
#  'RandoChat - Chat roulette': 11806.0,
#  'BeWild Free Dating & Chat App': 1999.0,
#  'FastMeet: Chat, Dating, Love': 22544.0,
#  'Free Dating App - YoCutie - Flirt, Chat & Meet': 97684.0,
#  'OurTime Dating for Singles 50+': 2519.0,
#  'FarmersOnly Dating': 1145.0,
#  'Dating for 50 plus Mature Singles – FINALLY': 13046.0,
#  'Sudy – Meet Elite & Rich Single': 17268.0,
#  'Christian Dating For Free App': 8722.0,
#  'Just She - Top Lesbian Dating': 953.0,
#  'Single Parent Meet #1 Dating': 2593.0,
#  'EliteSingles – Dating for Single Professionals': 5377.0,
#  'Millionaire Match: Rich Singles Dating App': 852.0,
#  'InterracialCupid - Interracial Dating App': 212.0,
#  'Sugar Mommas Dating And Single Search': 1972.0,
#  'Hide App, Private Dating, Safe Chat - PrivacyHider': 35205.0,
#  'muzmatch: Muslim & Arab Singles, Marriage & Dating': 5164.0,
#  'NoBuffDating - Free Dating App': 1939.0,
#  'Sugar Daddy Dating App': 277.0,
#  'Adult Dirty Emojis': 80.0,
#  'Free Dating App - Meet Local Singles - Flirt Chat': 825.0,
#  'Meet4U - Chat, Love, Singles!': 40035.0,
#  'SnpCupid Dating': 1093.0,
#  'Chat Rooms, Avatars, Date - Galaxy': 135418.0,
#  'Adult Dating - AdultFinder': 1601.0,
#  'Gay Sugar Daddy Dating & Hookup – Sudy Gay': 2212.0,
#  'Meet24 - Love, Chat, Singles': 57081.0,
#  'BBWCupid - BBW Dating App': 241.0,
#  'ChatVideo Meet new people': 63986.0,
#  'TryDate - Free Online Dating App, Chat Meet Adults': 7888.0,
#  'Black White Interracial Dating - Interracial Match': 535.0,
#  'USA Singles Meet, Match and Date Free - Date': 5084.0,
#  'FlirtChat - ♥Free Dating/Flirting App♥': 2430.0,
#  'The League': 837.0,
#  'Herpes Dating: 1,000K+ Singles': 738.0,
#  'Heart mill': 4631.0,
#  '95Live -SG#1 Live Streaming App': 4953.0,
#  'Mutual - LDS Dating': 1439.0,
#  '2RedBeans': 337.0,
#  'SweetRing - Meet, Match, Date': 51698.0,
#  'BiggerCity: Chat for gay bears, chubs & chasers': 923.0,
#  'SilverSingles: The 50+ Dating App': 149.0,
#  'Herpes Positive Singles Dating': 198.0,
#  'Glam - Premium Dating App': 23170.0,
#  'iDates - Chats, Flirts, Dating, Love & Relations': 13890.0,
#  'JustDating': 13440.0,
#  'Interracial Match Dating App': 143.0,
#  'Russian Dating & Chat for Russian speaking RusDate': 1059.0,
#  'Sky People (SPI): A secure blind date through authentication by Seoul National University': 894.0,
#  'Sweet mi - unlimited hunnam hunting blind date': 6191.0,
#  'Mingle - Online Dating App to Chat & Meet People': 15081.0,
#  'BBW Dating & Curvy Singles Chat- LargeFriends': 218.0,
#  'Hitwe - meet people and chat': 243950.0,
#  'A hundred': 236.0,
#  'JustSayHi- Dating App. Chat & Meet Singles Nearby': 5152.0,
#  'FERZU - Furries Social Network': 1576.0,
#  'WannaMeet – Dating & Chat App': 6701.0,
#  'Luxy Pro- Elite Dating Single': 742.0,
#  'Dating Network': 187.0,
#  'Chatting - Free chat, random chat, boyfriend, girlfriend': 2506.0,
#  'iPair-Meet, Chat, Dating': 182986.0,
#  'Meet, chat & date. Free dating app - Chocolate app': 8661.0,
#  'Transenger – Ts Dating and Chat for Free': 8.0,
#  'O-Star': 59.0,
#  'Free Cam Girls - Live Webcam': 35.0,
#  'Cardi B Live Stream Video Chat - Prank': 28.0,
#  'Live Girls Talk - Free Video Chat': 125.0,
#  'Live Talk - Free Text and Video Chat': 185.0,
#  'Chat Kids - Chat Room For Kids': 6.0,
#  'Girls Live Chat - Free Text & Video Chat': 110.0,
#  'Random Video Chat': 3.0,
#  'MouseMingle': 3.0,
#  'American Girls Mobile Numbers': 5.0,
#  'Random Video Chat App With Strangers': 3.0,
#  'FREE VIDEO CHAT - LIVE VIDEO AND TEXT CHAT': 84.0,
#  'Awake Dating': 2.0,
#  'Live Chat - Free Video Chat Rooms': 20.0,
#  'Meet With Strangers: Video Chat & Dating': 2.0,
#  'FREE LIVE TALK': 776.0,
#  'Random Chat App with Strangers': 2.0,
#  'Ost. Zombies Cast - New Music and Lyrics': 1.0,
#  'Dating White Girls': 0.0,
#  'Live Chat - Free Video Talk': 14.0,
#  'Geeks Dating': 0.0,
#  'Live chat - free video chat': 1.0,
#  'House party - live chat': 1.0,
#  'Fishing Brain & Boating Maps Marine': 3.0,
#  'CAM5678 Video Chat': 0.0,
#  'Video chat live advices': 0.0,
#  'chat live chat': 24.0,
#  'Pet Lovers Dating': 0.0,
#  'Friend Find: free chat + flirt dating app': 23.0,
#  'Latin Dating': 0.0,
#  'Spine- The dating app': 5.0,
#  'Online Chat Girls Meet': 18.0,
#  'Wifi Mingle': 0.0,
#  'Girls Live Talk - Free Text and Video Chat': 6.0,
#  'Soy Luna - Top Music And Lyrics': 1.0,
#  'When Will You Get Married': 2.0,
#  'HOW TO ASK A GIRL OUT': 0.0,
#  'Online Girls Chat Group': 5.0,
#  'The DJ - Match with People': 0.0,
#  'Toronto Dating': 0.0,
#  'i miss you quotes and photos': 0.0,
#  'JoJo Siwa Top Hits Music': 0.0,
#  'UK Girls Mobile Numbers': 1.0,
#  'chat saudi arabia': 11.0,
#  'Chat Click - Dating Search': 4.0,
#  'Iraq love chat': 14.0,
#  'Healthy Relationships Guide': 0.0,
#  'following': 1.0,
#  'Gods by Night': 104.0,
#  'PlusOne': 0.0,
#  'Love Calendar - Couple Sharing Calendar & CoupleDay': 14.0,
#  'Speeding Joyride & Car Meet App': 3.0,
#  'LOBSTR - go on a lunch date': 101.0,
#  'Titanic App - Feminist Dating Application': 120.0,
#  'French Chat Room': 24.0,
#  'Soul Mate': 0.0,
#  'Diamond Engagement Rings': 0.0,
#  'Dating Tips For Men': 0.0,
#  'Halalguur': 6.0,
#  'Find Lover': 21.0,
#  '2Date Dating App, Love and matching': 41605.0,
#  'Teenage Chat & Dating': 5.0,
#  'Girls Online Talk - Free Text and Video Chat': 791.0,
#  'Online Girls Chat': 5323.0,
#  'LIVE VIDEO TALK': 478.0,
#  'SkyLove – Dating and chat': 69.0,
#  'Free Live Talk-Video Call': 158.0,
#  'FindLoving': 24.0,
#  'Sugar Daddies Dating App': 53.0,
#  'Chat Mexico: meet people, flirt and friendship': 8.0,
#  'Duolingo: Learn Languages Free': 6289924.0,
#  'TED': 181893.0,
#  'English Communication - Learn English for Chinese (Learn English for Chinese)': 2544.0,
#  'Khan Academy': 85375.0,
#  'Learn English with Wlingua': 314299.0,
#  'Ai La Trieu Phu - ALTP Free': 776.0,
#  'Princess Coloring Book': 9770.0,
#  'Learn Spanish - Español': 32346.0,
#  'English Grammar Test': 4075.0,
#  'Speed Reading': 10611.0,
#  'English for beginners': 9321.0,
#  'Flame - درب عقلك يوميا': 56065.0,
#  'Mermaids': 14286.0,
#  'Learn Japanese, Korean, Chinese Offline & Free': 133136.0,
#  'Kids Mode': 2469.0,
#  'PBS KIDS Video': 36212.0,
#  'Dinosaurs Coloring Pages': 390.0,
#  'Cars Coloring Pages': 1090.0,
#  'Babbel – Learn Languages': 266935.0,
#  'Math Tricks': 342918.0,
#  'Monster Truck Driver & Racing': 748.0,
#  'Learn English Words Free': 172640.0,
#  'Japanese / English one-shop search dictionary - Free Japanese - English - Japanese dictionary application': 61.0,
#  'English speaking texts': 1619.0,
#  'Thai Handwriting': 3168.0,
#  'THAI DICT 2018': 29855.0,
#  'Kanji test · Han search Kanji training (free version)': 6736.0,
#  "Game for KIDS: KIDS match'em": 7005.0,
#  'Flippy Campus - Buy & sell on campus at a discount': 889.0,
#  'Free intellectual training game application |': 5741.0,
#  'ABC Preschool Free': 27572.0,
#  'PINKFONG Baby Shark': 10852.0,
#  'English words application mikan': 9888.0,
#  'Learn English for beginners': 1929.0,
#  'Listen and learn English in seven days': 1516.0,
#  'Lumosity: #1 Brain Games & Cognitive Training App': 215301.0,
#  'Learn English from Persian: Persian to English': 423.0,
#  'English with Lingualeo': 254519.0,
#  'Learn languages, grammar & vocabulary with Memrise': 1107884.0,
#  'Quizlet: Learn Languages & Vocab with Flashcards': 211856.0,
#  'Udemy - Online Courses': 99020.0,
#  'Coursera: Online courses': 90481.0,
#  'edX - Online Courses by Harvard, MIT & more': 32380.0,
#  'Elevate - Brain Training Games': 248912.0,
#  'NeuroNation - Focus and Brain Training': 248555.0,
#  'Peak – Brain Games & Training': 272145.0,
#  'Memorado - Brain Games': 56897.0,
#  'Lynda - Online Training Videos': 8599.0,
#  'Brilliant': 41185.0,
#  'CppDroid - C/C++ IDE': 29978.0,
#  'Quiz&Learn Python': 304.0,
#  'C++ Tutorials': 358.0,
#  'C++ Programming': 11904.0,
#  'C Programming': 22248.0,
#  'Udacity - Lifelong Learning': 22384.0,
#  'Learn C++': 73404.0,
#  'Learn programming': 12733.0,
#  'Learn JavaScript': 25183.0,
#  'Learn Java': 52743.0,
#  'Learn HTML': 61749.0,
#  'Programming Hub, Learn to code': 55704.0,
#  'Learn SQL': 19277.0,
#  'Ready4 SAT (Prep4 SAT)': 13612.0,
#  'Socratic - Math Answers & Homework Help': 37862.0,
#  'Ready4 GMAT (Prep4 GMAT)': 18372.0,
#  'Pocket GMAT Math': 656.0,
#  'GMAT Question Bank': 240.0,
#  'GRE Tutor': 275.0,
#  'GRE Flashcards': 13791.0,
#  'play2prep: ACT, SAT prep': 3692.0,
#  'SAT Test': 2363.0,
#  'GMAT Math Flashcards': 1769.0,
#  'Pocket SAT Math': 430.0,
#  'TOEFL Prep & Practice from Magoosh': 756.0,
#  'GRE Prep & Practice by Magoosh': 3963.0,
#  'GRE® Flashcards by Kaplan': 316.0,
#  'SAT Vocabulary': 642.0,
#  'Magoosh GMAT Prep & Practice': 1058.0,
#  'SAT Flashcards: Prep & Vocabulary': 2277.0,
#  'Rosetta Stone: Learn to Speak & Read New Languages': 172505.0,
#  'Google Classroom': 69493.0,
#  'LinkedIn Learning: Online Courses to Learn Skills': 7973.0,
#  'Learn English with Phrases': 5695.0,
#  'Free english course': 142632.0,
#  'Learn 50 languages': 55256.0,
#  'Babbel – Learn Spanish': 54798.0,
#  'Mango Languages: Lovable Language Courses': 4815.0,
#  'Learn English with Aco': 75112.0,
#  'Learn to Speak English': 33646.0,
#  'busuu: Learn Languages - Spanish, English & More': 206527.0,
#  'My Class Schedule: Timetable': 9348.0,
#  'Study Checker': 3816.0,
#  'My Study Life - School Planner': 47847.0,
#  'HomeWork': 16195.0,
#  'Next Gen Science Standards': 206.0,
#  'myHomework Student Planner': 28392.0,
#  "Teacher's Gradebook - Additio": 3241.0,
#  'Common Core': 835.0,
#  'Homework Planner': 2525.0,
#  'TeachersPayTeachers': 828.0,
#  'Edmodo': 200058.0,
#  'Socrative Teacher': 1239.0,
#  'Training schedule - AllUniver': 702.0,
#  'Remind: School Communication': 108613.0,
#  'ClassDojo': 148536.0,
#  'Lerni. Learn languages.': 3847.0,
#  'HelloTalk — Chat, Speak & Learn Foreign Languages': 84309.0,
#  'Innovative: Learn 34 Languages': 14206.0,
#  'Chegg Study - Homework Help': 14700.0,
#  'Canvas Student': 42828.0,
#  'Timetable': 40209.0,
#  'EasyBib: Citation Generator': 1405.0,
#  'SoloLearn: Learn to Code for Free': 256079.0,
#  'Kids Learn Languages by Mondly': 2078.0,
#  'Blinkist - Nonfiction Books': 16103.0,
#  'Sago Mini Hat Maker': 11.0,
#  'Fuzzy Numbers: Pre-K Number Foundation': 21.0,
#  'Toca Life: City': 31085.0,
#  'Toca Life: Hospital': 3528.0,
#  'Netflix': 5453997.0,
#  'Complete Spanish Movies': 11656.0,
#  'Pluto TV - It’s Free TV': 28948.0,
#  'Tubi TV - Free Movies & TV': 296771.0,
#  'YouTube Kids': 469851.0,
#  'Mobile TV': 10939.0,
#  'TV+': 98509.0,
#  'Digital TV': 5241.0,
#  'Motorola Spotlight Player™': 22508.0,
#  'Vigo Lite': 10291.0,
#  'Google Play Games': 7165362.0,
#  'Hotstar': 4885646.0,
#  'Peers.TV: broadcast TV channels First, Match TV, TNT ...': 141980.0,
#  'The green alien dance': 6979.0,
#  'Spectrum TV': 46618.0,
#  'H TV': 103064.0,
#  'StarTimes - Live International Champions Cup': 17682.0,
#  'Cinematic Cinematic': 37000.0,
#  'MEGOGO - Cinema and TV': 175528.0,
#  'Talking Angela': 1828284.0,
#  'DStv Now': 34923.0,
#  'ivi - movies and TV shows in HD': 684116.0,
#  'Radio Javan': 46916.0,
#  'Viki: Asian TV Dramas & Movies': 407698.0,
#  'Talking Ginger 2': 702975.0,
#  'Girly Lock Screen Wallpaper with Quotes': 32458.0,
#  'No.Draw - Colors by Number 2018': 235496.0,
#  '🔥 Football Wallpapers 4K | Full HD Backgrounds 😍': 11661.0,
#  'Movies by Flixster, with Rotten Tomatoes': 653008.0,
#  'Low Poly – Puzzle art game': 23063.0,
#  'BBC Media Player': 87384.0,
#  'Amazon Prime Video': 411683.0,
#  'Adult Glitter Color by Number Book - Sandbox Pages': 8918.0,
#  'IMDb Movies & TV': 501497.0,
#  'Twitch: Livestream Multiplayer Games & Esports': 2133047.0,
#  'Ziggo GO': 29690.0,
#  'YouTube Gaming': 130549.0,
#  'PlayStation App': 613059.0,
#  'Talking Ben the Dog': 1633565.0,
#  'Red Bull TV: Live Sports, Music & Entertainment': 42050.0,
#  'Trailer Addict Movie Trailers': 2646.0,
#  'Cinemark Theatres': 21867.0,
#  'Regal Cinemas': 32732.0,
#  'Fandango Movies - Times + Tickets': 243747.0,
#  'Marcus Theatres': 2639.0,
#  'Harkins Theatres': 1511.0,
#  'AMC Theatres': 44550.0,
#  'Food Network': 7813.0,
#  'Cooking Channel': 1033.0,
#  'Animal Planet GO': 2442.0,
#  'VRV: Anime, game videos & more': 15254.0,
#  'DramaFever: Stream Asian Drama Shows & Movies': 155234.0,
#  'Crunchyroll - Everything Anime': 310066.0,
#  'Investigation Discovery GO': 12216.0,
#  'Crackle - Free TV & Movies': 388089.0,
#  'CBS - Full Episodes & Live TV': 92058.0,
#  'STARZ': 88185.0,
#  'Acorn TV: World-class TV from Britain and Beyond': 493.0,
#  'HISTORY: Watch TV Show Full Episodes & Specials': 33387.0,
#  'Nick': 123279.0,
#  'VH1': 27424.0,
#  'FOX NOW - On Demand & Live TV': 60841.0,
#  'A&E - Watch Full Episodes of TV Shows': 29706.0,
#  'The CW': 288150.0,
#  'BET NOW - Watch Shows': 14807.0,
#  'Hulu: Stream TV, Movies & more': 319691.0,
#  'HBO NOW: Stream TV & Movies': 61201.0,
#  'Univision NOW - Live TV and On Demand': 22997.0,
#  'SHOWTIME': 12398.0,
#  'Lifetime - Watch Full Episodes & Original Movies': 35928.0,
#  'SeriesGuide – Show & Movie Manager': 64448.0,
#  'Comedy Central': 22378.0,
#  'CW Seed': 16372.0,
#  'The NBC App - Watch Live TV and Full Episodes': 58028.0,
#  'WWE': 736824.0,
#  'Universal Kids': 1968.0,
#  'MTV': 35279.0,
#  'LEGO® TV': 17247.0,
#  'HBO GO: Stream with TV Package': 87723.0,
#  'Showtime Anytime': 18522.0,
#  'PlayKids - Educational cartoons and games for kids': 182103.0,
#  'FOX': 197774.0,
#  'Telemundo Now': 8674.0,
#  'Vudu Movies & TV': 58082.0,
#  'Yidio: TV Show & Movie Guide': 27424.0,
#  'Redbox': 115033.0,
#  'Tribeca Shortlist - Handpicked Movies': 801.0,
#  'Nick Jr. - Shows & Games': 8968.0,
#  'Sticker Market: Emoji keyboard': 303.0,
#  'Kidjo TV Kids Have Fun & Learn': 732.0,
#  'Laugh Out Loud by Kevin Hart': 1856.0,
#  'ColorFul - Adult Coloring Book': 50725.0,
#  'Hamilton — The Official App': 1575.0,
#  'My Talking Pet': 6238.0,
#  'Funny Pics': 9941.0,
#  'Funny Quotes Free': 23666.0,
#  'LOL Pics (Funny Pictures)': 67554.0,
#  'Meme Creator': 38769.0,
#  'Imgur: Find funny GIFs, memes & watch viral videos': 160164.0,
#  'Meme Generator': 3771.0,
#  'SketchBook - draw and paint': 256664.0,
#  'Colorfy: Coloring Book for Adults - Free': 787107.0,
#  'All Events in City': 3782.0,
#  'Ticketmaster Event Tickets': 40113.0,
#  'Reminder': 7074.0,
#  'Birdays - Birthday reminder': 2153.0,
#  'StubHub - Tickets to Sports, Concerts & Events': 26089.0,
#  'Fever': 20611.0,
#  'DroidAdmin for Android - Advice': 811.0,
#  'SeatGeek – Tickets to Sports, Concerts, Broadway': 15558.0,
#  'my4D': 573.0,
#  'VAN NIAN 2018 - Vietnamese Calendar': 37.0,
#  'Vivid Seats – Event Tickets': 8232.0,
#  'Name days': 3089.0,
#  'LBB - Find New & Unique Things To Do Around You': 3874.0,
#  'Happy Birthday Songs Offline': 464.0,
#  'Series Valley of the Wolves full of part': 731.0,
#  'Mummatikabalkuragi': 69.0,
#  'Gametime - Tickets to Sports, Concerts, Theater': 8800.0,
#  'PTI Flex Maker, Photo Frame Editor & Songs 2018': 99.0,
#  'Wipe out': 30.0,
#  'Birthdays & Other Events': 456.0,
#  'Sarajevo Film Festival - Official': 6.0,
#  'Summer Madness': 4.0,
#  'Events High - Meet Your City!': 3200.0,
#  'vide-greniers.org': 5839.0,
#  'SUMMER SONIC app': 4.0,
#  'Quake & Volcanoes: 3D Globe of Volcanic Eruptions': 663.0,
#  'Prosperity': 16.0,
#  "Picktrainer: India's largest photo contest app": 1065.0,
#  'AAS-IN-ASIA 2018': 3.0,
#  'Moot Peru 2018': 13.0,
#  'FM News': 46.0,
#  'Goldstar: Live Event Tickets': 1953.0,
#  'Emmabodafestivalen': 12.0,
#  'KudaGo - things to do in NY': 4298.0,
#  'Mindvalley U Tallinn 2018': 1.0,
#  'Rockmaraton Info': 49.0,
#  'Freitas Auctioneer Official': 100.0,
#  'mobLee Events': 11.0,
#  'Xceed - Clubs, DJs, Festivals & Tickets': 399.0,
#  'AMM Events & CPD': 5.0,
#  'Arab Halls - For Wedding & Events': 28.0,
#  'MeAuDote - An act of love that saves a life': 250.0,
#  'TCF National Conference': 1.0,
#  'Endurance Lifestyle': 7.0,
#  'K PLUS': 124324.0,
#  'ING Banking': 39041.0,
#  'Citibanamex Movil': 52306.0,
#  'The postal bank': 36718.0,
#  'KTB Netbank': 42644.0,
#  'Mobile Bancomer': 278082.0,
#  'Nedbank Money': 6076.0,
#  'SCB EASY': 112656.0,
#  'CASHIER': 335738.0,
#  'Rabo Banking': 31906.0,
#  'Capitec Remote Banking': 20672.0,
#  'Itau bank': 957973.0,
#  'Nubank': 130582.0,
#  'The Societe Generale App': 31218.0,
#  'IKO': 167168.0,
#  'Cash App': 34428.0,
#  'Standard Bank / Stanbic Bank': 15247.0,
#  'Bualuang mBanking': 48445.0,
#  'Intesa Sanpaolo Mobile': 35518.0,
#  'UBA Mobile Banking': 12185.0,
#  'BBVA Spain': 36746.0,
#  'MyMo by GSB': 21996.0,
#  'VTB-Online': 138371.0,
#  'Ecobank Mobile Banking': 12073.0,
#  'Banorte Movil': 111632.0,
#  'Wells Fargo Mobile': 250706.0,
#  'Credit Karma': 706301.0,
#  'BZWBK24 mobile': 64959.0,
#  'PayPal': 659741.0,
#  'Capital One® Mobile': 510392.0,
#  'Zenith Bank Mobile App': 7215.0,
#  'GCash - Buy Load, Pay Bills, Send Money': 25508.0,
#  'Post Bank': 60449.0,
#  'İşCep': 381788.0,
#  "People's Bank": 10697.0,
#  'Google Pay': 347838.0,
#  'Transfer': 31804.0,
#  'T-Mobile in': 3856.0,
#  'TrueMoney Wallet': 199684.0,
#  'Alfa-Bank (Alfa-Bank)': 44545.0,
#  'Bank of Brazil': 1336246.0,
#  'WiseBanyan - Invest For Free': 257.0,
#  'Robinhood - Investing, No Fees': 57493.0,
#  'Wells Fargo Daily Change': 283.0,
#  'Even - organize your money, get paid early': 12304.0,
#  'Digit Save Money Automatically': 8188.0,
#  'Stash: Invest. Learn. Save.': 11919.0,
#  'Acorns - Invest Spare Change': 45957.0,
#  'Money Lover: Expense Tracker, Budget Planner': 126431.0,
#  'Expense IQ Money Manager': 21570.0,
#  'Money Manager Expense & Budget': 134564.0,
#  'Prism Pay Bills, Track Money, Personal Finance': 16961.0,
#  'Monefy - Money Manager': 111254.0,
#  'Simple - Better Banking': 7731.0,
#  'Chime - Mobile Banking': 5928.0,
#  'Bluebird by American Express': 15703.0,
#  'Walmart MoneyCard': 6148.0,
#  'Moven - Smart Finances': 861.0,
#  'Qapital - Save Small. Live Large': 8662.0,
#  'Experian - Free Credit Report': 23130.0,
#  'Branch': 69973.0,
#  'WalletHub - Free Credit Score, Report & Monitoring': 1311.0,
#  'CreditWise from Capital One': 26587.0,
#  'NerdWallet: Personal Finance, Credit Score & Cash': 2417.0,
#  'my face': 1054.0,
#  'Credit Sesame': 25166.0,
#  'Mint: Budget, Bills, Finance': 129304.0,
#  'Fresh EBT - Food Stamp Balance': 19870.0,
#  'Hurdlr: Track Mileage, Expenses, and Log Receipts': 3596.0,
#  'Mobills: Budget Planner': 161440.0,
#  'Everlance: Free Mileage Log': 7514.0,
#  'MileIQ - Free Mileage Tracker for Business': 46106.0,
#  'QuickBooks Self-Employed:Mileage Tracker and Taxes': 15141.0,
#  'FREE Stock Market Trading Tips': 714.0,
#  'MetaTrader 5': 42410.0,
#  'MetaTrader 4': 260547.0,
#  'Stock Quote': 4344.0,
#  'Seeking Alpha': 22808.0,
#  'Stock Trainer: Virtual Trading (Stock Markets)': 42809.0,
#  'Stocks: Realtime Quotes Charts': 16808.0,
#  'Stocks, Forex, Bitcoin, Ethereum: Portfolio & News': 157505.0,
#  'CNBC: Breaking Business News & Live Market Data': 24647.0,
#  'US Stock Market': 1922.0,
#  'Bloomberg Professional': 3334.0,
#  'E*TRADE Mobile': 10657.0,
#  'MSN Money- Stock Quotes & News': 78361.0,
#  'Fox Business': 2594.0,
#  'NSE Mobile Trading': 13868.0,
#  'Yahoo Finance': 135952.0,
#  'JStock - Stock Market, Portfolio & News': 11066.0,
#  'Webull - Stock Quotes & Free Stock Trading': 34861.0,
#  'Trading 212 - Forex, Stocks, CFDs': 37580.0,
#  'Moneycontrol – Stocks, Sensex, Mutual Funds, IPO': 281485.0,
#  'Current debit card and app made for teens': 685.0,
#  'Betterment': 3780.0,
#  'Citizens Bank Mobile Banking': 15192.0,
#  'GoBank': 5950.0,
#  'NetSpend Prepaid': 15993.0,
#  'BBVA Compass Banking': 5905.0,
#  'BankMobile Vibe App': 14627.0,
#  'Netspend Skylight ONE': 1098.0,
#  'ACE Elite': 2898.0,
#  'U.S. Bank': 70782.0,
#  'Huntington Mobile': 11264.0,
#  'USAA Mobile': 100997.0,
#  'Associated Credit Union Mobile': 3290.0,
#  'Bank of America Mobile Banking': 341090.0,
#  'USE Credit Union Mobile': 964.0,
#  'Discover Mobile': 87951.0,
#  'Amex Mobile': 24729.0,
#  'Citi Mobile®': 78306.0,
#  'Navy Federal Credit Union': 43313.0,
#  'Chase Mobile': 1374549.0,
#  'HDFC Bank MobileBanking': 208463.0,
#  'Barclays US for Android': 6998.0,
#  "McDonald's": 145323.0,
#  'Easy and Fast Recipes': 95.0,
#  'Cookpad - FREE recipe search makes fun cooking · musical making!': 64784.0,
#  'DELISH KITCHEN - FREE recipe movies make food fun and easy!': 32997.0,
#  'Sumine side dish - dish recipe side dish': 82.0,
#  'Easy Recipes': 2707.0,
#  'Delicious Recipes': 129737.0,
#  'Tastely': 611136.0,
#  'Pastry & Cooking (Without Net)': 6118.0,
#  'Frigo Magic: Easy recipe idea and anti-waste': 2473.0,
#  "McDonald's - McDonald's Japan": 109784.0,
#  'Debonairs Pizza': 3320.0,
#  'Popeyes® App': 61.0,
#  "Dunkin' Donuts": 68103.0,
#  'Pyaterochka': 8412.0,
#  'Refreshing app Free application that can use deal coupons': 10741.0,
#  'Simple Recipes': 3803.0,
#  'Grubhub: Food Delivery': 155944.0,
#  'Panera Bread': 10159.0,
#  'Chick-fil-A': 27931.0,
#  'hellofood - Food Delivery': 43614.0,
#  'Starbucks': 455377.0,
#  'Easy and quick desserts': 1398.0,
#  "Domino's Pizza USA": 1032935.0,
#  'Chef - Recipes & Cooking': 32405.0,
#  'Delivery Club-food delivery: pizza, sushi, burger, salad': 151080.0,
#  'HungerStation': 22513.0,
#  'Delivery yogi.': 90042.0,
#  'Delivery trough - delivery trough delivery trough': 58316.0,
#  'Dr. Oetker recipe ideas': 8509.0,
#  'SONIC Drive-In': 19314.0,
#  'SUBWAY®': 21314.0,
#  'GialloZafferano: Recipes': 30224.0,
#  'Dairy Queen': 731.0,
#  '9th stage': 454.0,
#  'OpenRice': 14952.0,
#  'SarashpazPapion (Cooking with Chef Bowls)': 1250.0,
#  'Little Caesars': 1726.0,
#  'Recipes Pastries and homemade pies More than 500 recipes for pastries': 14065.0,
#  'Om Waleed Sweets': 556.0,
#  'Eat Fast Prepare "Without Internet"': 4925.0,
#  'Wendy’s – Food and Offers': 6507.0,
#  'My Recipes Cookbook : RecetteTek': 11707.0,
#  'Healthy Recipes Free': 1077.0,
#  'Cookbook Recipes': 46539.0,
#  'ChefTap Recipes & Grocery List': 9066.0,
#  'Recipe Keeper': 1962.0,
#  'My CookBook (Recipe Manager)': 22071.0,
#  ...}

# %% [markdown]
# <h3> Affirming our Dictionary Contains no Duplicate Values </h3>
#
# Upon knowing that our target number of items for the dataset (after removing duplicates) is 9659, the above process creates a dictionary where each key is a unique application name, and the value is the highest number of reviews of that application.
#
# Because the length of the dictionary below matches that of our target, I was successfully able to remove the duplicate values from the data.

# %%
#Inspecting the Dictionary 
print(len(reviews_max_gs))
# Out:
# 9659

# %%
android_cleaned = [] #This list will store the new cleaned data 
already_added = [] #This list will store the names of the applications only. 

for app in google_store_data[1:]: 
    name = app[0]
    n_reviews = float(app[3])
    if (n_reviews ==reviews_max_gs[name]) and (name not in already_added): 
        android_cleaned.append(app)
        already_added.append(name)

# %%
#Explore this cleaned data: 
explore_data(android_cleaned, 0,5,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 9659
# Number of columns: 13

# %%
duplicate_values_android_cleaned = [] 
unique_values_android_cleaned = []

for app in android_cleaned: 
    name = app[0]
    if name in unique_values_android_cleaned: 
        duplicate_values_android_cleaned.append(app)
    else: 
        unique_values_android_cleaned.append(app)
print('Duplicate values Updated:', len(duplicate_values_android_cleaned))
print(" ")
print("Now, I have affirmed that there are truly no duplicate values in the android application dataset.")
# Out:
# Duplicate values Updated: 0
#
# Now, I have affirmed that there are truly no duplicate values in the android application dataset

# %% [markdown]
# <h3> Data Cleaning </h3>
#
# Another extremely relevant application will be cleaning the dataset and removing applications created for a Non-English audience. Since, I am only interested in English applications - as this is the focus of development for our company - I will need to remve the Non-English applications from both of the datasets.
#
# In order to remove the Non-English applications, I will be testing each iterable within the Name of an Application to test whether or not the Application is intended for an English audience.
#
# Thus, I will be utilizing the <b> ord </b> function to carry out this process. I will start by creating a definition called - english_detector.
#
# english_detector will return a boolean value (True) if the name of the application is, indeed, English and english_detector will also return another boolean value (False) if the name of the application is non-english.
#
# According to the American Standard Code for Information Interchange, the numbers corresponding to the characters we commonly use in an English text are within the range of 0 to 127.

# %%
def english_detector(string): 
    for character in string: 
        if ord(character) > 127: 
            return False 
    return True

# %%
#Testing the english_detector function
non_english_character = '爱奇艺PPS -《欢乐颂2》电视剧热播'
english_character = 'Spotify'
english_string_with_symbols = 'Docs To Go™ Free Office Suite'
english_string_with_emojis = 'Instachat 😜'
print(english_detector(non_english_character))
print(english_detector(english_character))
print(english_detector(english_string_with_symbols))
print(english_detector(english_string_with_emojis))
# Out:
# False
# True
# False
# False

# %% [markdown]
# Though the definition above correctly identifies plain text english characters, it does not handle english strings with symbols nor does it handle english strings with emojis. Thus, if I were to use the above function, I would actually end up using useful data since many English apps with special characters might be labeleed as non-English.
#
# I will have to make a few adjustments. To minimize the impact of data loss, I'll only remove an app if it's name has more than three characters falling outside of the ASCII range of 127.
#
# Therefore, all English apps with up to three emojis or special characters will still be labeled as English apps.

# %%
def english_detector(string): 
    non_ascii = 0
    
    for character in string:
        if ord(character) > 127:
            non_ascii += 1
    
    if non_ascii > 3:
        return False
    else:
        return True

# %%
print(english_detector(non_english_character))
print(english_detector(english_character))
print(english_detector(english_string_with_symbols))
print(english_detector(english_string_with_emojis))
# Out:
# False
# True
# True
# True

# %%
android_english = []
ios_english = []

for app in android_cleaned:
    name = app[0]
    if english_detector(name):
        android_english.append(app)
        
for app in apple_store_data:
    name = app[2]
    if english_detector(name):
        ios_english.append(app)
        
explore_data(android_english, 0, 3, True)
print('\n')
explore_data(ios_english, 0, 3, True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# Number of rows: 6184
# Number of columns: 17

# %% [markdown]
# Isolating Free Apps
# Basically this is filter savagery without Pandas using Pythonifius

# %%
android_free = [] 
ios_free = [] 

for app in android_english: 
    name = app[0]
    free_status = app[6]
    if free_status == 'Free': 
        android_free.append(app)

# %%
explore_data(android_free,0,5,True)
print(" ")
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# Number of rows: 8863
# Number of columns: 13

# %%
ios_free = [] 

for app in ios_english: 
    name = app[2]
    free_status = app[5]
    if free_status == '0': 
        ios_free.append(app)

# %%
explore_data(ios_free,0,5,True)
# Out:
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# ['4', '282614216', 'eBay: Best App to Buy, Sell, Save! Online Shopping', '128512000', 'USD', '0', '262241', '649', '4', '4.5', '5.10.0', '12+', 'Shopping', '37', '5', '9', '1']
#
#
# ['5', '282935706', 'Bible', '92774400', 'USD', '0', '985920', '5320', '4.5', '5', '7.5.1', '4+', 'Reference', '37', '5', '45', '1']
#
#
# ['7', '283646709', 'PayPal - Send and request money safely', '227795968', 'USD', '0', '119487', '879', '4', '4.5', '6.12.0', '4+', 'Finance', '37', '0', '19', '1']
#
#
# Number of rows: 3222
# Number of columns: 17

# %% [markdown]
# <h3> Checkpoint: Cleaning Complete </h3>
#
# Thus far within the dataset, I have spent a majority of the time cleaning the data and narrowing the scope of our focus to two data frames - ios_free and android_free.
#
# The Steps Completed Thus Far:
# - Removing Innaccurate Data
# - Removing Duplicate Applications
# - Mantaining Strategic Balance While Removing Duplicates
# - Removing Irrelevant Applications (Such as Non-English Apps)
# - Isolating Free Apps as we want to assess the impact of in-application advertisemesnts

# %% [markdown]
# <h3> Goal Moving Forward </h3>
#
# The aim from this point onwards in the study is to determine the type of applications that are likely to attract more users. Because revenue for "free" applications is directly correlated to the number of users for the application, this will be an integral part of our focus.
#
# In any business, the goal is to minimize risk and overhead costs associated with any given process. In this case, I would like to mention that the overall process is Application Development. Thus, in order to minimize costs and mitigate risk, the validation strategy I am following is based off of the following three assumptions:
# 1. The company that is conducting this study builds a minimal Android MVP of the application and then adds this iteration to Google Play.
# 2. If the application has a good response from users, the company develops it further and iterates on its findings.
# 3. If the application then yields profitability within six month from positive response time, the company will focus on building an iOS version of the application and add this to the Apple Store.
#
#  Since the end goal for the company I am consulting is to add the application to both the Goole Play and Apple App Store, I will need to detect application types that are successful on both platforms.

# %% [markdown]
# <h3> Analyzing Application Genres By Platform </h3>
#
# Building Two Functions to help this process:
# 1. One function to generate frequency tbales that show percentages
# 2. Another function that we can use to display the percentages in Descending Order

# %%
def freq_table(dataset,index): 
    table = {} 
    total = 0 
    for row in dataset: 
        total+= 1
        value = row[index]
        if value in table: 
            table[value]+=1 
        else: 
            table[value]=1
            
    table_percentages = {} 
    for key in table: 
        percentage = (table[key]/total)*100
        table_percentages[key] = percentage 
    return table_percentages 

def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
        
    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
display_table(ios_free,-5)
# Out:
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# <h3> Takeaway from Apple Store Genres </h3>
#
# It is clearly evident that from the free English applications in the Apple App Store, more than half (58.16%) are games. Entertainment apps comprise of the next biggest bucket at 8%, followed by photo and video apps, which are close to 5%. Only 3.66% of the apps are designed for education. Lastly, social networking apps account for 3.29% of the toal applications in the dataset.
#
# The general impression is that App Store (at least the part containing free English apps) is dominated by apps that are designed for fun (games, entertainment, photo and video, social networking, sports, music, etc.), while apps with practical purposes (education, shopping, utilities, productivity, lifestyle, etc.) are more rare. However, the fact that fun apps are the most numerous doesn't also imply that they also have the greatest number of users.

# %%
display_table(android_free,1)
# Out:
# FAMILY : 18.898792733837304
# GAME : 9.725826469592688
# TOOLS : 8.462146000225657
# BUSINESS : 4.592124562789123
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.5315355974275078
# SPORTS : 3.396141261423897
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2381812027530184
# HEALTH_AND_FITNESS : 3.0802211440821394
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7939749520478394
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.1621347173643235
# ENTERTAINMENT : 0.9590432133589079
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# EVENTS : 0.7108202640189552
# PARENTING : 0.6544059573507841
# ART_AND_DESIGN : 0.6431230960171499
# COMICS : 0.6205573733498815
# BEAUTY : 0.5979916506826132

# %% [markdown]
# <h3> Takeaway: Google Store Categories </h3>
#
# When analyzing the frequency distribution of Google Play applications, it becomes clear that it is quite different from the distribution of that of the Apple App Store.
#
# Unlike the AppStore, there are not as many applications designed for fun. In fact, a good number of applications are designed for practical purposes(family, tools, business, lifestyle, productivity, etc.). However, looking at this deeper, the family category (which accounts for almost 19% of the apps) means mostly games for kids.
#
# Nevertheless, practical applications do seem to have a better representation on Google Play compared to App Store.

# %%
display_table(android_free,9)
# Out:
# Tools : 8.450863138892023
# Entertainment : 6.070179397495204
# Education : 5.348076272142616
# Business : 4.592124562789123
# Productivity : 3.8925871601038025
# Lifestyle : 3.8925871601038025
# Finance : 3.7007785174320205
# Medical : 3.5315355974275078
# Sports : 3.463838429425702
# Personalization : 3.317161232088458
# Communication : 3.2381812027530184
# Action : 3.102786866749408
# Health & Fitness : 3.0802211440821394
# Photography : 2.944826808078529
# News & Magazines : 2.798149610741284
# Social : 2.6627552747376737
# Travel & Local : 2.324269434728647
# Shopping : 2.245289405393208
# Books & Reference : 2.1437436533904997
# Simulation : 2.042197901387792
# Dating : 1.8616721200496444
# Arcade : 1.8503892587160102
# Video Players & Editors : 1.771409229380571
# Casual : 1.7601263680469368
# Maps & Navigation : 1.399074805370642
# Food & Drink : 1.241114746699763
# Puzzle : 1.128286133363421
# Racing : 0.9928917973598104
# Role Playing : 0.9364774906916393
# Libraries & Demo : 0.9364774906916393
# Auto & Vehicles : 0.9251946293580051
# Strategy : 0.9026289066907368
# House & Home : 0.8236488773552973
# Weather : 0.8010831546880289
# Events : 0.7108202640189552
# Adventure : 0.6769716800180525
# Comics : 0.6092745120162473
# Beauty : 0.5979916506826132
# Art & Design : 0.5979916506826132
# Parenting : 0.4964458986799052
# Card : 0.4513144533453684
# Casino : 0.42874873067809993
# Trivia : 0.4174658693444658
# Educational;Education : 0.3949001466771973
# Board : 0.38361728534356315
# Educational : 0.37233442400992894
# Education;Education : 0.33848584000902626
# Word : 0.25950581067358686
# Casual;Pretend Play : 0.2369400880063184
# Music : 0.20309150400541578
# Racing;Action & Adventure : 0.16924292000451313
# Puzzle;Brain Games : 0.16924292000451313
# Entertainment;Music & Video : 0.16924292000451313
# Casual;Brain Games : 0.1353943360036105
# Casual;Action & Adventure : 0.1353943360036105
# Arcade;Action & Adventure : 0.1241114746699763
# Action;Action & Adventure : 0.10154575200270789
# Educational;Pretend Play : 0.09026289066907367
# Simulation;Action & Adventure : 0.07898002933543948
# Parenting;Education : 0.07898002933543948
# Entertainment;Brain Games : 0.07898002933543948
# Board;Brain Games : 0.07898002933543948
# Parenting;Music & Video : 0.06769716800180525
# Educational;Brain Games : 0.06769716800180525
# Casual;Creativity : 0.06769716800180525
# Art & Design;Creativity : 0.06769716800180525
# Education;Pretend Play : 0.05641430666817105
# Role Playing;Pretend Play : 0.045131445334536835
# Education;Creativity : 0.045131445334536835
# Role Playing;Action & Adventure : 0.033848584000902626
# Puzzle;Action & Adventure : 0.033848584000902626
# Entertainment;Creativity : 0.033848584000902626
# Entertainment;Action & Adventure : 0.033848584000902626
# Educational;Creativity : 0.033848584000902626
# Educational;Action & Adventure : 0.033848584000902626
# Education;Music & Video : 0.033848584000902626
# Education;Brain Games : 0.033848584000902626
# Education;Action & Adventure : 0.033848584000902626
# Adventure;Action & Adventure : 0.033848584000902626
# Video Players & Editors;Music & Video : 0.022565722667268417
# Sports;Action & Adventure : 0.022565722667268417
# Simulation;Pretend Play : 0.022565722667268417
# Puzzle;Creativity : 0.022565722667268417
# Music;Music & Video : 0.022565722667268417
# Entertainment;Pretend Play : 0.022565722667268417
# Casual;Education : 0.022565722667268417
# Board;Action & Adventure : 0.022565722667268417
# Video Players & Editors;Creativity : 0.011282861333634209
# Trivia;Education : 0.011282861333634209
# Travel & Local;Action & Adventure : 0.011282861333634209
# Tools;Education : 0.011282861333634209
# Strategy;Education : 0.011282861333634209
# Strategy;Creativity : 0.011282861333634209
# Strategy;Action & Adventure : 0.011282861333634209
# Simulation;Education : 0.011282861333634209
# Role Playing;Brain Games : 0.011282861333634209
# Racing;Pretend Play : 0.011282861333634209
# Puzzle;Education : 0.011282861333634209
# Parenting;Brain Games : 0.011282861333634209
# Music & Audio;Music & Video : 0.011282861333634209
# Lifestyle;Pretend Play : 0.011282861333634209
# Lifestyle;Education : 0.011282861333634209
# Health & Fitness;Education : 0.011282861333634209
# Health & Fitness;Action & Adventure : 0.011282861333634209
# Entertainment;Education : 0.011282861333634209
# Communication;Creativity : 0.011282861333634209
# Comics;Creativity : 0.011282861333634209
# Casual;Music & Video : 0.011282861333634209
# Card;Action & Adventure : 0.011282861333634209
# Books & Reference;Education : 0.011282861333634209
# Art & Design;Pretend Play : 0.011282861333634209
# Art & Design;Action & Adventure : 0.011282861333634209
# Arcade;Pretend Play : 0.011282861333634209
# Adventure;Education : 0.011282861333634209

# %% [markdown]
# <h3> Takeaway: Google Store Continued </h3>
#
# Within the Google Store dataset, it becomes clear that there is another column labeled as "genres". Though this column is labeled the same as the Apple Store dataset, it is much more granular than the "category" column which makes it more difficult to make broader insights. For the purpose of this study, "category" does a much better job in comparing with the Apple Store data that is in the dataset.

# %%
apple_store_data[0:10]
# Out:
# [['',
#   'id',
#   'track_name',
#   'size_bytes',
#   'currency',
#   'price',
#   'rating_count_tot',
#   'rating_count_ver',
#   'user_rating',
#   'user_rating_ver',
#   'ver',
#   'cont_rating',
#   'prime_genre',
#   'sup_devices.num',
#   'ipadSc_urls.num',
#   'lang.num',
#   'vpp_lic'],
#  ['1',
#   '281656475',
#   'PAC-MAN Premium',
#   '100788224',
#   'USD',
#   '3.99',
#   '21292',
#   '26',
#   '4',
#   '4.5',
#   '6.3.5',
#   '4+',
#   'Games',
#   '38',
#   '5',
#   '10',
#   '1'],
#  ['2',
#   '281796108',
#   'Evernote - stay organized',
#   '158578688',
#   'USD',
#   '0',
#   '161065',
#   '26',
#   '4',
#   '3.5',
#   '8.2.2',
#   '4+',
#   'Productivity',
#   '37',
#   '5',
#   '23',
#   '1'],
#  ['3',
#   '281940292',
#   'WeatherBug - Local Weather, Radar, Maps, Alerts',
#   '100524032',
#   'USD',
#   '0',
#   '188583',
#   '2822',
#   '3.5',
#   '4.5',
#   '5.0.0',
#   '4+',
#   'Weather',
#   '37',
#   '5',
#   '3',
#   '1'],
#  ['4',
#   '282614216',
#   'eBay: Best App to Buy, Sell, Save! Online Shopping',
#   '128512000',
#   'USD',
#   '0',
#   '262241',
#   '649',
#   '4',
#   '4.5',
#   '5.10.0',
#   '12+',
#   'Shopping',
#   '37',
#   '5',
#   '9',
#   '1'],
#  ['5',
#   '282935706',
#   'Bible',
#   '92774400',
#   'USD',
#   '0',
#   '985920',
#   '5320',
#   '4.5',
#   '5',
#   '7.5.1',
#   '4+',
#   'Reference',
#   '37',
#   '5',
#   '45',
#   '1'],
#  ['6',
#   '283619399',
#   'Shanghai Mahjong',
#   '10485713',
#   'USD',
#   '0.99',
#   '8253',
#   '5516',
#   '4',
#   '4',
#   '1.8',
#   '4+',
#   'Games',
#   '47',
#   '5',
#   '1',
#   '1'],
#  ['7',
#   '283646709',
#   'PayPal - Send and request money safely',
#   '227795968',
#   'USD',
#   '0',
#   '119487',
#   '879',
#   '4',
#   '4.5',
#   '6.12.0',
#   '4+',
#   'Finance',
#   '37',
#   '0',
#   '19',
#   '1'],
#  ['8',
#   '284035177',
#   'Pandora - Music & Radio',
#   '130242560',
#   'USD',
#   '0',
#   '1126879',
#   '3594',
#   '4',
#   '4.5',
#   '8.4.1',
#   '12+',
#   'Music',
#   '37',
#   '4',
#   '1',
#   '1'],
#  ['9',
#   '284666222',
#   'PCalc - The Best Calculator',
#   '49250304',
#   'USD',
#   '9.99',
#   '1117',
#   '4',
#   '4.5',
#   '5',
#   '3.6.6',
#   '4+',
#   'Utilities',
#   '37',
#   '5',
#   '1',
#   '1']]

# %%
genres_ios = freq_table(ios_free, 12)

for genre in genres_ios:
    total = 0
    len_genre = 0
    for app in ios_free:
        genre_app = app[12]
        if genre_app == genre:            
            n_ratings = float(app[6])
            total += n_ratings
            len_genre += 1
    avg_n_ratings = total / len_genre
    print(genre, ':', avg_n_ratings)
# Out:
# Productivity : 21028.410714285714
# Weather : 52279.892857142855
# Shopping : 26919.690476190477
# Reference : 74942.11111111111
# Finance : 31467.944444444445
# Music : 57326.530303030304
# Utilities : 18684.456790123455
# Travel : 28243.8
# Social Networking : 71548.34905660378
# Sports : 23008.898550724636
# Health & Fitness : 23298.015384615384
# Games : 22788.6696905016
# Food & Drink : 33333.92307692308
# News : 21248.023255813954
# Book : 39758.5
# Photo & Video : 28441.54375
# Entertainment : 14029.830708661417
# Business : 7491.117647058823
# Lifestyle : 16485.764705882353
# Education : 7003.983050847458
# Navigation : 86090.33333333333
# Medical : 612.0
# Catalogs : 4004.0

# %% [markdown]
# On average, navigation apps have the highest number of user reviews, but this figure is heavily influenced by Waze and Google Maps, which have close to half a million user reviews together:

# %%
#Navigational Applications iOS App Store 
for app in ios_free: 
    if app[12] =='Navigation': 
        print(app[2],':',app[6])
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Geocaching® : 12811
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# Google Maps - Navigation & Transit : 154911

# %%
#Social Networking Applications iOS App Store 
for app in ios_free: 
    if app[12] =='Social Networking': 
        print(app[2],':',app[6])
# Out:
# Facebook : 2974676
# LinkedIn : 71856
# Skype for iPhone : 373519
# Tumblr : 334293
# Match™ - #1 Dating App. : 60659
# WhatsApp Messenger : 287589
# TextNow - Unlimited Text + Calls : 164963
# Grindr - Gay and same sex guys chat, meet and date : 23201
# imo video calls and chat : 18841
# Ameba : 269
# Weibo : 7265
# Badoo - Meet New People, Chat, Socialize. : 34428
# Kik : 260965
# Qzone : 1649
# Fake-A-Location Free ™ : 354
# Tango - Free Video Call, Voice and Chat : 75412
# MeetMe - Chat and Meet New People : 97072
# SimSimi : 23530
# Viber Messenger – Text & Call : 164249
# Find My Family, Friends & iPhone - Life360 Locator : 43877
# Weibo HD : 16772
# POF - Best Dating App for Conversations : 52642
# GroupMe : 28260
# Lobi : 36
# WeChat : 34584
# ooVoo – Free Video Call, Text and Voice : 177501
# Pinterest : 1061624
# 知乎 : 397
# Qzone HD : 458
# Skype for iPad : 60163
# LINE : 11437
# QQ : 9109
# LOVOO - Dating Chat : 1985
# QQ HD : 5058
# Messenger : 351466
# eHarmony™ Dating App - Meet Singles : 11124
# YouNow: Live Stream Video Chat : 12079
# Cougar Dating & Life Style App for Mature Women : 213
# Battlefield™ Companion : 689
# Whisper - Share, Express, Meet : 39819
# We Heart It - Fashion, wallpapers, quotes, tattoos : 90414
# Followers - Social Analytics For Instagram : 112778
# InsTrack for Instagram - Analytics Plus More : 85535
# Followers + for Instagram - Follower Analytics : 28633
# Timehop : 49510
# Repost for Instagram : 15185
# LINE PLAY - Your Avatar World : 34677
# Nextdoor : 14402
# Hangouts : 36404
# FollowMeter for Instagram - Followers Tracking : 11976
# Telegram Messenger : 7573
# Chatous - Chat with new people : 1609
# QQ International : 274
# FireChat : 1037
# Jodel : 1193
# Wishbone - Compare Anything : 20649
# Zenly - Locate your friends in realtime : 427
# Tantan : 235
# Flinch - Video Chat Staring Contest : 2134
# botman - Real time video chat : 7
# 豆瓣 : 407
# Marco Polo Video Walkie Talkie : 27662
# After School - Funny Anonymous School News : 18482
# Highrise - Your Avatar Community : 2011
# Quick Reposter - Repost, Regram and Reshare Photos : 17694
# Kiwi - Q&A : 1538
# Periscope - Live Video Streaming Around the World : 6062
# Inke—Broadcast an amazing life : 147
# Discord - Chat for Gamers : 9152
# Candid - Speak Your Mind Freely : 398
# Down To Lunch : 2535
# SOMA Messenger : 3232
# Rawr Messenger - Dab your chat : 180
# Popcorn Buzz - Free Group Calls : 281
# Chain: Collaborate On MyVideo Story/Group Video : 35
# BestieBox : 0
# Selfeo : 366
# Followers Analysis Tool For Instagram App Free : 4253
# Hey! VINA - Where Women Meet New Friends : 719
# PlayStation®Messages : 1918
# WhenToPost: Best Time to Post Photos for Instagram : 158
# MATCH ON LINE chat : 0
# Fiesta by Tango - Chat & Meet New People : 885
# Houseparty - Group Video Chat : 3991
# All Devices for WhatsApp - Messenger for iPad : 682
# Peach — share vividly : 727
# bit-tube - Live Stream Video Chat : 0
# Miitomo : 23965
# SoundCloud Pulse: for creators : 240
# IAmNaughty – Dating App to Meet New People Online : 463
# League of Legends Friends : 420
# GhostCodes - a discovery app for Snapchat : 1313
# live.ly - live video streaming : 4145
# Live.me – Live Video Chat & Make Friends Nearby : 14724
# BOO! - Video chat camera with filters & stickers : 1805
# Google Allo — smart messaging : 862
# Google Duo - simple video calling : 1033
# Chat for Whatsapp - iPad Version : 5060
# Chat for Pokemon Go - GoChat : 500
# niconico ch : 0
# Followers Analytics for Instagram - InstaReport : 13914
# Monkey : 3060
# LINE BLOG : 0
# Mustknow - anonymous video Q&A : 53
# CTFxCmoji : 39
# Fam — Group video calling for iMessage : 279

# %%
#Music Applications iOS App Store 
for app in ios_free: 
    if app[12] =='Music': 
        print(app[2],':',app[6])
# Out:
# Pandora - Music & Radio : 1126879
# Shazam - Discover music, artists, videos & lyrics : 402925
# iHeartRadio – Free Music & Radio Stations : 293228
# Deezer - Listen to your Favorite Music & Playlists : 4677
# Sonos Controller : 48905
# NRJ Radio : 38
# radio.de - Der Radioplayer : 64
# Spotify Music : 878563
# SoundCloud - Music & Audio : 135744
# Sing Karaoke Songs Unlimited with StarMaker : 26227
# SoundHound Song Search & Music Player : 82602
# Ringtones for iPhone & Ringtone Maker : 25403
# Coach Guitar - Lessons & Easy Tabs For Beginners : 2416
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 110420
# Magic Piano by Smule : 131695
# QQ音乐HD : 224
# The Singing Machine Mobile Karaoke App : 130
# Bandsintown Concerts : 30845
# PetitLyrics : 0
# edjing Mix:DJ turntable to remix and scratch music : 13580
# Smule Sing! : 119316
# Amazon Music : 106235
# AutoRap by Smule : 18202
# My Mixtapez Music : 26286
# Certified Mixtapes - Hip Hop Albums & Mixtapes : 9975
# Karaoke - Sing Karaoke, Unlimited Songs! : 28606
# Napster - Top Music & Radio : 14268
# Musi - Unlimited Music For YouTube : 25193
# UE BOOM : 612
# Spinrilla - Mixtapes For Free : 15053
# Google Play Music : 10118
# Piano - Play Keyboard Music Games with Magic Tiles : 1636
# Bose SoundTouch : 3687
# DatPiff : 2815
# Sounds app - Music And Friends : 5126
# Smart Music: Streaming Videos and Radio : 17
# Free Piano app by Yokee : 13016
# Simple Radio - Live AM & FM Radio Stations : 4787
# Trebel Music - Unlimited Music Downloader : 2570
# TIDAL : 7398
# Acapella from PicPlayPost : 2487
# Medly - Music Maker : 933
# Amazon Alexa : 3018
# Music Freedom - Unlimited Free MP3 Music Streaming : 1246
# PlayGround • Music At Your Fingertips : 150
# Musical Video Maker - Create Music clips lip sync : 320
# Free Music Play - Mp3 Streamer & Player : 2496
# LiveMixtapes : 555
# AmpMe - A Portable Social Party Music Speaker : 1047
# NOISE : 355
# YouTube Music : 7109
# Ringtones for iPhone with Ringtone Maker : 4013
# Music Memos : 909
# Musicloud - MP3 and FLAC Music Player for Cloud Platforms. : 2211
# Bose Connect : 915
# Cloud Music Player - Downloader & Playlist Manager : 319
# Remixlive - Remix loops with pads : 288
# Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : 46
# Boom: Best Equalizer & Magical Surround Sound : 1375
# MP3 Music Player & Streamer for Clouds : 329
# Nicki Minaj: The Empire : 5196
# SongFlip - Free Music Streamer : 5004
# Blocs Wave - Make & Record Music : 158
# Music and Chill : 135
# Free Music - MP3 Streamer & Playlist Manager Pro : 13443
# BOSS Tuner : 13

# %% [markdown]
# The same pattern applies to social networking apps, where the average number is heavily influenced by a few giants like Facebook, Pinterest, Skype, etc. Same applies to music apps, where a few big players like Pandora, Spotify, and Shazam heavily influence the average number.
#
# The goal is to find popular genres, but navigation, social networking or music apps might seem more popular than they really are. The average number of ratings seem to be skewed by very few apps which have hundreds of thousands of user ratings, while the other apps may struggle to get past the 10,000 threshold.
#
# Reference apps have 74,942 user ratings on average, but it's actually the Bible and Dictionary.com which skew up the average rating:

# %%
for app in ios_free: 
    if app[12] == 'Reference': 
        print(app[2],':',app[6])
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# Merriam-Webster Dictionary : 16849
# Google Translate : 26786
# Night Sky : 12122
# WWDC : 762
# Jishokun-Japanese English Dictionary & Translator : 0
# 教えて!goo : 0
# VPN Express : 14
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Real Bike Traffic Rider Virtual Reality Glasses : 8

# %% [markdown]
# However, this niche seems to show some potential. One thing our business could do is take another popular book and turn it into an app where we could add different features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes about the book, etc. On top of that, our business could also embed a dictionary within the app, so users don't need to exit our app to look up words in an external app.
#
# This idea seems to fit well with the fact that the App Store is dominated by for-fun apps. This suggests the market might be a bit saturated with for-fun apps, which means a practical app might have more of a chance to stand out among the huge number of apps on the App Store.
#
# Other genres that seem popular include weather, book, food and drink, or finance. The book genre seem to overlap a bit with the app idea we described above, but the other genres don't seem too interesting to us:
# - Weather apps — people generally don't spend too much time in-app, and the chances of making profit from in-app adds are low. Also, getting reliable live weather data may require us to connect our apps to non-free APIs.
#
# - Food and drink — examples here include Starbucks, Dunkin' Donuts, McDonald's, etc. So making a popular food and drink app requires actual cooking and a delivery service, which is outside the scope of our company.
#
# - Finance apps — these apps involve banking, paying bills, money transfer, etc. Building a finance app requires domain knowledge, and we don't want to hire a finance expert just to build an app.

# %% [markdown]
# <h3> Analyzing the Google Play Store </h3>

# %%
display_table(android_free, 5) # the Installs columns
# Out:
# 1,000,000+ : 15.728308699086089
# 100,000+ : 11.55365000564143
# 10,000,000+ : 10.549475346947986
# 10,000+ : 10.199706645605326
# 1,000+ : 8.394448832223853
# 100+ : 6.916393997517771
# 5,000,000+ : 6.826131106848697
# 500,000+ : 5.562450637481666
# 50,000+ : 4.772650344127271
# 5,000+ : 4.513144533453684
# 10+ : 3.542818458761142
# 500+ : 3.2494640640866526
# 50,000,000+ : 2.3017037120613786
# 100,000,000+ : 2.1324607920568655
# 50+ : 1.9180864267178157
# 5+ : 0.7898002933543946
# 1+ : 0.5077287600135394
# 500,000,000+ : 0.270788672007221
# 1,000,000,000+ : 0.2256572266726842
# 0+ : 0.045131445334536835

# %% [markdown]
# One problem with this data is that is not precise. For instance, we don't know whether an app with 100,000+ installs has 100,000 installs, 200,000, or 350,000. However, we don't need very precise data for our purposes — we only want to get an idea which app genres attract the most users, and we don't need perfect precision with respect to the number of users.
#
# We're going to leave the numbers as they are, which means that we'll consider that an app with 100,000+ installs has 100,000 installs, and an app with 1,000,000+ installs has 1,000,000 installs, and so on.
#
# To perform computations, however, we'll need to convert each install number to float — this means that we need to remove the commas and the plus characters, otherwise the conversion will fail and raise an error. We'll do this directly in the loop below, where we also compute the average number of installs for each genre (category).

# %%
categories_android = freq_table(android_free, 1)

for category in categories_android:
    total = 0
    len_category = 0
    for app in android_free:
        category_app = app[1]
        if category_app == category:            
            n_installs = app[5]
            n_installs = n_installs.replace(',', '')
            n_installs = n_installs.replace('+', '')
            total += float(n_installs)
            len_category += 1
    avg_n_installs = total / len_category
    print(category, ':', avg_n_installs)
# Out:
# ART_AND_DESIGN : 1986335.0877192982
# AUTO_AND_VEHICLES : 647317.8170731707
# BEAUTY : 513151.88679245283
# BOOKS_AND_REFERENCE : 8767811.894736841
# BUSINESS : 1712290.1474201474
# COMICS : 817657.2727272727
# COMMUNICATION : 38456119.167247385
# DATING : 854028.8303030303
# EDUCATION : 1833495.145631068
# ENTERTAINMENT : 11640705.88235294
# EVENTS : 253542.22222222222
# FINANCE : 1387692.475609756
# FOOD_AND_DRINK : 1924897.7363636363
# HEALTH_AND_FITNESS : 4188821.9853479853
# HOUSE_AND_HOME : 1331540.5616438356
# LIBRARIES_AND_DEMO : 638503.734939759
# LIFESTYLE : 1437816.2687861272
# GAME : 15588015.603248259
# FAMILY : 3697848.1731343283
# MEDICAL : 120550.61980830671
# SOCIAL : 23253652.127118643
# SHOPPING : 7036877.311557789
# PHOTOGRAPHY : 17840110.40229885
# SPORTS : 3638640.1428571427
# TRAVEL_AND_LOCAL : 13984077.710144928
# TOOLS : 10801391.298666667
# PERSONALIZATION : 5201482.6122448975
# PRODUCTIVITY : 16787331.344927534
# PARENTING : 542603.6206896552
# WEATHER : 5074486.197183099
# VIDEO_PLAYERS : 24727872.452830188
# NEWS_AND_MAGAZINES : 9549178.467741935
# MAPS_AND_NAVIGATION : 4056941.7741935486

# %%
for app in android_free:
    if app[1] == 'COMMUNICATION' and (app[5] == '1,000,000,000+'
                                      or app[5] == '500,000,000+'
                                      or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# WhatsApp Messenger : 1,000,000,000+
# imo beta free calls and text : 100,000,000+
# Android Messages : 100,000,000+
# Google Duo - High Quality Video Calls : 500,000,000+
# Messenger – Text and Video Chat for Free : 1,000,000,000+
# imo free video calls and chat : 500,000,000+
# Skype - free IM & video calls : 1,000,000,000+
# Who : 100,000,000+
# GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000+
# LINE: Free Calls & Messages : 500,000,000+
# Google Chrome: Fast & Secure : 1,000,000,000+
# Firefox Browser fast & private : 100,000,000+
# UC Browser - Fast Download Private & Secure : 500,000,000+
# Gmail : 1,000,000,000+
# Hangouts : 1,000,000,000+
# Messenger Lite: Free Calls & Messages : 100,000,000+
# Kik : 100,000,000+
# KakaoTalk: Free Calls & Text : 100,000,000+
# Opera Mini - fast web browser : 100,000,000+
# Opera Browser: Fast and Secure : 100,000,000+
# Telegram : 100,000,000+
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000+
# UC Browser Mini -Tiny Fast Private & Secure : 100,000,000+
# Viber Messenger : 500,000,000+
# WeChat : 100,000,000+
# Yahoo Mail – Stay Organized : 100,000,000+
# BBM - Free Calls & Messages : 100,000,000+

# %%
under_100_m = []

for app in android_free:
    n_installs = app[5]
    n_installs = n_installs.replace(',', '')
    n_installs = n_installs.replace('+', '')
    if (app[1] == 'COMMUNICATION') and (float(n_installs) < 100000000):
        under_100_m.append(float(n_installs))
        
sum(under_100_m) / len(under_100_m)
# Out:
# 3603485.3884615386

# %% [markdown]
# The pattern is the same for the video players category, which is the runner-up with 24,727,872 installs. The market is dominated by apps like Youtube, Google Play Movies & TV, or MX Player. The pattern is repeated for social apps (where we have giants like Facebook, Instagram, Google+, etc.), photography apps (Google Photos and other popular photo editors), or productivity apps (Microsoft Word, Dropbox, Google Calendar, Evernote, etc.).
#
# Again, the main concern is that these app genres might seem more popular than they really are. Moreover, these niches seem to be dominated by a few giants who are hard to compete against.
#
# The game genre seems pretty popular, but previously we found out this part of the market seems a bit saturated, so we'd like to come up with a different app recommendation if possible.
#
# The books and reference genre looks fairly popular as well, with an average number of installs of 8,767,811. It's interesting to explore this in more depth, since we found this genre has some potential to work well on the App Store, and the primary goal is to recommend an app genre that shows potential for being profitable on both the App Store and Google Play.

# %%
for app in android_free:
    if app[1] == 'BOOKS_AND_REFERENCE':
        print(app[0], ':', app[5])
# Out:
# E-Book Read - Read Book for free : 50,000+
# Download free book with green book : 100,000+
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Free Panda Radio Music : 100,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# English Grammar Complete Handbook : 500,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# Google Play Books : 1,000,000,000+
# AlReader -any text book reader : 5,000,000+
# Offline English Dictionary : 100,000+
# Offline: English to Tagalog Dictionary : 500,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# Recipes of Prophetic Medicine for free : 500,000+
# ReadEra – free ebook reader : 1,000,000+
# Anonymous caller detection : 10,000+
# Ebook Reader : 5,000,000+
# Litnet - E-books : 100,000+
# Read books online : 5,000,000+
# English to Urdu Dictionary : 500,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# English Persian Dictionary : 500,000+
# Flybook : 500,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# English translation from Bengali : 100,000+
# Pdf Book Download - Read Pdf Book : 100,000+
# Free Book Reader : 100,000+
# eBoox new: Reader for fb2 epub zip books : 50,000+
# Only 30 days in English, the guideline is guaranteed : 500,000+
# Moon+ Reader : 10,000,000+
# SH-02J Owner's Manual (Android 8.0) : 50,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Azpen eReader : 500,000+
# URBANO V 02 instruction manual : 100,000+
# Bible : 100,000,000+
# C Programs and Reference : 50,000+
# C Offline Tutorial : 1,000+
# C Programs Handbook : 50,000+
# Amazon Kindle : 100,000,000+
# Aab e Hayat Full Novel : 100,000+
# Aldiko Book Reader : 10,000,000+
# Google I/O 2018 : 500,000+
# R Language Reference Guide : 10,000+
# Learn R Programming Full : 5,000+
# R Programing Offline Tutorial : 1,000+
# Guide for R Programming : 5+
# Learn R Programming : 10+
# R Quick Reference Big Data : 1,000+
# V Made : 100,000+
# Wattpad 📖 Free Books : 100,000,000+
# Dictionary - WordWeb : 5,000,000+
# Guide (for X-MEN) : 100,000+
# AC Air condition Troubleshoot,Repair,Maintenance : 5,000+
# AE Bulletins : 1,000+
# Ae Allah na Dai (Rasa) : 10,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Ag PhD Field Guide : 10,000+
# Ag PhD Deficiencies : 10,000+
# Ag PhD Planting Population Calculator : 1,000+
# Ag PhD Soybean Diseases : 1,000+
# Fertilizer Removal By Crop : 50,000+
# A-J Media Vault : 50+
# Al-Quran (Free) : 10,000,000+
# Al Quran (Tafsir & by Word) : 500,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al-Muhaffiz : 50,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Al-Quran 30 Juz free copies : 500,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Surah Al-Waqiah : 100,000+
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000+
# Satellite AR : 1,000,000+
# Audiobooks from Audible : 100,000,000+
# Kinot & Eichah for Tisha B'Av : 10,000+
# AW Tozer Devotionals - Daily : 5,000+
# Tozer Devotional -Series 1 : 1,000+
# The Pursuit of God : 1,000+
# AY Sing : 5,000+
# Ay Hasnain k Nana Milad Naat : 10,000+
# Ay Mohabbat Teri Khatir Novel : 10,000+
# Arizona Statutes, ARS (AZ Law) : 1,000+
# Oxford A-Z of English Usage : 1,000,000+
# BD Fishpedia : 1,000+
# BD All Sim Offer : 10,000+
# Youboox - Livres, BD et magazines : 500,000+
# B&H Kids AR : 10,000+
# B y H Niños ES : 5,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# Borneo Bible, BM Bible : 10,000+
# MOD Black for BM : 100+
# BM Box : 1,000+
# Anime Mod for BM : 100+
# NOOK: Read eBooks & Magazines : 10,000,000+
# NOOK Audiobooks : 500,000+
# NOOK App for NOOK Devices : 500,000+
# Browsery by Barnes & Noble : 5,000+
# bp e-store : 1,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# BR Ambedkar Biography & Quotes : 10,000+
# BU Alsace : 100+
# Catholic La Bu Zo Kam : 500+
# Khrifa Hla Bu (Solfa) : 10+
# Kristian Hla Bu : 10,000+
# SA HLA BU : 1,000+
# Learn SAP BW : 500+
# Learn SAP BW on HANA : 500+
# CA Laws 2018 (California Laws and Codes) : 5,000+
# Bootable Methods(USB-CD-DVD) : 10,000+
# cloudLibrary : 100,000+
# SDA Collegiate Quarterly : 500+
# Sabbath School : 100,000+
# Cypress College Library : 100+
# Stats Royale for Clash Royale : 1,000,000+
# GATE 21 years CS Papers(2011-2018 Solved) : 50+
# Learn CT Scan Of Head : 5,000+
# Easy Cv maker 2018 : 10,000+
# How to Write CV : 100,000+
# CW Nuclear : 1,000+
# CY Spray nozzle : 10+
# BibleRead En Cy Zh Yue : 5+
# CZ-Help : 5+
# Modlitební knížka CZ : 500+
# Guide for DB Xenoverse : 10,000+
# Guide for DB Xenoverse 2 : 10,000+
# Guide for IMS DB : 10+
# DC HSEMA : 5,000+
# DC Public Library : 1,000+
# Painting Lulu DC Super Friends : 1,000+
# Dictionary : 10,000,000+
# Fix Error Google Playstore : 1,000+
# D. H. Lawrence Poems FREE : 1,000+
# Bilingual Dictionary Audio App : 5,000+
# DM Screen : 10,000+
# wikiHow: how to do anything : 1,000,000+
# Dr. Doug's Tips : 1,000+
# Bible du Semeur-BDS (French) : 50,000+
# La citadelle du musulman : 50,000+
# DV 2019 Entry Guide : 10,000+
# DV 2019 - EDV Photo & Form : 50,000+
# DV 2018 Winners Guide : 1,000+
# EB Annual Meetings : 1,000+
# EC - AP & Telangana : 5,000+
# TN Patta Citta & EC : 10,000+
# AP Stamps and Registration : 10,000+
# CompactiMa EC pH Calibration : 100+
# EGW Writings 2 : 100,000+
# EGW Writings : 1,000,000+
# Bible with EGW Comments : 100,000+
# My Little Pony AR Guide : 1,000,000+
# SDA Sabbath School Quarterly : 500,000+
# Duaa Ek Ibaadat : 5,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+
# EP Research Service : 1,000+
# Hymnes et Louanges : 100,000+
# EU Charter : 1,000+
# EU Data Protection : 1,000+
# EU IP Codes : 100+
# EW PDF : 5+
# BakaReader EX : 100,000+
# EZ Quran : 50,000+
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000+
# La Fe de Jesus : 1,000+
# La Fe de Jesús : 500+
# Le Fe de Jesus : 500+
# Florida - Pocket Brainbook : 1,000+
# Florida Statutes (FL Code) : 1,000+
# English To Shona Dictionary : 10,000+
# Greek Bible FP (Audio) : 1,000+
# Golden Dictionary (FR-AR) : 500,000+
# Fanfic-FR : 5,000+
# Bulgarian French Dictionary Fr : 10,000+
# Chemin (fr) : 1,000+
# The SCP Foundation DB fr nn5n : 1,000+

# %%
for app in android_free:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000,000+'
                                            or app[5] == '500,000,000+'
                                            or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Google Play Books : 1,000,000,000+
# Bible : 100,000,000+
# Amazon Kindle : 100,000,000+
# Wattpad 📖 Free Books : 100,000,000+
# Audiobooks from Audible : 100,000,000+

# %% [markdown]
# However, it looks like there are only a few very popular apps, so this market still shows potential. Now, I will look at some applications that are somewhere in the middle in terms of popularity (between 1,000,000 and 100,000,000 downloads):

# %%
for app in android_free:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000+'
                                            or app[5] == '5,000,000+'
                                            or app[5] == '10,000,000+'
                                            or app[5] == '50,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# AlReader -any text book reader : 5,000,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# ReadEra – free ebook reader : 1,000,000+
# Ebook Reader : 5,000,000+
# Read books online : 5,000,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# Moon+ Reader : 10,000,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Aldiko Book Reader : 10,000,000+
# Dictionary - WordWeb : 5,000,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Al-Quran (Free) : 10,000,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Satellite AR : 1,000,000+
# Oxford A-Z of English Usage : 1,000,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# NOOK: Read eBooks & Magazines : 10,000,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# Stats Royale for Clash Royale : 1,000,000+
# Dictionary : 10,000,000+
# wikiHow: how to do anything : 1,000,000+
# EGW Writings : 1,000,000+
# My Little Pony AR Guide : 1,000,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+

# %% [markdown]
# This niche seems to be dominated by software for processing and reading ebooks, as well as various collections of libraries and dictionaries, so it's probably not a good idea to build similar apps since there'll be some significant competition.
#
# Also, there are quite a few apps built around the book Quran, which suggests that building an app around a popular book can be profitable. It seems that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets.
#
# However, it looks like the market is already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.

# %% [markdown]
# <h3> Conclusions </h3>

# %% [markdown]
# In this project, the primary objective was to analyze data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# In conclusion, a good strategy might be to take a popular book (perhaps a more recent book) and turn it into an app that could be profitable for both the Google Play and the Apple App Store markets. The markets are already full of libraries, so it is imperative to note that in order for this strategy to be successful, our developers will need to add some special features besides just the raw version of the book. As previously mentioned, this could look something like the following:
# - daily quotes from the book
# - an audio version of the book
# - a forum where people can discuss the book
# - any other special features
